# %%
# !python -m spacy download nb_core_news_sm
# !python -m spacy download nb_core_news_md
# !python -m spacy download nb_core_news_lg
# !pip install sklearn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting nb-core-news-sm==3.5.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/nb_core_news_sm-3.5.0/nb_core_news_sm-3.5.0-py3-none-any.whl (12.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.5/12.5 MB 12.7 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: spacy<3.6.0,>=3.5.0 in /home/vincent/.local/lib/python3.10/site-packages (from nb-core-news-sm==3.5.0) (3.5.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/vincent/.local/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->nb-core-news-sm==3.5.0) (4.64.1)
# Requirement already satisfied: pathy>=0.10.0 in /home/vincent/.local/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->nb-core-news-sm==3.5.0) (0.10.1)
# Requirement already satisfied: jinja2 in /home/vincent/.local/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->nb-core-news-sm==3.5.0) (3.1.2)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /home/vincent/.local/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->nb-core-news-sm==3.5.0) (1.1.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/vincent/.local/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->nb-core-news-sm==3.5.0) (1.0.9)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /home/vincent/.local/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->nb-core-news-sm==3.5.0) (3.0.12)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/vincent/.local/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->nb-core-news-sm==3.5.0) (2.0.7)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/vincent/.local/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->nb-core-news-sm==3.5.0) (1.0.4)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /home/vincent/.local/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->nb-core-news-sm==3.5.0) (1.10.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/lib/python3/dist-packages (from spacy<3.6.0,>=3.5.0->nb-core-news-sm==3.5.0) (2.25.1)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /home/vincent/.local/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->nb-core-news-sm==3.5.0) (0.7.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /home/vincent/.local/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->nb-core-news-sm==3.5.0) (2.4.5)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from spacy<3.6.0,>=3.5.0->nb-core-news-sm==3.5.0) (59.6.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /home/vincent/.local/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->nb-core-news-sm==3.5.0) (6.3.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/vincent/.local/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->nb-core-news-sm==3.5.0) (3.3.0)
# Requirement already satisfied: packaging>=20.0 in /home/vincent/.local/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->nb-core-news-sm==3.5.0) (23.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/vincent/.local/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->nb-core-news-sm==3.5.0) (3.0.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/vincent/.local/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->nb-core-news-sm==3.5.0) (2.0.8)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /home/vincent/.local/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->nb-core-news-sm==3.5.0) (8.1.7)
# Requirement already satisfied: numpy>=1.15.0 in /home/vincent/.local/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->nb-core-news-sm==3.5.0) (1.24.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.6.0,>=3.5.0->nb-core-news-sm==3.5.0) (4.4.0)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /home/vincent/.local/lib/python3.10/site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.6.0,>=3.5.0->nb-core-news-sm==3.5.0) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /home/vincent/.local/lib/python3.10/site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.6.0,>=3.5.0->nb-core-news-sm==3.5.0) (0.0.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/lib/python3/dist-packages (from typer<0.8.0,>=0.3.0->spacy<3.6.0,>=3.5.0->nb-core-news-sm==3.5.0) (8.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/lib/python3/dist-packages (from jinja2->spacy<3.6.0,>=3.5.0->nb-core-news-sm==3.5.0) (2.0.1)
# ✔ Download and installation successful
# You can now load the package via spacy.load('nb_core_news_sm')
# Defaulting to user installation because normal site-packages is not writeable
# Collecting nb-core-news-md==3.5.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/nb_core_news_md-3.5.0/nb_core_news_md-3.5.0-py3-none-any.whl (42.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.3/42.3 MB 11.7 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: spacy<3.6.0,>=3.5.0 in /home/vincent/.local/lib/python3.10/site-packages (from nb-core-news-md==3.5.0) (3.5.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /home/vincent/.local/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->nb-core-news-md==3.5.0) (3.0.12)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/vincent/.local/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->nb-core-news-md==3.5.0) (3.0.8)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/vincent/.local/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->nb-core-news-md==3.5.0) (1.0.4)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /home/vincent/.local/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->nb-core-news-md==3.5.0) (6.3.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /home/vincent/.local/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->nb-core-news-md==3.5.0) (1.10.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/lib/python3/dist-packages (from spacy<3.6.0,>=3.5.0->nb-core-news-md==3.5.0) (2.25.1)
# Requirement already satisfied: numpy>=1.15.0 in /home/vincent/.local/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->nb-core-news-md==3.5.0) (1.24.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/vincent/.local/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->nb-core-news-md==3.5.0) (1.0.9)
# Requirement already satisfied: jinja2 in /home/vincent/.local/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->nb-core-news-md==3.5.0) (3.1.2)
# Requirement already satisfied: pathy>=0.10.0 in /home/vincent/.local/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->nb-core-news-md==3.5.0) (0.10.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/vincent/.local/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->nb-core-news-md==3.5.0) (3.3.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /home/vincent/.local/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->nb-core-news-md==3.5.0) (2.4.5)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/vincent/.local/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->nb-core-news-md==3.5.0) (2.0.7)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /home/vincent/.local/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->nb-core-news-md==3.5.0) (0.7.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/vincent/.local/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->nb-core-news-md==3.5.0) (2.0.8)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from spacy<3.6.0,>=3.5.0->nb-core-news-md==3.5.0) (59.6.0)
# Requirement already satisfied: packaging>=20.0 in /home/vincent/.local/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->nb-core-news-md==3.5.0) (23.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/vincent/.local/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->nb-core-news-md==3.5.0) (4.64.1)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /home/vincent/.local/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->nb-core-news-md==3.5.0) (8.1.7)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /home/vincent/.local/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->nb-core-news-md==3.5.0) (1.1.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.6.0,>=3.5.0->nb-core-news-md==3.5.0) (4.4.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /home/vincent/.local/lib/python3.10/site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.6.0,>=3.5.0->nb-core-news-md==3.5.0) (0.0.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /home/vincent/.local/lib/python3.10/site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.6.0,>=3.5.0->nb-core-news-md==3.5.0) (0.7.9)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/lib/python3/dist-packages (from typer<0.8.0,>=0.3.0->spacy<3.6.0,>=3.5.0->nb-core-news-md==3.5.0) (8.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/lib/python3/dist-packages (from jinja2->spacy<3.6.0,>=3.5.0->nb-core-news-md==3.5.0) (2.0.1)
# ✔ Download and installation successful
# You can now load the package via spacy.load('nb_core_news_md')
# Defaulting to user installation because normal site-packages is not writeable
# Collecting nb-core-news-lg==3.5.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/nb_core_news_lg-3.5.0/nb_core_news_lg-3.5.0-py3-none-any.whl (569.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 569.4/569.4 MB 3.8 MB/s eta 0:00:0000:0100:02
# Requirement already satisfied: spacy<3.6.0,>=3.5.0 in /home/vincent/.local/lib/python3.10/site-packages (from nb-core-news-lg==3.5.0) (3.5.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /home/vincent/.local/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->nb-core-news-lg==3.5.0) (1.10.5)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /home/vincent/.local/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->nb-core-news-lg==3.5.0) (8.1.7)
# Requirement already satisfied: jinja2 in /home/vincent/.local/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->nb-core-news-lg==3.5.0) (3.1.2)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/vincent/.local/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->nb-core-news-lg==3.5.0) (1.0.9)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /home/vincent/.local/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->nb-core-news-lg==3.5.0) (0.7.0)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/vincent/.local/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->nb-core-news-lg==3.5.0) (1.0.4)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/vincent/.local/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->nb-core-news-lg==3.5.0) (2.0.7)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/vincent/.local/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->nb-core-news-lg==3.5.0) (2.0.8)
# Requirement already satisfied: numpy>=1.15.0 in /home/vincent/.local/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->nb-core-news-lg==3.5.0) (1.24.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /home/vincent/.local/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->nb-core-news-lg==3.5.0) (2.4.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/lib/python3/dist-packages (from spacy<3.6.0,>=3.5.0->nb-core-news-lg==3.5.0) (2.25.1)
# Requirement already satisfied: pathy>=0.10.0 in /home/vincent/.local/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->nb-core-news-lg==3.5.0) (0.10.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /home/vincent/.local/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->nb-core-news-lg==3.5.0) (3.0.12)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/vincent/.local/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->nb-core-news-lg==3.5.0) (3.0.8)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /home/vincent/.local/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->nb-core-news-lg==3.5.0) (6.3.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/vincent/.local/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->nb-core-news-lg==3.5.0) (3.3.0)
# Requirement already satisfied: packaging>=20.0 in /home/vincent/.local/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->nb-core-news-lg==3.5.0) (23.0)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /home/vincent/.local/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->nb-core-news-lg==3.5.0) (1.1.1)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from spacy<3.6.0,>=3.5.0->nb-core-news-lg==3.5.0) (59.6.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/vincent/.local/lib/python3.10/site-packages (from spacy<3.6.0,>=3.5.0->nb-core-news-lg==3.5.0) (4.64.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.6.0,>=3.5.0->nb-core-news-lg==3.5.0) (4.4.0)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /home/vincent/.local/lib/python3.10/site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.6.0,>=3.5.0->nb-core-news-lg==3.5.0) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /home/vincent/.local/lib/python3.10/site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.6.0,>=3.5.0->nb-core-news-lg==3.5.0) (0.0.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/lib/python3/dist-packages (from typer<0.8.0,>=0.3.0->spacy<3.6.0,>=3.5.0->nb-core-news-lg==3.5.0) (8.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/lib/python3/dist-packages (from jinja2->spacy<3.6.0,>=3.5.0->nb-core-news-lg==3.5.0) (2.0.1)
# ✔ Download and installation successful
# You can now load the package via spacy.load('nb_core_news_lg')
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: sklearn in /home/vincent/.local/lib/python3.10/site-packages (0.0.post1)

# %%
import spacy
import json
import pandas
from numpy import arange
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.naive_bayes import MultinomialNB, BernoulliNB
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import confusion_matrix

# %%
data_3class = {}
for name in ["train", "dev", "test"]:
    with open(f"norec_sentence/3class/{name}.json") as infile:
        data_3class[name] = json.load(infile)

# %% [markdown]
# The data from thre json files named train, dev, and test are loaded are collected in the two dictionaries data_3class and data_binary

# %% [markdown]
# Dataset cloned from github: https://github.com/ltgoslo/norec_sentence
#
# Kutuzov, A., Barnes, J., Velldal, E., Øvrelid, L., & Oepen, S. (2021). Large-Scale Contextualised Language Modelling for Norwegian. Proceedings of the 23rd Nordic Conference on Computational Linguistics (NoDaLiDa 2021).
#
# Øvrelid, L., Mæhlum, P., Barnes, J., & Velldal, E. (2020). A Fine-grained Sentiment Dataset for Norwegian. Proceedings of the 12th Edition of the Language Resources and Evaluation Conference. Marseille, France, 2020.

# %% [markdown]
# The NoReC dataset is a collection of data from reviews, since it comes from reviews it can easely be maped to sentiment, ass most reviews come with a rating.

# %%
data_3class['train']
# Out:
# [{'sent_id': '201911-01-01', 'text': 'Philips 190G6', 'label': 'Neutral'},
#  {'sent_id': '201911-02-01',
#   'text': 'Med integrerte høyttalere som på ingen måte er diskret plassert , og med en stor subwoofer inkludert , da snakker vi om en gutteskjerm .',
#   'label': 'Neutral'},
#  {'sent_id': '201911-02-02',
#   'text': 'Eller bedrar skinnet ?',
#   'label': 'Negative'},
#  {'sent_id': '201911-03-01',
#   'text': 'De fleste skjermer har et diskret design , med smale rammer og slank fot .',
#   'label': 'Neutral'},
#  {'sent_id': '201911-03-02',
#   'text': 'Men 190G6 fra Philips er en helt annen historie .',
#   'label': 'Neutral'},
#  {'sent_id': '201911-03-03',
#   'text': 'Den har et utseende som krever oppmerksomhet , med glinsende svart ramme , glansbelegg på skjermflaten og store sølvfargede sidepaneler med fire innfelte høyttalere med svart deksel .',
#   'label': 'Neutral'},
#  {'sent_id': '201911-04-01', 'text': 'LES OGSÅ :', 'label': 'Neutral'},
#  {'sent_id': '201911-05-01',
#   'text': 'Foten har en stor og blank søyle , og det er store knapper og blå lys .',
#   'label': 'Neutral'},
#  {'sent_id': '201911-06-01',
#   'text': 'Baksiden er sort , blank og skinnende , med et deksel som skjuler kontakter og kabler .',
#   'label': 'Positive'},
#  {'sent_id': '201911-06-02',
#   'text': 'De fire høyttalerbrønnene stikker tydelig ut - her er det ikke snakk om å gjemme noe .',
#   'label': 'Neutral'},
#  {'sent_id': '201911-07-02',
#   'text': 'Likegyldig er det uansett vanskelig å være .',
#   'label': 'Neutral'},
#  {'sent_id': '201911-08-01', 'text': 'God betjening', 'label': 'Positive'},
#  {'sent_id': '201911-10-01',
#   'text': 'I midten finner vi volumknappen , som roterer fritt .',
#   'label': 'Neutral'},
#  {'sent_id': '201911-10-02',
#   'text': 'Nivået leser du av på skjermen , det dukker opp en skala så snart du skrur på knappen .',
#   'label': 'Neutral'},
#  {'sent_id': '201911-11-01',
#   'text': 'Til venstre finner vi en inngangsvelger , som bestemmer om skjermen skal vise sginal fra VGA , DVI , Scart , S-video , coaks eller komponentinngangene , som alle er plassert på baksiden av skjermen , under det sorte dekselet .',
#   'label': 'Neutral'},
#  {'sent_id': '201911-11-02',
#   'text': 'En mer allsidig og tilkoblingsvennlig skjerm har vi knapt sett .',
#   'label': 'Positive'},
#  {'sent_id': '201911-12-01',
#   'text': 'Til høyre finner vi forhåndsinnstillinger for lyden .',
#   'label': 'Neutral'},
#  {'sent_id': '201911-13-01',
#   'text': 'På hver side av foten er det tilkoblinger for henholdsvis USB og hodetelefon / mikrofon , og på baksiden er det tilkoblinger for USB til lyddelen , strøm og utsignal til subwooferen .',
#   'label': 'Neutral'},
#  {'sent_id': '201911-14-01',
#   'text': 'Skjermen kan bare vippes , ikke heves / senkes eller dreies .',
#   'label': 'Negative'},
#  {'sent_id': '201911-15-01', 'text': 'Bildekvalitet', 'label': 'Neutral'},
#  {'sent_id': '201911-16-01',
#   'text': 'Vi ble positivt overrasket over bildekvaliteten .',
#   'label': 'Positive'},
#  {'sent_id': '201911-16-02',
#   'text': 'Spesielt fargedynamikken var klart over gjennomsnittet .',
#   'label': 'Positive'},
#  {'sent_id': '201911-16-03',
#   'text': 'Det er flere faste fargeprofiler med forskjellige temperaturer å velge mellom , i tillegg til manuell innstilling .',
#   'label': 'Positive'},
#  {'sent_id': '201911-16-04',
#   'text': 'Justeringsområdet er stort , så det er svært gode tilpasningsmuligheter til forskjellige omgivelser .',
#   'label': 'Positive'},
#  {'sent_id': '201911-18-01',
#   'text': 'Responstiden var ikke av de aller raskeste , det var etterslep å se på testmaterialet .',
#   'label': 'Negative'},
#  {'sent_id': '201911-18-02',
#   'text': 'Men i praktisk spillsammenheng var det helt uproblematisk .',
#   'label': 'Positive'},
#  {'sent_id': '201911-19-01',
#   'text': 'Betraktningsvinkelen fra sidene var meget bra , du kan godt invitere 4 venn( inn ) er til å sitte ved siden av deg og se på skjermen uten at noen på sidene vil få dårligere bilde .',
#   'label': 'Positive'},
#  {'sent_id': '201911-20-01',
#   'text': 'Vertikalt er det derimot ikke spesielt imponerende , her forsvant rødt med det samme vi reiste oss opp og så ned på skjermen .',
#   'label': 'Negative'},
#  {'sent_id': '201911-21-01', 'text': 'Lydkvalitet', 'label': 'Neutral'},
#  {'sent_id': '201911-22-01',
#   'text': '190G6 kan kobles til et eksisterende lydkort med vanlig stereo minikack , men det er også en innebygd USB-lydenhet .',
#   'label': 'Neutral'},
#  {'sent_id': '201911-22-02',
#   'text': 'En driver må installeres , så er det bare å velge denne USB-lydenheten i stedet for den som sitter integrert eller montert i PCen .',
#   'label': 'Neutral'},
#  {'sent_id': '201911-23-01',
#   'text': 'Vi ble ikke imponert over lydstyrken .',
#   'label': 'Negative'},
#  {'sent_id': '201911-23-02',
#   'text': 'Ut fra størrelsen på subwooferen og de fire høyttalerene i skjermen hadde vi ventet oss en noe kraftigere lydstyrke .',
#   'label': 'Negative'},
#  {'sent_id': '201911-24-02',
#   'text': 'Det er egen volumkontroll på sub-wooferen , og den settes typisk i nærheten av midtstilling , avhengig av rom og plassering .',
#   'label': 'Neutral'},
#  {'sent_id': '201911-25-02',
#   'text': 'Den sliter litt også før den kommer opp i nærheten av maksområdet .',
#   'label': 'Negative'},
#  {'sent_id': '201911-26-01', 'text': 'Konkluskjon', 'label': 'Neutral'},
#  {'sent_id': '201911-27-01',
#   'text': 'Skjermen er spesiell , men den er god å betjene og har bildekvalitet godt over gjennommsnittet .',
#   'label': 'Positive'},
#  {'sent_id': '201911-28-02',
#   'text': 'I hvert fall når man ikke er alene hjemme ...',
#   'label': 'Neutral'},
#  {'sent_id': '102727-01-01', 'text': 'Liten storfilm', 'label': 'Neutral'},
#  {'sent_id': '102727-02-01',
#   'text': '« The Descendants » ( Etterkommerne ) er egentlig en ganske « liten » film , men med store spørsmål inne i seg .',
#   'label': 'Neutral'},
#  {'sent_id': '102727-02-02',
#   'text': 'Det handler om en travel advokat på Hawaii , som plutselig får livet snudd på hodet , når hans initiativrike hustru blir hardt skadet i en ulykke .',
#   'label': 'Neutral'},
#  {'sent_id': '102727-03-01',
#   'text': 'Først må han ta vare på sine to døtre - noe han aldri har gjort før .',
#   'label': 'Neutral'},
#  {'sent_id': '102727-03-02',
#   'text': 'Så må han ta tak i sin egen storfamilies hovedutfordring :',
#   'label': 'Neutral'},
#  {'sent_id': '102727-03-03',
#   'text': 'Som etterkommere av en polynesisk prinsesse , eier de et stort stykke land - verd ufattelige mye penger dersom det selges til utbygging .',
#   'label': 'Neutral'},
#  {'sent_id': '102727-04-01',
#   'text': 'Det store med denne filmen , er at den tar utfordringen med skikkelig behandling av noe så vanskelig som mellommenneskelige forhold .',
#   'label': 'Positive'},
#  {'sent_id': '102727-04-02',
#   'text': 'Etter filmer som « Sideways » og « About Schmidt » må vel regissør Alexander Payne sies å være en slags ekspert på dette .',
#   'label': 'Positive'},
#  {'sent_id': '102727-05-01',
#   'text': 'Kjenner vi egentlig våre nærmeste ?',
#   'label': 'Neutral'},
#  {'sent_id': '102727-05-02',
#   'text': 'Prioriterer vi riktig i hverdagen ?',
#   'label': 'Neutral'},
#  {'sent_id': '102727-05-03',
#   'text': 'Hvordan forvalter vi vårt ansvar , som enkeltindivider og samfunnsborgere ?',
#   'label': 'Neutral'},
#  {'sent_id': '102727-06-01',
#   'text': 'George Clooney er mannen som bærer det hele på sine ikke alt for brede skuldre .',
#   'label': 'Neutral'},
#  {'sent_id': '102727-06-02',
#   'text': 'Og han gjør det enormt godt .',
#   'label': 'Positive'},
#  {'sent_id': '102727-06-03',
#   'text': 'Uten store geberder gjennomlever han en livsomveltende krise .',
#   'label': 'Neutral'},
#  {'sent_id': '102727-06-04',
#   'text': 'Man opplever en intelligent skuespiller flink nok til å holde igjen - dog alltid tydelig nok i alt han foretar seg .',
#   'label': 'Positive'},
#  {'sent_id': '102727-07-01',
#   'text': 'Her er han , på mest mulig overbevisende måte , en helt « vanlig mann » .',
#   'label': 'Neutral'},
#  {'sent_id': '102727-07-02',
#   'text': 'Ikke glamorøs , nokså tydelig litt aldrende , helt tydelig meget sårbar .',
#   'label': 'Neutral'},
#  {'sent_id': '102727-08-01',
#   'text': 'Interessant er også beskrivelsen av Hawaii , ofte nok beskrevet som en « paradis » .',
#   'label': 'Positive'},
#  {'sent_id': '102727-08-02',
#   'text': 'Denne gangen mye mer trivielt eksponert - dog med sine helt særegne skikker og tradisjoner og historie .',
#   'label': 'Neutral'},
#  {'sent_id': '102727-09-01',
#   'text': 'Så på flere plan makter denne filmen ikke bare å underholde og vise følelser - men også gi interessant ny kunnskap .',
#   'label': 'Positive'},
#  {'sent_id': '102727-10-01',
#   'text': 'Det er godt gjort !',
#   'label': 'Positive'},
#  {'sent_id': '001392-01-01',
#   'text': 'Halvhjertet helhet',
#   'label': 'Negative'},
#  {'sent_id': '001392-02-01',
#   'text': 'The New Pornographers :',
#   'label': 'Neutral'},
#  {'sent_id': '001392-02-02', 'text': 'Together', 'label': 'Neutral'},
#  {'sent_id': '001392-03-01',
#   'text': 'Trygt og godt album fra The New Pornographers , men det er ikke slik vi vil ha dem .',
#   'label': 'Negative'},
#  {'sent_id': '001392-04-01',
#   'text': 'Et eller annet sted like etter Twin Cinema ( 2005 ) bestemte The New Pornographers seg plutselig for å bli et ordentlig band .',
#   'label': 'Neutral'},
#  {'sent_id': '001392-04-02',
#   'text': 'Dette var en forferdelig avgjørelse for de av oss som hadde elsket dem tidligere , for det betød i dette tilfellet at medlemmene skulle dra i samme retning – albumene skulle bli mer helhetlige og lyden skulle være mer polert og avrundet .',
#   'label': 'Negative'},
#  {'sent_id': '001392-07-01',
#   'text': 'Dessverre insisterer de fortsatt på en unødvendig kompleksitet ( ”A Bite Out',
#   'label': 'Positive'},
#  {'sent_id': '001392-09-02',
#   'text': 'Når de nå fremstår som et helhetlig band har det meste av magien forsvunnet .',
#   'label': 'Negative'},
#  {'sent_id': '701363-01-01', 'text': 'Die Hard 5 :', 'label': 'Neutral'},
#  {'sent_id': '701363-01-02', 'text': 'Bedre enn bra nok', 'label': 'Positive'},
#  {'sent_id': '701363-02-01',
#   'text': 'Action-scenene bærer den femte " Die hard " -filmen , for det finnes verken engasjerende følsomhet eller elegante replikker mellom far og sønn McClane når de destruerer det som er igjen av Russland .',
#   'label': 'Positive'},
#  {'sent_id': '701363-02-02',
#   'text': 'Og deretter spøkelseskraftverket i Tsjernobyl .',
#   'label': 'Neutral'},
#  {'sent_id': '701363-03-01', 'text': 'A good day to die', 'label': 'Neutral'},
#  {'sent_id': '701363-04-01', 'text': 'USA.', 'label': 'Neutral'},
#  {'sent_id': '701363-04-02', 'text': '2013 .', 'label': 'Neutral'},
#  {'sent_id': '701363-04-03',
#   'text': '1 time , 37 minutter .',
#   'label': 'Neutral'},
#  {'sent_id': '701363-04-04', 'text': '15 år .', 'label': 'Neutral'},
#  {'sent_id': '701363-04-05',
#   'text': 'Regi : John Moore .',
#   'label': 'Neutral'},
#  {'sent_id': '701363-04-06', 'text': 'Med :', 'label': 'Neutral'},
#  {'sent_id': '701363-04-07',
#   'text': 'Bruce Willis , Jay Courtney , Sebasitan Koch , Yulia Snigir .',
#   'label': 'Neutral'},
#  {'sent_id': '701363-05-01',
#   'text': 'Er det sånn at du husker John McClane som en familiekjær steelcar-cowboy som kom dettende i hvit t-skjorte gjennom glassruter ?',
#   'label': 'Neutral'},
#  {'sent_id': '701363-05-02',
#   'text': 'Han gjør det igjen .',
#   'label': 'Neutral'},
#  {'sent_id': '701363-05-04',
#   'text': 'Jeg får av og til en forstyrrende følelse av å se Han Innante med Modern Warfare-tunge automatvåpen .',
#   'label': 'Negative'},
#  {'sent_id': '701363-05-05',
#   'text': 'Men det varer ikke så lenge .',
#   'label': 'Neutral'},
#  {'sent_id': '701363-05-06',
#   'text': 'Det er egentlig mest skallen som likner .',
#   'label': 'Neutral'},
#  {'sent_id': '701363-06-01',
#   'text': 'Russerne er stort sett proteinhjerna torpedoer med panser-torsoer , og de ser ut som analfabetiske statister fra en Dolph Lundgren-film .',
#   'label': 'Negative'},
#  {'sent_id': '701363-07-01',
#   'text': '« Die hard » var den selvutslettende omsorgens film , der Willis trengte inn i en kapra skyskraper med sitt uutslettelige sprangridning-utrop « yippi ki yay » .',
#   'label': 'Neutral'},
#  {'sent_id': '701363-07-03',
#   'text': 'Mannen var motoren .',
#   'label': 'Neutral'},
#  {'sent_id': '701363-07-04',
#   'text': '25 år seinere er det maskinen som er mester .',
#   'label': 'Neutral'},
#  {'sent_id': '701363-07-05',
#   'text': 'Allerede tidlig i filmen gjennomfører Moore et demolition derby gjennom Moskvas gater der Willis på sitt beste overkjører rushtrafikken i sin robuste Mercedes , mens bilmerker fra flere verdenshjørner kaster seg rundt i sanseløse turnoppvisninger og blir knust til resirkulasjonsmaterale som tyggegummi-Ladaer .',
#   'label': 'Positive'},
#  {'sent_id': '701363-07-06', 'text': 'Biler i spagaten .', 'label': 'Neutral'},
#  {'sent_id': '701363-07-07',
#   'text': 'Biler i pilates-stillinger .',
#   'label': 'Neutral'},
#  {'sent_id': '701363-08-02', 'text': 'Vi liker det .', 'label': 'Positive'},
#  {'sent_id': '701363-08-03',
#   'text': 'Skikkelig vond jernverk .',
#   'label': 'Negative'},
#  {'sent_id': '701363-08-04',
#   'text': 'Og særlig i naboskapet til rikelige eufemiseringer av det vi som barn kalte plaffing .',
#   'label': 'Neutral'},
#  {'sent_id': '701363-09-01',
#   'text': 'Handlingen starter som pysestoff .',
#   'label': 'Negative'},
#  {'sent_id': '701363-09-02',
#   'text': 'En fengsla dissident blir trua av en slags russisk Alec Baldwin som påstår at han eier alle i rettssalen , en påminnelse om det vidunderlige demokratiet som oppsto etter Gorbatsjov .',
#   'label': 'Positive'},
#  {'sent_id': '701363-09-03',
#   'text': 'På nattklubb der menn sikkert snakker respektløst til unge jenter , skyter McClanes sønn John en rik mann og blir arrestert .',
#   'label': 'Neutral'},
#  {'sent_id': '701363-09-04',
#   'text': 'Det gjør at den amerikanske politimannen må ta Aeroflot til Moskva for å redde gutten , men ting er ikke helt slik de ser ut .',
#   'label': 'Neutral'},
#  {'sent_id': '701363-09-05',
#   'text': 'Jeg røper ikke det .',
#   'label': 'Neutral'},
#  {'sent_id': '701363-09-06',
#   'text': 'Sønnen er sur og McClane litt defensiv , og for å være helt ærlig ønska jeg at de skulle komme bort fra hverandre ganske kvikt .',
#   'label': 'Negative'},
#  {'sent_id': '701363-10-01',
#   'text': 'Det er slutt på den tida da film-ungdom var spedlemma , men pene små fyrer .',
#   'label': 'Neutral'},
#  {'sent_id': '701363-10-02',
#   'text': 'Den unge McClane spilles av den unge australieren Jay Courtney fra tv-serien « Spartacus » , som er omtrent like høy som Willis , men er firkanta som en Minecraft-Steve .',
#   'label': 'Neutral'},
#  {'sent_id': '701363-10-03',
#   'text': 'Han har fjeset og humøret til Vinnie Jones og blir ikke tålelig før han omsider smiler .',
#   'label': 'Negative'},
#  {'sent_id': '701363-10-04',
#   'text': 'Far og sønn driver med kjerringaktig småkrangling , og samtalene kommer ikke til å skape forventninger om at replikk-forfatterne i USA er på bedringens vei .',
#   'label': 'Negative'},
#  {'sent_id': '701363-10-05',
#   'text': 'Både dattera til den antatte Komarov og unge McClane sutrer om at fedrene bare var på jobb hele tida .',
#   'label': 'Neutral'},
#  {'sent_id': '701363-10-06',
#   'text': 'I ei tid da halve USA går arbeidsledige klager denne filmen på de som faktisk utøver et yrke .',
#   'label': 'Negative'},
#  {'sent_id': '701363-10-07',
#   'text': 'Det er ikke bare sviskete Oprah-skitt , men politisk umusikalsk i tillegg .',
#   'label': 'Negative'},
#  {'sent_id': '701363-11-01',
#   'text': 'Filmen redder seg av gårde til det mest uventa stedet i verden .',
#   'label': 'Positive'},
#  {'sent_id': '701363-11-02',
#   'text': 'Skurkene ikler seg drakter som ville ha holdt infuensaen ute i en heftig stavangervinter og tar seg inn i spøkelsesverket i Tsjernobyl .',
#   'label': 'Neutral'},
#  {'sent_id': '701363-11-03',
#   'text': 'Dit kommer også McClane-familien i tynt sommertøy , og de gir seg ikke før skurker blir rotorkutta slik man ellers bare ser i Happy Wheels ( sjekk google ) .',
#   'label': 'Neutral'},
#  {'sent_id': '701363-12-01',
#   'text': 'Hvis folk ikke hadde snakket til hverandre i det hele tatt , ville denne filmen vært perfekt .',
#   'label': 'Negative'},
#  {'sent_id': '701363-12-02',
#   'text': 'Nå er den bare litt mer enn bra nok .',
#   'label': 'Negative'},
#  {'sent_id': '701363-13-01',
#   'text': 'Følg meg på Twitter :',
#   'label': 'Neutral'},
#  {'sent_id': '701363-13-02', 'text': '@arilabra', 'label': 'Neutral'},
#  {'sent_id': '500043-01-01', 'text': 'Gutta på tur', 'label': 'Neutral'},
#  {'sent_id': '500043-02-01',
#   'text': 'Velspilt komedie med alvorlige undertoner .',
#   'label': 'Positive'},
#  {'sent_id': '500043-03-01', 'text': 'Barndomsvenner .', 'label': 'Neutral'},
#  {'sent_id': '500043-03-02',
#   'text': 'Ordet smaker søtt , smaker sommer og saltvann og peanøtter .',
#   'label': 'Neutral'},
#  {'sent_id': '500043-03-03',
#   'text': 'Venner for livet , liksom .',
#   'label': 'Neutral'},
#  {'sent_id': '500043-03-04', 'text': 'Jadda .', 'label': 'Neutral'},
#  {'sent_id': '500043-03-05', 'text': 'Som om .', 'label': 'Neutral'},
#  {'sent_id': '500043-04-01',
#   'text': 'For plutselig er man andre steder , på hvert sitt sted , og det som var , er ikke lenger .',
#   'label': 'Neutral'},
#  {'sent_id': '500043-04-02', 'text': 'Så er spørsmålet :', 'label': 'Neutral'},
#  {'sent_id': '500043-04-03',
#   'text': 'Kan vennskapet fastholdes ?',
#   'label': 'Neutral'},
#  {'sent_id': '500043-04-04',
#   'text': 'Er det overhodet et vennskap lenger ?',
#   'label': 'Neutral'},
#  {'sent_id': '500043-04-05',
#   'text': 'Kjente vi hverandre , egentlig ?',
#   'label': 'Neutral'},
#  {'sent_id': '500043-05-01',
#   'text': 'Regidebutantene Julian Hagemann og Andreas Lisberg stuper inn i tematikken med fin sans for timing og typetegning .',
#   'label': 'Positive'},
#  {'sent_id': '500043-06-01',
#   'text': 'I en særdeles effektiv åpningssekvens settes både rammen og personene .',
#   'label': 'Positive'},
#  {'sent_id': '500043-07-01',
#   'text': 'Den bokstavelig og billedlig talt syklende studenten Jo ( Øivind Vogt ) , trygghetsnarkoman , konfliktsky og samboer med Ane .',
#   'label': 'Neutral'},
#  {'sent_id': '500043-09-01',
#   'text': 'Utagerende og rølpete Lasse ( Simen Aurstad Gjernes ) , som fortsatt bor hjemme hos mamma .',
#   'label': 'Negative'},
#  {'sent_id': '500043-10-01',
#   'text': 'Stoffern ( Benjamin Helstad ) som har begynt å slå seg opp som eiendomsmegler .',
#   'label': 'Neutral'},
#  {'sent_id': '500043-11-01',
#   'text': 'De er i tyveårene , og fortsatt der hvor man kan se hvordan de var som guttunger , da vennskapet mellom dem oppsto .',
#   'label': 'Neutral'},
#  {'sent_id': '500043-12-01',
#   'text': 'De treffes ikke så ofte lenger , men når de møtes , skal de gjøre de gamle greiene .',
#   'label': 'Neutral'},
#  {'sent_id': '500043-12-02',
#   'text': 'De har særlig en tradisjon å ta vare på : den årlige gutteturen på hytten til Jos foreldre .',
#   'label': 'Neutral'},
#  {'sent_id': '500043-13-01',
#   'text': 'Det blir en tur med flere nisser på lasset .',
#   'label': 'Neutral'},
#  {'sent_id': '500043-13-02',
#   'text': 'Anes bikkje , blant annet .',
#   'label': 'Neutral'},
#  {'sent_id': '500043-13-03',
#   'text': 'Andre , ikke spesielt velkomne folk .',
#   'label': 'Neutral'},
#  {'sent_id': '500043-13-04', 'text': 'Personlig drass .', 'label': 'Neutral'},
#  {'sent_id': '500043-14-01',
#   'text': 'Ting skjer som kaster nytt lys over både vennskapet og særlig en av guttene .',
#   'label': 'Neutral'},
#  {'sent_id': '500043-14-02',
#   'text': 'Han som kanskje trenger disse kompisene mest .',
#   'label': 'Neutral'},
#  {'sent_id': '500043-15-01',
#   'text': 'Hagemann og Lisberg etablerer raskt en frisk og lekende tone , full av autentiske dialoger og gjenkjennelige situasjoner .',
#   'label': 'Positive'},
#  {'sent_id': '500043-15-02',
#   'text': 'Her er mye å le av .',
#   'label': 'Positive'},
#  {'sent_id': '500043-15-03',
#   'text': 'Under det hele ligger et drag av noe som kanskje ikke er vemodig , det er snarere forgangent , og bidrar — til et visst punkt , til det komikkens skjær som ligger over disse kompisenes samvær og den maskuline hjelpeløsheten som etter hvert utspiller seg .',
#   'label': 'Neutral'},
#  {'sent_id': '500043-16-01',
#   'text': '« Å begrave en hund » er ingen ambisiøs eller dristig film , verken formmessig eller i måten temaet behandles på .',
#   'label': 'Negative'},
#  {'sent_id': '500043-16-02',
#   'text': 'Men den preges av en fin blanding munter ærlighet og vilje til å stå lenge nok i alvoret til at tøyset får en nødvendig klangbunn .',
#   'label': 'Positive'},
#  {'sent_id': '500043-17-01',
#   'text': 'Dessuten er den velspilt .',
#   'label': 'Positive'},
#  {'sent_id': '500043-17-02',
#   'text': 'Vogt og Gjernes har de mest takknemlige rollene , og fyller dem med stort nærvær og mye komisk talent .',
#   'label': 'Positive'},
#  {'sent_id': '500043-18-01',
#   'text': 'Små , innklippede videosnutter skaper god rytme og nærhet , og fungerer som en enkel , men fiffig tematisk kommentar .',
#   'label': 'Positive'},
#  {'sent_id': '500043-19-01',
#   'text': 'Filmen flyter ellers litt vimsete hit og dit , i tråd med både typer og vekslende stemningsleier .',
#   'label': 'Negative'},
#  {'sent_id': '500043-19-02',
#   'text': 'Slik sett har den en indre stringens , også der hvor manus synes å la en tråd henge løs av hensyn til dramaturgien .',
#   'label': 'Neutral'},
#  {'sent_id': '500043-20-01',
#   'text': 'Det skjer idet det oppstår en situasjon hvor en av guttene skal , og bør , dra fra øyen .',
#   'label': 'Neutral'},
#  {'sent_id': '500043-20-02',
#   'text': 'Han venter på en ferge , den viser seg å gå om flere timer .',
#   'label': 'Neutral'},
#  {'sent_id': '500043-20-03',
#   'text': 'Guttene disponerer egen båt .',
#   'label': 'Neutral'},
#  {'sent_id': '500043-20-04',
#   'text': 'Ingen tilbyr seg å skysse ham over .',
#   'label': 'Neutral'},
#  {'sent_id': '500043-20-05',
#   'text': 'Fergeturen forsvinner i det blå .',
#   'label': 'Neutral'},
#  {'sent_id': '500043-20-06',
#   'text': 'Ingen evner å ta grep om noe , ingen makter å si det som må sies .',
#   'label': 'Neutral'},
#  {'sent_id': '500043-21-01',
#   'text': 'Filmen borer ikke dypt nok til at det vonde kjennes virkelig vondt .',
#   'label': 'Negative'},
#  {'sent_id': '500043-21-02',
#   'text': 'I stedet for å svi der det skulle svi , tenderer den mer mot å hvile i en tilstand av trykkende taushet .',
#   'label': 'Neutral'},
#  {'sent_id': '500043-22-01',
#   'text': 'Er du enig med vår anmelder ?',
#   'label': 'Neutral'},
#  {'sent_id': '103580-01-01', 'text': 'Chris Rea :', 'label': 'Neutral'},
#  {'sent_id': '103580-01-02',
#   'text': '« The Blue Jukebox »',
#   'label': 'Neutral'},
#  {'sent_id': '103580-02-01', 'text': '( Edel )', 'label': 'Neutral'},
#  {'sent_id': '103580-03-01',
#   'text': 'Britiske Chris Rea fortsetter å dyrke bluesen sammen med sine franske musikere .',
#   'label': 'Neutral'},
#  {'sent_id': '103580-04-01',
#   'text': 'Chris Rea fortsetter blues-stilen som han vendte tilbake til på sin forrige plate « Stoney Road » .',
#   'label': 'Neutral'},
#  {'sent_id': '103580-04-02',
#   'text': 'Den nye platen , med 13 låter signert Rea , appellerer mer til blues- enn til popfansen .',
#   'label': 'Neutral'},
#  {'sent_id': '103580-04-05',
#   'text': "Best er han i « Baby don't cry » og « Somebody Say Amen » .",
#   'label': 'Positive'},
#  {'sent_id': '103580-04-06',
#   'text': 'Disse tre er platens beste sanger .',
#   'label': 'Positive'},
#  {'sent_id': '101277-01-01',
#   'text': 'Fin tone i stemmen',
#   'label': 'Positive'},
#  {'sent_id': '101277-02-01',
#   'text': 'Natnael « Natti » Asgedom kom inn i finalen som sistemann .',
#   'label': 'Neutral'},
#  {'sent_id': '101277-02-02',
#   'text': 'Han fremførte « Is This Love » av Bob Marley .',
#   'label': 'Neutral'},
#  {'sent_id': '101277-03-01',
#   'text': '- Det er ingen andre som koser seg så mye som deg , sa Kurt Nilsen og la til at han håper å se Natnael vidre .',
#   'label': 'Positive'},
#  {'sent_id': '101277-04-01',
#   'text': 'VG anmelder Morten Ståle Nilsens dom :',
#   'label': 'Neutral'},
#  {'sent_id': '101277-05-01',
#   'text': 'Natti setter selv fingeren på problemet :',
#   'label': 'Neutral'},
#  {'sent_id': '101277-05-02',
#   'text': 'Dette er en så velkjent sang at det er vanskelig å sette et nytt preg på den .',
#   'label': 'Neutral'},
#  {'sent_id': '101277-05-03',
#   'text': 'Men han prøver , og kommer nærmest i det andre verset .',
#   'label': 'Positive'},
#  {'sent_id': '101277-05-04',
#   'text': 'Det første blir forsiktig amatøraften , komplett med ubekveme « moves » .',
#   'label': 'Negative'},
#  {'sent_id': '002575-01-01', 'text': 'Teskjekjerringa', 'label': 'Neutral'},
#  {'sent_id': '002575-02-01',
#   'text': 'Mye snodig er nødt til å foregå bak kraniet til Vilde Tuv - et sted det godt kunne vært enklere å få slippe inn .',
#   'label': 'Negative'},
#  {'sent_id': '002575-03-01',
#   'text': '“ Naivt ” og “ drømmende ” er to eldgamle adjektivklisjeer i musikkskribentgloseboka .',
#   'label': 'Neutral'},
#  {'sent_id': '002575-03-02',
#   'text': 'Men det bergensbaserte enkvinnesbandet Vilde Tuv - hvor kun hun selv , baritongitar og basstromme står disponibelt - må være det nærmeste man kommer å få høre vuggesanger like håndgripelige som uhåndgripelige .',
#   'label': 'Neutral'},
#  {'sent_id': '002575-04-01',
#   'text': 'En del av grunnen ligger riktignok i den visuelle presentasjonen .',
#   'label': 'Neutral'},
#  {'sent_id': '002575-04-02',
#   'text': 'For bak sortkledde Tuv står det reist en halvmåneformet vegg , der kaleidoskopiske animasjoner ( signert kunstneren Birk Nygård ) av vindmøller , planeter , galakser og arkaiske symboler roterer “ hypnotisk ” på lag med musikken .',
#   'label': 'Neutral'},
#  {'sent_id': '002575-04-03',
#   'text': 'Passende nok flyter tidvis gitarplukking ut i periferien og skaper en subtil ambiens ikke ulikt universet til Seattle-musikeren Grouper .',
#   'label': 'Positive'},
#  {'sent_id': '002575-05-01',
#   'text': 'Barnligheten kommer imidlertid til uttrykk gjennom Tuvs tekster , som trolig vil kunne bli godt mottatt blant nysgjerrige krapyler på Miniøya .',
#   'label': 'Positive'},
#  {'sent_id': '002575-05-02',
#   'text': 'Der eksempelvis to av låtene er titulert “ Tyngdekraft ” og “ Cellevevet ” , tar en låt for seg at “ det er så mye som blir bedre når man blir stor ” , mens en annen - som visstnok flere andre - handler om den ene av de fem sansene .',
#   'label': 'Neutral'},
#  {'sent_id': '002575-06-01',
#   'text': '“ For det er fem sanser ?',
#   'label': 'Neutral'},
#  {'sent_id': '002575-06-02', 'text': 'Ja .', 'label': 'Neutral'},
#  {'sent_id': '002575-06-03',
#   'text': 'Mange av sangene handler egentlig om den sansen , ” forklarer hun distré , uten at hun eller strofene svarer på hvilken sans det er snakk om .',
#   'label': 'Neutral'},
#  {'sent_id': '002575-06-04',
#   'text': 'Hodet hennes virker med andre ord å være tusen steder på samme tid , et karaktertrekk man gjerne finner hos medbergenserne Fjorden Baby !-frontmann Sturle Kvilekval eller Christian Stockhaus fra all-nonsense-bandet Ungdomskulen .',
#   'label': 'Negative'},
#  {'sent_id': '002575-07-01', 'text': 'Snakker om sola :', 'label': 'Neutral'},
#  {'sent_id': '002575-07-02',
#   'text': 'Stockhaus og Vilde Tuv har sammen gitt ut en av de kuleste låtene så langt i år , i form av det übersløye elektropopsporet “ Svømmebasseng ” .',
#   'label': 'Positive'},
#  {'sent_id': '002575-07-04',
#   'text': 'Seilende under sitt eget skrudde flagg finnes det enkelte - men ikke nok - hjelpere til å finne veien helt inn i hennes verden .',
#   'label': 'Negative'},
#  {'sent_id': '111035-01-01', 'text': 'Spillanmeldelse :', 'label': 'Neutral'},
#  {'sent_id': '111035-01-02',
#   'text': '« Beyond Good & Evil HD »',
#   'label': 'Neutral'},
#  {'sent_id': '111035-02-01', 'text': '( VG Nett )', 'label': 'Neutral'},
#  {'sent_id': '111035-02-02',
#   'text': 'Ubisoft varter opp med et herlig gjensyn med en skammelig forbigått sjarmbombe av et spill .',
#   'label': 'Positive'},
#  {'sent_id': '111035-03-01',
#   'text': 'I 2003 forsøkte Ubisoft å skape en actionheltinne og en spillopplevelse som tilførte dybde i en spillverden og en genre hvor det mer umiddelbart tilfredsstillende dominerte .',
#   'label': 'Neutral'},
#  {'sent_id': '111035-04-01',
#   'text': '« Beyond Good & Evil » hadde en uredd fotojournalist i hovedrollen , og tematikken sneiet innom temaer som politisk undertrykkelse , slaveindustri , krig og revolusjon .',
#   'label': 'Neutral'},
#  {'sent_id': '111035-04-02',
#   'text': 'Pakket inn i en engasjerende sci-fi-historie og givende , « Ratchet & Clank » -lignende spillbarhet .',
#   'label': 'Positive'},
#  {'sent_id': '111035-05-02',
#   'text': 'Kanskje var det bare uheldige tilfeldigheter , kanskje ble spillet oppfattet som utilgjengelig og arty-farty eller kanskje var det noen år forut for sin tid .',
#   'label': 'Neutral'},
#  {'sent_id': '111035-06-01',
#   'text': 'I så fall er muligens tiden mer moden nå , syv og et halvt år senere .',
#   'label': 'Neutral'},
#  {'sent_id': '111035-06-02',
#   'text': 'Nå slippes spillet i HD-oppusset versjon på Xbox Live Marketplace og Playstation Network , og det er fremdeles snakk om en kruttsterk opplevelse .',
#   'label': 'Positive'},
#  {'sent_id': '111035-07-01',
#   'text': 'Det er riktignok umulig å ignorere at teknologien har tatt enorme skritt siden den gang , og at endel av designvalgene nå kan fremstå som litt vel gammeldagse .',
#   'label': 'Negative'},
#  {'sent_id': '111035-07-02',
#   'text': '« Beyond Good & Evil » var utvilsomt mer interessant satt opp mot spillmarkedet anno 2003 .',
#   'label': 'Negative'},
#  {'sent_id': '111035-08-01',
#   'text': 'Men det at det fremdeles er såpass givende , underholdende , engasjerende og spennende tyder på et bunnsolid designfundament .',
#   'label': 'Positive'},
#  {'sent_id': '111035-08-02',
#   'text': "Jeg liker dette universet , jeg er glad i Jade , Pey'j og det øvrige rollegalleriet , jeg koser meg med de givende oppdragene , jeg elsker tematikken og spillet i seg selv er veldig underholdende .",
#   'label': 'Positive'},
#  {'sent_id': '111035-09-01',
#   'text': 'Og det er tross alt vel så viktig som spillets spillhistoriske betydning .',
#   'label': 'Neutral'},
#  {'sent_id': '111035-10-01', 'text': 'PS :', 'label': 'Neutral'},
#  {'sent_id': '111035-10-02',
#   'text': 'Ute nå på Xbox Live Marketplace med en prislapp på 800 MS-poeng ( ca . 100 kroner ) .',
#   'label': 'Neutral'},
#  {'sent_id': '111035-10-03',
#   'text': 'Kommer på PSN i 2. kvartal .',
#   'label': 'Neutral'},
#  {'sent_id': '111035-11-01',
#   'text': 'BEYOND GOOD & EVIL HD Plattform : 360 Genre :',
#   'label': 'Neutral'},
#  {'sent_id': '111035-11-02',
#   'text': 'Action / eventyr Alder : 12 Utvikler :',
#   'label': 'Neutral'},
#  {'sent_id': '111035-11-03', 'text': 'Ubisoft Utgiver :', 'label': 'Neutral'},
#  {'sent_id': '111035-11-04', 'text': 'Ubisoft', 'label': 'Neutral'},
#  {'sent_id': '111035-11-05', 'text': 'Mer info', 'label': 'Neutral'},
#  {'sent_id': '106360-01-01',
#   'text': 'Enestående spill-magi',
#   'label': 'Positive'},
#  {'sent_id': '106360-02-01',
#   'text': 'Avlys alle avtaler og gled deg til nok et magisk , enormt , fantastisk og oppslukende « Zelda » -eventyr .',
#   'label': 'Positive'},
#  {'sent_id': '106360-03-01',
#   'text': 'Det finnes neppe noen mer elskede spillserier enn « Zelda » .',
#   'label': 'Positive'},
#  {'sent_id': '106360-03-02',
#   'text': 'Helt siden starten i 1986 har det ene « Zelda » -spillet etter det andre bergtatt eventyrlystne over hele verden .',
#   'label': 'Positive'},
#  {'sent_id': '106360-04-01',
#   'text': 'Og det er med stor glede og et fårete glis om munnen jeg kan konstatere at « The Legend of Zelda :',
#   'label': 'Positive'},
#  {'sent_id': '106360-04-02',
#   'text': 'Twilight Princess » ikke er noe unntak .',
#   'label': 'Neutral'},
#  {'sent_id': '106360-05-01',
#   'text': 'Det er i steden , i mine øyne , det kanskje beste spillet i serien til nå .',
#   'label': 'Positive'},
#  {'sent_id': '106360-05-02',
#   'text': 'Et fantastisk og episk eventyr som sakte men sikkert vokser og vokser helt til hjertet mitt holder på å eksplodere av pur lykke .',
#   'label': 'Positive'},
#  {'sent_id': '106360-06-01',
#   'text': 'Historien og oppbyggingen av spillet er velkjent .',
#   'label': 'Neutral'},
#  {'sent_id': '106360-06-02',
#   'text': 'Det starter særdeles rolig og avslappet i en søvnig og idyllisk liten landsby .',
#   'label': 'Neutral'},
#  {'sent_id': '106360-06-03',
#   'text': 'Men en ondskap er i ferd med å spre seg , og truer med å ta over fantasiverdenen spillet foregår i .',
#   'label': 'Neutral'},
#  {'sent_id': '106360-07-01',
#   'text': 'Dermed blir det opp til spilleren , som tar på seg rollen som den utvalgte frelseren Link , å redde både prinsesse Zelda , kongeriket Hyrule , vennene fra landsbyen og til syvende og sist hele verden .',
#   'label': 'Neutral'},
#  {'sent_id': '106360-08-01',
#   'text': 'Fra den spede starten legges den ene nye egenskapen og gjenstanden etter den andre til .',
#   'label': 'Neutral'},
#  {'sent_id': '106360-08-02',
#   'text': 'Stadig nye områder å utforske åpner seg opp .',
#   'label': 'Positive'},
#  {'sent_id': '106360-08-03',
#   'text': 'Historien tar plutselige og dramatiske vendinger .',
#   'label': 'Positive'},
#  {'sent_id': '106360-09-01',
#   'text': 'Og før du vet ordet av det , er du fullstendig oppslukt i det som skjer .',
#   'label': 'Positive'},
#  {'sent_id': '106360-09-02',
#   'text': 'Et magisk eventyr på flerfoldige titalls timer ligger foran deg .',
#   'label': 'Positive'},
#  {'sent_id': '106360-09-03',
#   'text': 'Det er bare å rydde plass i kalenderen med en gang - inntil « Twilight Princess » er fullført vil du neppe ha lyst til å gjøre noe annet .',
#   'label': 'Positive'},
#  {'sent_id': '106360-10-01',
#   'text': 'Alt sitter som et skudd .',
#   'label': 'Positive'},
#  {'sent_id': '106360-10-02',
#   'text': 'Fra den nydelige visuelle stilen til det herlige lydbildet , den nostalgiske musikken , slåssingen mot monstere , utforsking av grotter og andre områder og kreativ bruk av diverse hjelpemidler for å komme videre .',
#   'label': 'Positive'},
#  {'sent_id': '106360-10-03', 'text': 'For å nevne noe .', 'label': 'Neutral'},
#  {'sent_id': '106360-11-01',
#   'text': 'Det er i det hele tatt ikke langt mellom gåsehudøyeblikkene i dette spillet .',
#   'label': 'Positive'},
#  {'sent_id': '106360-11-02',
#   'text': 'Og det mener jeg bokstavelig .',
#   'label': 'Neutral'},
#  {'sent_id': '106360-11-03',
#   'text': '« Twilight Princess » er så bra at jeg får gåsehud bare av å tenke på det - en svært sjelden begivenhet for en som spiller såpass mye som meg .',
#   'label': 'Positive'},
#  {'sent_id': '106360-12-01',
#   'text': 'Wii-håndkontrolleren er dessuten utnyttet på en eksemplarisk måte .',
#   'label': 'Positive'},
#  {'sent_id': '106360-12-02',
#   'text': 'Du bruker den til å sikte med pil og bue , til å svinge sverd , til å fiske og til mye annet .',
#   'label': 'Neutral'},
#  {'sent_id': '106360-13-01',
#   'text': 'Etter en tilvenningsperiode på rundt en halvtime , føles det både selvfølgelig og naturlig .',
#   'label': 'Positive'},
#  {'sent_id': '106360-14-01',
#   'text': 'Nintendos nye spillkonsoll kunne i det hele tatt ikke ha bedt om noe bedre lanseringsspill , selv om Gamecube-eiere muligens ikke vil gå glipp av mye dersom de går for Gamecube-versjonen 15. desember .',
#   'label': 'Positive'},
#  {'sent_id': '106360-15-01',
#   'text': 'For det er nok spillet i seg selv - og ikke Wii-håndkontrolleren - som gjør « The Legend of Zelda :',
#   'label': 'Positive'},
#  {'sent_id': '106360-15-02',
#   'text': 'Twilight Princess » til et av tidenes beste konsollspill .',
#   'label': 'Positive'},
#  {'sent_id': '106360-16-01',
#   'text': 'Den dypt elskede Zelda-serien får snart et nytt kapittel med Wii-spillet « The Legend of Zelda :',
#   'label': 'Neutral'},
#  {'sent_id': '106360-16-02',
#   'text': 'Twilight Princess » .',
#   'label': 'Neutral'},
#  {'sent_id': '106360-16-03',
#   'text': 'Slik blir spillet .',
#   'label': 'Neutral'},
#  {'sent_id': '101554-01-01', 'text': 'Götze :', 'label': 'Neutral'},
#  {'sent_id': '101554-01-02',
#   'text': '- Skylder kjæresten min mye',
#   'label': 'Neutral'},
#  {'sent_id': '101554-02-01',
#   'text': 'RIO DE JANIERO / OSLO ( VG ) ( Tyskland - Argentina 1 - 0 ) Mario Götze ( 22 ) kom inn fra benken og gjorde Tyskland til verdensmestere på egen hånd med en fantastisk volley i ekstraomgangene .',
#   'label': 'Neutral'},
#  {'sent_id': '101554-03-01',
#   'text': '- Det er utrolig hvordan vi alle har jobbet for dette .',
#   'label': 'Neutral'},
#  {'sent_id': '101554-03-02',
#   'text': 'Dette er en utrolig følelse , jublet kaptein Philipp Lahm etter sin første VM-triumf i karrieren .',
#   'label': 'Positive'},
#  {'sent_id': '101554-04-01',
#   'text': 'Avgjørelsen på VM-finalen 2014 falt så sent som i det 112. minutt da innbytter André Schürrles innlegg fra venstresiden fant en annen innbytter inne i Argentina-boksen .',
#   'label': 'Neutral'},
#  {'sent_id': '101554-05-01',
#   'text': 'Mario Götze erstattet tidenes mestscorende i VM-historien , Miroslav Klose , etter 88 minutter .',
#   'label': 'Neutral'},
#  {'sent_id': '101554-05-02',
#   'text': 'Da innlegget kom svarte Bayern München-spilleren med en scoring på ekte goalgettervis .',
#   'label': 'Positive'},
#  {'sent_id': '101554-07-01',
#   'text': 'Matchvinneren møtte pressen i spillerutstyr og sandaler på pressesenteret i Rio , etter at laget hadde fått summet seg i garderoben .',
#   'label': 'Neutral'},
#  {'sent_id': '101554-08-01',
#   'text': '- Det var en utrolig følelse .',
#   'label': 'Positive'},
#  {'sent_id': '101554-08-02',
#   'text': 'Jeg vet ikke hva som skjedde , jeg bare skjøt .',
#   'label': 'Neutral'},
#  {'sent_id': '101554-08-03',
#   'text': 'Det som skjer etter kampen , å ha denne festen med dette laget , det er en drøm som går i oppfyllelse .',
#   'label': 'Positive'},
#  {'sent_id': '101554-08-04',
#   'text': 'Jeg vet nesten ikke hva jeg føler , dette er helt sensasjonelt , sa Götze .',
#   'label': 'Positive'},
#  {'sent_id': '101554-09-01',
#   'text': '- Det har ikke vært et enkelt år for meg og ikke en enkel turnering .',
#   'label': 'Negative'},
#  {'sent_id': '101554-09-02',
#   'text': 'Jeg skylder mye til familien og kjæresten min , som har trodd på meg .',
#   'label': 'Neutral'},
#  {'sent_id': '101554-09-03',
#   'text': 'Jeg er veldig glad for at vi har vunnet dette .',
#   'label': 'Positive'},
#  {'sent_id': '101554-09-04',
#   'text': 'Jeg har fortsatt trent med laget , og hver eneste spiller fortjener å bli nevnt .',
#   'label': 'Positive'},
#  {'sent_id': '101554-09-05',
#   'text': 'Vi har fortjent dette trofeet .',
#   'label': 'Positive'},
#  {'sent_id': '101554-10-01',
#   'text': 'Mario Götzes kjæreste er den tyske modellen Ann-Kathrin Brömmel , som blant annet har figurert i spaltene hos den tyske utgaven av herremagasinet GQ.',
#   'label': 'Neutral'},
#  {'sent_id': '101554-11-01', 'text': '- Beskriver laget', 'label': 'Neutral'},
#  {'sent_id': '101554-12-01',
#   'text': '- Måten vi scorer målet på beskriver dette laget , sier Thomas Müller , Tysklands toppscorer i mesterskapet med fem mål .',
#   'label': 'Positive'},
#  {'sent_id': '101554-13-01',
#   'text': '- Vi har kjempet så hardt for dette , jeg har ikke ord .',
#   'label': 'Neutral'},
#  {'sent_id': '101554-14-01',
#   'text': 'Nå hylles de nybakte VM-vinnerne av tidligere tyske helter .',
#   'label': 'Positive'},
#  {'sent_id': '101554-15-01',
#   'text': '- Et sensasjonelt mål av Götze !',
#   'label': 'Positive'},
#  {'sent_id': '101554-15-02',
#   'text': 'Disse ungdommene fortjente å bli verdensmestere .',
#   'label': 'Positive'},
#  {'sent_id': '101554-15-03',
#   'text': 'De er våre verdige etterfølgere , sier Andreas Brehme til den tyske avisen Bild .',
#   'label': 'Positive'},
#  {'sent_id': '101554-16-01',
#   'text': 'Brehme ble matchvinner fra straffemerket sist gang Tyskland vant en VM-finale - mot nettopp Argentina i Italia i 1990',
#   'label': 'Neutral'},
#  {'sent_id': '101554-17-01',
#   'text': 'Dermed gjorde Tyskland akkurat som de gjorde mot Argentina i VM-finalen i 1990 :',
#   'label': 'Neutral'},
#  {'sent_id': '101554-17-02', 'text': 'De vant 1 - 0 .', 'label': 'Neutral'},
#  {'sent_id': '101554-17-03',
#   'text': 'Den gang etter scoring av Andreas Brehme .',
#   'label': 'Neutral'},
#  {'sent_id': '101554-17-04',
#   'text': 'Og i 2014 var det altså unggutten Mario Götze som ble den store helten , til tross for at han ikke har vært fast på det tyske laget de siste VM-kampene .',
#   'label': 'Neutral'},
#  {'sent_id': '101554-18-01',
#   'text': 'Det var en relativt nedtonet og lavmælt Argentinsk trener som møtte pressen etter nederlaget i finalen :',
#   'label': 'Neutral'},
#  {'sent_id': '101554-19-02',
#   'text': 'Kampen hadde sine opp-og-ned-situasjoner .',
#   'label': 'Neutral'},
#  {'sent_id': '101554-19-03',
#   'text': 'Vi hadde klare sjanser , sa Alejandro Sabella , for anledningen i skjorte og slips .',
#   'label': 'Neutral'},
#  {'sent_id': '101554-20-01',
#   'text': 'Argentina-treneren nevnte også det faktum at Argentina-spillerne hadde flere minutter i beina før kampen .',
#   'label': 'Neutral'},
#  {'sent_id': '101554-21-01',
#   'text': '- Vi hadde spilt to ekstraomganger og vi hadde en dag mindre hvile .',
#   'label': 'Positive'},
#  {'sent_id': '101554-21-02',
#   'text': 'Generelt er jeg veldig stolt .',
#   'label': 'Positive'},
#  {'sent_id': '101554-21-03',
#   'text': 'Guttene har spilt en ekstraordinær VM-turnering .',
#   'label': 'Positive'},
#  {'sent_id': '101554-21-04',
#   'text': 'De har lagt igjen alt de har på banen .',
#   'label': 'Positive'},
#  {'sent_id': '101554-22-01',
#   'text': 'Sabella tok Argentina nærmere VM-gull enn de har vært på mange år .',
#   'label': 'Neutral'},
#  {'sent_id': '101554-22-02',
#   'text': 'Allikevel fikk han spørsmål om han sitter trygt i trenerstolen .',
#   'label': 'Neutral'},
#  {'sent_id': '101554-23-01',
#   'text': '- Dere må bli lei av at jeg stadig gjentar dette .',
#   'label': 'Neutral'},
#  {'sent_id': '101554-23-02',
#   'text': 'Jeg kan ikke snakke om fremtiden .',
#   'label': 'Neutral'},
#  {'sent_id': '101554-23-03',
#   'text': 'Fremtiden min nå er å være med spillerne , støtteapparatet , familien min .',
#   'label': 'Neutral'},
#  {'sent_id': '101554-23-04',
#   'text': 'Så jeg vet ikke hva jeg skal si , svarte Sabella .',
#   'label': 'Neutral'},
#  {'sent_id': '101554-24-01',
#   'text': '- Når du kommer til finalen vil du vinne , men jeg sitter også igjen med en følelse av være tilfredsstilt , av å ha gitt alt , avsluttet Sabella før han forlot salen til applaus fra flere av journalistene .',
#   'label': 'Neutral'},
#  {'sent_id': '101554-25-01', 'text': 'Veteranene gråt', 'label': 'Neutral'},
#  {'sent_id': '101554-26-01',
#   'text': 'Tyskland har hatt et fantastisk mesterskap og de fleste så på « Die Mannschaft » som den store favoritten til VM-gullet etter den vanvittige 7-1-seieren over Brasil i semifinalen .',
#   'label': 'Positive'},
#  {'sent_id': '101554-26-02',
#   'text': 'Den spådommen ble ikke gjort til skam .',
#   'label': 'Positive'},
#  {'sent_id': '101554-27-01',
#   'text': 'Götze gjorde også at flere av de aldrende Tyskland-spillerne endelig fikk løfte VM-trofeet før karriereslutt .',
#   'label': 'Neutral'},
#  {'sent_id': '101554-27-02',
#   'text': 'Etter kampen var det blant andre veteranene Bastian Schweinsteiger og Thomas Müller som gråt mest over den enormt etterlengtede triumfen .',
#   'label': 'Neutral'},
#  {'sent_id': '101554-28-01',
#   'text': 'Argentina klarte aldri å svare på Götzes volley i sluttminuttene .',
#   'label': 'Neutral'},
#  {'sent_id': '101554-28-02',
#   'text': 'Ekspertene i VGs VM-studio mente perlemålet var en av tidenes vakreste scoringer som har avgjort et VM .',
#   'label': 'Positive'},
#  {'sent_id': '101554-29-01',
#   'text': '- Det er så perfekt utført !',
#   'label': 'Positive'},
#  {'sent_id': '101554-29-02',
#   'text': 'Han legger den perfekt til rette med kassa , og smeller den i lengste hjørne , sier talentspeider Stig Thorbjørnsen .',
#   'label': 'Positive'},
#  {'sent_id': '101554-30-01',
#   'text': 'Dermed kunne både Tyskland-spillerne og den tyske fansen juble for trofeet de har vært nær ved å kapre flere ganger de siste tyve årene .',
#   'label': 'Neutral'},
#  {'sent_id': '101554-31-01',
#   'text': '- Det ble tøffere enn forventet .',
#   'label': 'Positive'},
#  {'sent_id': '101554-31-02',
#   'text': 'En åpen kamp , sånn man ønsker at en slik stor finale skal være .',
#   'label': 'Positive'},
#  {'sent_id': '101554-31-03',
#   'text': 'Det hadde ingen betydning så lenge kreftene holdt , men vi må huske at argentinerne hadde én dag mindre pause og måtte ut i ekstraomganger i semifinalen , sier den tyske legenden Franz Beckenbauer til Bild .',
#   'label': 'Neutral'},
#  {'sent_id': '101554-32-01',
#   'text': 'Mens tyskerne feiret og gråt om hverandre , satte Argentina-stjernen Lionel Messi seg på gresset med hodet mellom knærne .',
#   'label': 'Neutral'},
#  {'sent_id': '101554-32-02',
#   'text': 'Han lyktes ikke med å ta sitt Argentina til VM-gull , som Maradona gjorde i 1986 .',
#   'label': 'Neutral'},
#  {'sent_id': '101554-32-03',
#   'text': 'Real Madrid-stjernen Ángel Di Maria ble ikke klar til søndagens VM-finale , og virker helt sønderknust ute på gressmatta sammen med lagkameratene etter kampslutt .',
#   'label': 'Neutral'},
#  {'sent_id': '101554-33-01',
#   'text': 'Lionel Messi mottok Gullballen , prisen for VMs beste spiller , etter kampslutt , men Argentinas store stjerne rikket ikke på smilebåndet da han gikk opp podiet og mottok prisen fra FIFA-president Sepp Blatter .',
#   'label': 'Positive'},
#  {'sent_id': '101554-34-01',
#   'text': 'En som derimot smilte fra øret til øret var Tyskland-keeper Manuel Neuer , som både kunne innkassere VM-gullet og Gullhansken , prisen for mesterskapets beste keeper .',
#   'label': 'Positive'},
#  {'sent_id': '101554-35-01', 'text': 'Argentina nære', 'label': 'Neutral'},
#  {'sent_id': '101554-36-01',
#   'text': 'Kampen var målløs helt frem til Götzes matchvinner-scoringen i det 112. minutt , men hadde nok av målsjanser .',
#   'label': 'Neutral'},
#  {'sent_id': '101554-36-02',
#   'text': 'Både Argentina og Tyskland gikk ut i hundre i ekstraomgangene foran de 74738 tilskuerne på Maracana stadion .',
#   'label': 'Neutral'},
#  {'sent_id': '101554-36-03',
#   'text': 'Først stoppet keeper Sergio Romero et André Schürrle-skudd på mesterlig vis fra fem-seks meter .',
#   'label': 'Positive'},
#  {'sent_id': '101554-36-04',
#   'text': 'Deretter beinet Lionel Messi fremover på en kontring , men Argentina-stjernen ble hindret rett før han var på vei gjennom mot mål .',
#   'label': 'Neutral'},
#  {'sent_id': '101554-37-01',
#   'text': 'Messi spilte en stor første omgang , men maktet ikke å finne lukene i det tyske forsvaret i løpet av kampen .',
#   'label': 'Neutral'},
#  {'sent_id': '101554-38-01',
#   'text': 'Innbytter Rodrigo Palacio var svært , svært nær ved å sende Argentina i en forløsende ledelse etter 97 minutter , men Inter-spissens lobb ble altfor upresis i en duell med keeper Manuel Neuer rundt åtte meter fra mål .',
#   'label': 'Neutral'},
#  {'sent_id': '101554-38-02',
#   'text': 'Det var det nærmeste noen av lagene kom i den første ekstraomgangen .',
#   'label': 'Neutral'},
#  {'sent_id': '101554-39-01',
#   'text': 'Higuaíns hode mot Neuers kne',
#   'label': 'Neutral'},
#  {'sent_id': '101554-40-01',
#   'text': 'Den andre omgangen bød ikke på fantastisk angrepsspill fra noen av lagene , og det som satte mest støkk i publikum var en stygg episode mellom Gonzalo Higuaín og Manuel Neuer .',
#   'label': 'Negative'},
#  {'sent_id': '101554-40-02',
#   'text': 'Argentina-spissens hode frontkolliderte med kneet til Neuer da han forsøkte å rekke en gjennombruddspasning fra Pablo Zabaleta .',
#   'label': 'Neutral'},
#  {'sent_id': '101554-41-01',
#   'text': 'Dommer Nicola Rizzoli dømte frisparket mot Higuáin , som heldigvis kom seg på beina etter smellen .',
#   'label': 'Neutral'},
#  {'sent_id': '101554-42-01',
#   'text': '- Det er livsfarlig spill av Neuer , sa fotballekspert Bernt Hulsker i VGs VM-studio .',
#   'label': 'Negative'},
#  {'sent_id': '101554-43-01',
#   'text': 'Sammenstøtet preget Higuaín såpass mye at han ble byttet ut etter 77 minutter .',
#   'label': 'Neutral'},
#  {'sent_id': '101554-44-01',
#   'text': 'Tyskland hadde overtaket i siste halvdel av den andre omgangen , men maktet ikke å produsere de virkelig store mulighetene .',
#   'label': 'Neutral'},
#  {'sent_id': '101554-45-01',
#   'text': 'Enorm Argentina-sjanse',
# ...
#   'label': 'Neutral'},
#  {'sent_id': '101014-09-01',
#   'text': 'MORTEN STÅLE NILSEN',
#   'label': 'Neutral'},
#  {'sent_id': '303566-01-01', 'text': 'Savnet :', 'label': 'Neutral'},
#  {'sent_id': '303566-01-02',
#   'text': 'Spenstig TV om hus og hjem',
#   'label': 'Positive'},
#  {'sent_id': '303566-02-01',
#   'text': 'TVNorge kårer Norges flotteste hjem med Bonytt-TV .',
#   'label': 'Neutral'},
#  {'sent_id': '303566-03-01', 'text': 'TV :', 'label': 'Neutral'},
#  {'sent_id': '303566-03-02',
#   'text': 'Vi nordmenn er gale etter bolig , enten det handler om kjøp og salg , interiør eller oppussing .',
#   'label': 'Positive'},
#  {'sent_id': '303566-04-01',
#   'text': "Den voldsomme interessen har ikke gått TV-produsentene hus forbi , og de tradisjonelle interiørprogrammene har etter hvert fått selskap av et bredt utvalg boligrelaterte konsepter — fra « Sinnasnekker'n » og « Skjulte skatter » til « Boligjakten » og « Solgt ! » .",
#   'label': 'Neutral'},
#  {'sent_id': '303566-05-01',
#   'text': 'Nå skal TVNorge og programleder Birgitte Lund Nakken etter to sesonger med « Herlige hjem » kåre landets « mest inspirerende og personlige hjem » .',
#   'label': 'Neutral'},
#  {'sent_id': '303566-05-02',
#   'text': 'I hvert program presenteres tre boliger og menneskene som bor der , før en eksperttrio får se seg om og til slutt stemmer fram en finalist .',
#   'label': 'Neutral'},
#  {'sent_id': '303566-05-03',
#   'text': 'Hvem som ender opp med tittelen « Årets hjem » og 100 000 kroner , avgjøres av seerne i finaleprogrammet .',
#   'label': 'Neutral'},
#  {'sent_id': '303566-06-01',
#   'text': 'Mer folkelig enn trendy',
#   'label': 'Neutral'},
#  {'sent_id': '303566-06-02',
#   'text': 'Det blir fort tydelig at det ikke er D2-segmentet som skal fenges av « Årets hjem » .',
#   'label': 'Neutral'},
#  {'sent_id': '303566-06-03',
#   'text': 'Selv om både dommerpanelets arkitekt Knut Hovland og tidligere « Norway Says » -designer Andreas Engesvik representerer en trendriktig , ren smak , har interiørdesigner Maria Erlingsdotter Neerland rollen som gispende begeistret tilhenger av det sjarmerende , hjemmekoselige , prangende og detaljrike .',
#   'label': 'Neutral'},
#  {'sent_id': '303566-07-01',
#   'text': 'Og det er det siste vi får mest av i første program , enten det er i sveitservillaen restaurert med tidsriktig , tungt 1800-tallsinteriør , eller det jordnære 30-tallshuset med egentegnet , moderne tilbygg .',
#   'label': 'Neutral'},
#  {'sent_id': '303566-08-01',
#   'text': 'Langsomt sveipende vidvinkelbilder viser lyse , mennesketomme og pertenlig ryddige rom og eksteriører , som hentet rett ut av en boligannonse eller et boligmagasin .',
#   'label': 'Neutral'},
#  {'sent_id': '303566-09-01',
#   'text': 'I avslappet tempo slår Nakken av en prat med eierne om hva de liker med huset sitt , før ekspertene like avslappet rusler rundt og diskuterer seg imellom .',
#   'label': 'Neutral'},
#  {'sent_id': '303566-10-01', 'text': 'Strømlinjeformet', 'label': 'Neutral'},
#  {'sent_id': '303566-10-02',
#   'text': '« Årets hjem » er nemlig utelukkende basert på opptak på location , som regel med en reportasjetilnærming der « det som skjer , får skje » .',
#   'label': 'Neutral'},
#  {'sent_id': '303566-11-01',
#   'text': 'Men historikken i både bygninger og interiør pirrer nysgjerrigheten langt mer enn programmet utnytter .',
#   'label': 'Negative'},
#  {'sent_id': '303566-11-02',
#   'text': 'Hva med litt infografikk om kjennetegn for en periode eller stilart ?',
#   'label': 'Negative'},
#  {'sent_id': '303566-11-03',
#   'text': 'Eller intervjuer med ekspertene der de får fortelle om det ?',
#   'label': 'Negative'},
#  {'sent_id': '303566-11-04',
#   'text': 'Det hadde gjort underverker , ikke minst for tempoet .',
#   'label': 'Negative'},
#  {'sent_id': '303566-13-01',
#   'text': 'Og det er klart , for et program som skal kåre « hele Norges... » er det kanskje riktig å gå for det strømlinjeformede .',
#   'label': 'Neutral'},
#  {'sent_id': '303566-13-02',
#   'text': 'Men det hadde vært befriende å en gang få se et boligprogram som så og hørtes litt mer ut som SVTs « Kobra » og litt mindre som tv-versjonen av Bonytt .',
#   'label': 'Negative'},
#  {'sent_id': '600374-01-01',
#   'text': 'Meget franske betroelser',
#   'label': 'Neutral'},
#  {'sent_id': '600374-02-01',
#   'text': 'Vincent , i førtiårene , blivende far for første gang , inviteres til middag hjemme hos sin søster og svoger , pluss en barndomsvenn .',
#   'label': 'Neutral'},
#  {'sent_id': '600374-02-02',
#   'text': 'Mens de venter på hans betydelig yngre kone , bombarderes han med spørsmål .',
#   'label': 'Neutral'},
#  {'sent_id': '600374-02-03',
#   'text': 'Blant annet stilles spørsmålet :',
#   'label': 'Neutral'},
#  {'sent_id': '600374-02-04',
#   'text': 'Hva skal barnet hete ?',
#   'label': 'Neutral'},
#  {'sent_id': '600374-02-05',
#   'text': 'Svaret hans reiser en vegg av vantro og sinne .',
#   'label': 'Neutral'},
#  {'sent_id': '600374-03-01',
#   'text': 'Det er utgangspunktet for en aften der mange fortielser blir brakt fram i lyset , ferske avsløringer skaper hysteri , sinne og sjokk , unnvikelser , bløff og små og store , hvite og sorte løgner avsløres .',
#   'label': 'Neutral'},
#  {'sent_id': '600374-04-02', 'text': 'For , nemlig :', 'label': 'Neutral'},
#  {'sent_id': '600374-04-03',
#   'text': 'Dette er meget fransk , med høy temperatur og høye stemmer omkring bagateller , med mye brusing av fjæra for trivialiteter , med vin og kyss på kinnet og gestikulasjoner en i Norge bare begir seg hen til når en vepsesverm angriper .',
#   'label': 'Neutral'},
#  {'sent_id': '600374-04-04',
#   'text': 'Det er også en film som nesten føles privat , som om filmskaperne har satt et skjult kamera og skjulte mikrofoner i en leilighet hvor mennesker av velberget , standard middelklasse befinner seg .',
#   'label': 'Neutral'},
#  {'sent_id': '600374-05-01',
#   'text': 'Men i all denne praten om ditt og datt og mangt og mye og litt til , finnes det også befriende avsløringer , avsløringer som på sikt nok gjør klimaet mellom de seks friere .',
#   'label': 'Positive'},
#  {'sent_id': '600374-05-03',
#   'text': 'Det er som å se et dyrt smykke i en butikk for billige suvenirer .',
#   'label': 'Positive'},
#  {'sent_id': '600374-06-01',
#   'text': 'Regien er meget nær , tett på , vi er i stuen hele tiden , men kamerat beveger seg hele tiden smidig , det blir aldri stivt , aldri .',
#   'label': 'Positive'},
#  {'sent_id': '600374-06-02',
#   'text': 'Det samme kan en i høy grad anføre om skuespillerne .',
#   'label': 'Positive'},
#  {'sent_id': '600374-07-01', 'text': 'Igjen :', 'label': 'Neutral'},
#  {'sent_id': '200937-01-01', 'text': 'Second Sight', 'label': 'Neutral'},
#  {'sent_id': '200937-02-01',
#   'text': 'Sniking , skyting og psykiske krefter står på dagsordenen i Second Sight .',
#   'label': 'Neutral'},
#  {'sent_id': '200937-02-02',
#   'text': 'Klarer du å hjelpe John Vattic ut av mentalsykehuset ?',
#   'label': 'Neutral'},
#  {'sent_id': '200937-03-01',
#   'text': 'Det er alltid hyggelig å oppdage de litt mindre omtalte spillene , som kanskje drukner i den overveldende massen av høybudsjett-spill som dominerer salgslistene .',
#   'label': 'Positive'},
#  {'sent_id': '200937-03-02',
#   'text': 'Second Sight er en slik gledelig overraskelse , en parapsykologisk thriller som gir deg kontroll over krefter du ikke ante du hadde .',
#   'label': 'Positive'},
#  {'sent_id': '200937-04-01', 'text': 'LES OGSÅ :', 'label': 'Neutral'},
#  {'sent_id': '200937-05-01',
#   'text': 'Historien bak Second Sight er hentet rett fra en lang rekke filmer og bøker , og sånn sett ikke spesielt original .',
#   'label': 'Negative'},
#  {'sent_id': '200937-05-02',
#   'text': 'Men den blir likevel fortalt på en spennende og gripende måte , og det er vanskelig å legge spillet fra seg nettopp fordi du vil så gjerne få vite hva som egentlig foregår .',
#   'label': 'Positive'},
#  {'sent_id': '200937-06-01', 'text': 'Hvem er jeg ?', 'label': 'Neutral'},
#  {'sent_id': '200937-07-01',
#   'text': 'Du spiller som John Vattic , en tildligere forsker som en dag våkner i et militært sykehus , uten hukommelse og i elendig forfatning .',
#   'label': 'Neutral'},
#  {'sent_id': '200937-07-02',
#   'text': 'Til hans store sjokk oppdager han at han tydeligvis har overnaturlige krefter , som lar han flytte på gjenstander , bli usynlig , gå ut av sin egen kropp eller helbrede seg selv .',
#   'label': 'Neutral'},
#  {'sent_id': '200937-07-03',
#   'text': 'I tillegg ser det ut til at sykehusets ansatte ikke er overbegeistret for at han har kommet seg løs , og setter inn store styrker for å stanse ham .',
#   'label': 'Neutral'},
#  {'sent_id': '200937-07-04',
#   'text': 'Målet for John Vattic blir altså å komme seg i frihet , og samtidig finne ut hva som har skjedd med ham og hvem han egentlig er .',
#   'label': 'Neutral'},
#  {'sent_id': '200937-08-01',
#   'text': 'Spillet foregår i to tidsperioder .',
#   'label': 'Neutral'},
#  {'sent_id': '200937-08-02',
#   'text': 'I nåtiden hjelper du John å komme seg vekk fra sykehuset samtidig som du leter etter svar , mens noen av brettene er tilbakeblikk på Johns tidligere forskerkarriere , og hvordan han ble involvert i en strengt hemmelig , militær operasjon .',
#   'label': 'Neutral'},
#  {'sent_id': '200937-08-03',
#   'text': 'Her er det mye konspirasjoner , ulovlige eksperimenter og andre hemmeligheter , og vi følger spent med .',
#   'label': 'Positive'},
#  {'sent_id': '200937-09-01',
#   'text': 'Second Sight prøver å kombinere flere sjangere under ett tak , og får det faktisk til .',
#   'label': 'Positive'},
#  {'sent_id': '200937-09-02',
#   'text': 'Det er flere måter å forsere et brett på , du kan snike i Sam Fisher-stil , dra frem de største våpnene , eller benytte deg av dine psykiske evner .',
#   'label': 'Neutral'},
#  {'sent_id': '200937-09-03',
#   'text': 'Snikeaspektet er langt fra så avansert som i Splinter Cell eller Metal Gear Solid , men fungerer likevel , men det er klart gøyest å løfte en søppelkasse med tankekraften og sende den rett i hodet på en patruljerende vakt .',
#   'label': 'Positive'},
#  {'sent_id': '200937-09-04',
#   'text': 'Tilbakeblikk-brettene er imidlertid en del kjedeligere , da de for det meste dreier seg om ren skyting .',
#   'label': 'Negative'},
#  {'sent_id': '200937-10-01', 'text': 'Ujevn kontroll', 'label': 'Negative'},
#  {'sent_id': '200937-11-01',
#   'text': 'Vi ble litt plaget av kontrollsystemet , som er litt rotete når det gjelder å låse seg inn på mål .',
#   'label': 'Negative'},
#  {'sent_id': '200937-11-02',
#   'text': 'Når en soldat løper mot deg og du forsøker å bli kvitt ham raskest mulig , hjelper det lite at siktet låser seg konstant inn på et askebeger ved siden av , ikke på den tungt bevæpnede fienden .',
#   'label': 'Negative'},
#  {'sent_id': '200937-11-03',
#   'text': 'Men heldigvis er ikke spillet blant de vanskeligste vi har spilt , spesielt fordi du til en hver tid kan helbrede deg selv med dine evner .',
#   'label': 'Positive'},
#  {'sent_id': '200937-12-01',
#   'text': 'Så lenge du unngår å skyte for mye og heller fokuserer på tankeevnene og sniking , er Second Sight blant de mest nervepirrende titlene på en god stund .',
#   'label': 'Positive'},
#  {'sent_id': '200937-12-02',
#   'text': 'Og historien griper tak i deg , takket være den glimrende måten den blir fortalt på .',
#   'label': 'Positive'},
#  {'sent_id': '200937-12-03',
#   'text': 'Du vil gjerne at John skal finne ut hva som foregår , og du blir selv engasjert og nysgjerrig , og det er jo en god ting .',
#   'label': 'Positive'},
#  {'sent_id': '200937-12-05',
#   'text': 'Har du spilt TimeSplitters , kan du selv tenke deg den grafiske stilen , da utvikleren er den samme .',
#   'label': 'Neutral'},
#  {'sent_id': '200937-12-06',
#   'text': 'Vi liker spesielt godt utseendet på figurene , med sine noe spesielle ansiktstrekk og detaljerte animasjoner .',
#   'label': 'Positive'},
#  {'sent_id': '200937-13-01',
#   'text': 'Vi må også skryte av musikken , som skaper utrolig god stemning gjennom hele spillet .',
#   'label': 'Positive'},
#  {'sent_id': '200937-14-02',
#   'text': 'Vi anbefaler det til alle som gleder seg til nye Splinter Cell , men klarer ikke å vente et par måneder til , samt alle de som er opptatt av overnaturlige evner .',
#   'label': 'Positive'},
#  {'sent_id': '200937-14-03',
#   'text': 'Du vil nok bli gledelig overrasket .',
#   'label': 'Positive'},
#  {'sent_id': '107941-01-01', 'text': 'Anakonda-mat', 'label': 'Neutral'},
#  {'sent_id': '107941-02-01',
#   'text': 'Regi : Dwight H . Little .',
#   'label': 'Neutral'},
#  {'sent_id': '107941-02-02', 'text': 'Med :', 'label': 'Neutral'},
#  {'sent_id': '107941-02-03',
#   'text': 'Johnny Messner og Kadee Strickland .',
#   'label': 'Neutral'},
#  {'sent_id': '107941-02-04', 'text': 'Am . eventyr .', 'label': 'Neutral'},
#  {'sent_id': '107941-02-05', 'text': 'Sensur : 15 år .', 'label': 'Neutral'},
#  {'sent_id': '107941-03-01',
#   'text': 'Borneos anakondaer er kjeeeeempestore og trenger myyyye mat .',
#   'label': 'Neutral'},
#  {'sent_id': '107941-04-01',
#   'text': 'Ideen om å la vitenskapen og kapitalen slå seg sammen og dra ut i jungelen hvor livet er en virkelig kamp på liv og død , er god nok .',
#   'label': 'Positive'},
#  {'sent_id': '107941-04-02',
#   'text': 'Ekspedisjonen reiser til Borneos jungel hvor det vokser en orkidé med et enzym som gir evig ungdom - og evig rikdom til dem som kan lansere ungdomspillen .',
#   'label': 'Neutral'},
#  {'sent_id': '107941-05-01',
#   'text': 'Ute i jungelen må orkidéjegerne ikke bare kjempe mot værguder og jungelvegetasjon .',
#   'label': 'Neutral'},
#  {'sent_id': '107941-05-02',
#   'text': 'Det de ikke vet , er at orkideen inngår i kostholdet til de lokale anakondaene ( kveleslange som kan bli 10 meter .',
#   'label': 'Neutral'},
#  {'sent_id': '107941-05-03',
#   'text': 'Lever i Sør-Amerika ! ) .',
#   'label': 'Neutral'},
#  {'sent_id': '107941-06-02',
#   'text': 'Ca. hvert tredje minutt varsler lydbildet at noe farlig er på vei .',
#   'label': 'Negative'},
#  {'sent_id': '107941-06-03',
#   'text': 'Det skjer med forutsigbar presisjon og gjør etter hvert det nifse mye mindre nifst .',
#   'label': 'Negative'},
#  {'sent_id': '107941-06-04',
#   'text': 'Forutsigbart er det også hvem som blir anakondamat og hvem som skal overleve og finne kjærligheten .',
#   'label': 'Negative'},
#  {'sent_id': '107941-06-05',
#   'text': 'I det hele tatt , de fleste av oss har sett det før .',
#   'label': 'Negative'},
#  {'sent_id': '702689-01-01', 'text': 'Vakker bikkje-sex', 'label': 'Positive'},
#  {'sent_id': '702689-02-01',
#   'text': 'Overklassebikkja kommer på kjøret med en bakgårdskjøter , slik man skulle gjøre det i de begynnende opprørstidene på femtitallet .',
#   'label': 'Neutral'},
#  {'sent_id': '702689-02-02',
#   'text': 'En vakker film i fantastisk Blu-ray .',
#   'label': 'Positive'},
#  {'sent_id': '702689-03-01',
#   'text': '« Lady og Landstrykeren :',
#   'label': 'Neutral'},
#  {'sent_id': '702689-03-02',
#   'text': 'Amerikansk tegnefilm .',
#   'label': 'Neutral'},
#  {'sent_id': '702689-03-03', 'text': '1956.', 'label': 'Neutral'},
#  {'sent_id': '702689-03-04',
#   'text': '1 time,15 minutter .',
#   'label': 'Neutral'},
#  {'sent_id': '702689-03-05', 'text': 'Alle .', 'label': 'Neutral'},
#  {'sent_id': '702689-03-06', 'text': 'Regi :', 'label': 'Neutral'},
#  {'sent_id': '702689-03-07',
#   'text': 'Clyde Geronimi , Wilfred Jackson , Hamilton Luske .',
#   'label': 'Neutral'},
#  {'sent_id': '702689-03-08', 'text': 'Med :', 'label': 'Neutral'},
#  {'sent_id': '702689-03-09',
#   'text': 'Stemmen til blant andre Peggy Lee .',
#   'label': 'Neutral'},
#  {'sent_id': '702689-04-01',
#   'text': 'Jeg har ikke sett Disney-tegnefilmen « Lady ogLandstrykeren » siden jeg var barn , og gjensynet i Blu-ray ble en storøyd ogbegeistra ting .',
#   'label': 'Positive'},
#  {'sent_id': '702689-04-02',
#   'text': 'For det første er bildene så vakkert modernisert at de er ennesten vantro fryd .',
#   'label': 'Positive'},
#  {'sent_id': '702689-04-03',
#   'text': 'Dessuten er bikkjene så søte at de kan kureremorgen-misantropi .',
#   'label': 'Positive'},
#  ...]

# %%
for sent in data_3class['train']:
    print(sent['text'])
# Out:
# Philips 190G6
# Med integrerte høyttalere som på ingen måte er diskret plassert , og med en stor subwoofer inkludert , da snakker vi om en gutteskjerm .
# Eller bedrar skinnet ?
# De fleste skjermer har et diskret design , med smale rammer og slank fot .
# Men 190G6 fra Philips er en helt annen historie .
# Den har et utseende som krever oppmerksomhet , med glinsende svart ramme , glansbelegg på skjermflaten og store sølvfargede sidepaneler med fire innfelte høyttalere med svart deksel .
# LES OGSÅ :
# Foten har en stor og blank søyle , og det er store knapper og blå lys .
# Baksiden er sort , blank og skinnende , med et deksel som skjuler kontakter og kabler .
# De fire høyttalerbrønnene stikker tydelig ut - her er det ikke snakk om å gjemme noe .
# Likegyldig er det uansett vanskelig å være .
# God betjening
# I midten finner vi volumknappen , som roterer fritt .
# Nivået leser du av på skjermen , det dukker opp en skala så snart du skrur på knappen .
# Til venstre finner vi en inngangsvelger , som bestemmer om skjermen skal vise sginal fra VGA , DVI , Scart , S-video , coaks eller komponentinngangene , som alle er plassert på baksiden av skjermen , under det sorte dekselet .
# En mer allsidig og tilkoblingsvennlig skjerm har vi knapt sett .
# Til høyre finner vi forhåndsinnstillinger for lyden .
# På hver side av foten er det tilkoblinger for henholdsvis USB og hodetelefon / mikrofon , og på baksiden er det tilkoblinger for USB til lyddelen , strøm og utsignal til subwooferen .
# Skjermen kan bare vippes , ikke heves / senkes eller dreies .
# Bildekvalitet
# Vi ble positivt overrasket over bildekvaliteten .
# Spesielt fargedynamikken var klart over gjennomsnittet .
# Det er flere faste fargeprofiler med forskjellige temperaturer å velge mellom , i tillegg til manuell innstilling .
# Justeringsområdet er stort , så det er svært gode tilpasningsmuligheter til forskjellige omgivelser .
# Responstiden var ikke av de aller raskeste , det var etterslep å se på testmaterialet .
# Men i praktisk spillsammenheng var det helt uproblematisk .
# Betraktningsvinkelen fra sidene var meget bra , du kan godt invitere 4 venn( inn ) er til å sitte ved siden av deg og se på skjermen uten at noen på sidene vil få dårligere bilde .
# Vertikalt er det derimot ikke spesielt imponerende , her forsvant rødt med det samme vi reiste oss opp og så ned på skjermen .
# Lydkvalitet
# 190G6 kan kobles til et eksisterende lydkort med vanlig stereo minikack , men det er også en innebygd USB-lydenhet .
# En driver må installeres , så er det bare å velge denne USB-lydenheten i stedet for den som sitter integrert eller montert i PCen .
# Vi ble ikke imponert over lydstyrken .
# Ut fra størrelsen på subwooferen og de fire høyttalerene i skjermen hadde vi ventet oss en noe kraftigere lydstyrke .
# Det er egen volumkontroll på sub-wooferen , og den settes typisk i nærheten av midtstilling , avhengig av rom og plassering .
# Den sliter litt også før den kommer opp i nærheten av maksområdet .
# Konkluskjon
# Skjermen er spesiell , men den er god å betjene og har bildekvalitet godt over gjennommsnittet .
# I hvert fall når man ikke er alene hjemme ...
# Liten storfilm
# « The Descendants » ( Etterkommerne ) er egentlig en ganske « liten » film , men med store spørsmål inne i seg .
# Det handler om en travel advokat på Hawaii , som plutselig får livet snudd på hodet , når hans initiativrike hustru blir hardt skadet i en ulykke .
# Først må han ta vare på sine to døtre - noe han aldri har gjort før .
# Så må han ta tak i sin egen storfamilies hovedutfordring :
# Som etterkommere av en polynesisk prinsesse , eier de et stort stykke land - verd ufattelige mye penger dersom det selges til utbygging .
# Det store med denne filmen , er at den tar utfordringen med skikkelig behandling av noe så vanskelig som mellommenneskelige forhold .
# Etter filmer som « Sideways » og « About Schmidt » må vel regissør Alexander Payne sies å være en slags ekspert på dette .
# Kjenner vi egentlig våre nærmeste ?
# Prioriterer vi riktig i hverdagen ?
# Hvordan forvalter vi vårt ansvar , som enkeltindivider og samfunnsborgere ?
# George Clooney er mannen som bærer det hele på sine ikke alt for brede skuldre .
# Og han gjør det enormt godt .
# Uten store geberder gjennomlever han en livsomveltende krise .
# Man opplever en intelligent skuespiller flink nok til å holde igjen - dog alltid tydelig nok i alt han foretar seg .
# Her er han , på mest mulig overbevisende måte , en helt « vanlig mann » .
# Ikke glamorøs , nokså tydelig litt aldrende , helt tydelig meget sårbar .
# Interessant er også beskrivelsen av Hawaii , ofte nok beskrevet som en « paradis » .
# Denne gangen mye mer trivielt eksponert - dog med sine helt særegne skikker og tradisjoner og historie .
# Så på flere plan makter denne filmen ikke bare å underholde og vise følelser - men også gi interessant ny kunnskap .
# Det er godt gjort !
# Halvhjertet helhet
# The New Pornographers :
# Together
# Trygt og godt album fra The New Pornographers , men det er ikke slik vi vil ha dem .
# Et eller annet sted like etter Twin Cinema ( 2005 ) bestemte The New Pornographers seg plutselig for å bli et ordentlig band .
# Dette var en forferdelig avgjørelse for de av oss som hadde elsket dem tidligere , for det betød i dette tilfellet at medlemmene skulle dra i samme retning – albumene skulle bli mer helhetlige og lyden skulle være mer polert og avrundet .
# Dessverre insisterer de fortsatt på en unødvendig kompleksitet ( ”A Bite Out
# Når de nå fremstår som et helhetlig band har det meste av magien forsvunnet .
# Die Hard 5 :
# Bedre enn bra nok
# Action-scenene bærer den femte " Die hard " -filmen , for det finnes verken engasjerende følsomhet eller elegante replikker mellom far og sønn McClane når de destruerer det som er igjen av Russland .
# Og deretter spøkelseskraftverket i Tsjernobyl .
# A good day to die
# USA.
# 2013 .
# 1 time , 37 minutter .
# 15 år .
# Regi : John Moore .
# Med :
# Bruce Willis , Jay Courtney , Sebasitan Koch , Yulia Snigir .
# Er det sånn at du husker John McClane som en familiekjær steelcar-cowboy som kom dettende i hvit t-skjorte gjennom glassruter ?
# Han gjør det igjen .
# Jeg får av og til en forstyrrende følelse av å se Han Innante med Modern Warfare-tunge automatvåpen .
# Men det varer ikke så lenge .
# Det er egentlig mest skallen som likner .
# Russerne er stort sett proteinhjerna torpedoer med panser-torsoer , og de ser ut som analfabetiske statister fra en Dolph Lundgren-film .
# « Die hard » var den selvutslettende omsorgens film , der Willis trengte inn i en kapra skyskraper med sitt uutslettelige sprangridning-utrop « yippi ki yay » .
# Mannen var motoren .
# 25 år seinere er det maskinen som er mester .
# Allerede tidlig i filmen gjennomfører Moore et demolition derby gjennom Moskvas gater der Willis på sitt beste overkjører rushtrafikken i sin robuste Mercedes , mens bilmerker fra flere verdenshjørner kaster seg rundt i sanseløse turnoppvisninger og blir knust til resirkulasjonsmaterale som tyggegummi-Ladaer .
# Biler i spagaten .
# Biler i pilates-stillinger .
# Vi liker det .
# Skikkelig vond jernverk .
# Og særlig i naboskapet til rikelige eufemiseringer av det vi som barn kalte plaffing .
# Handlingen starter som pysestoff .
# En fengsla dissident blir trua av en slags russisk Alec Baldwin som påstår at han eier alle i rettssalen , en påminnelse om det vidunderlige demokratiet som oppsto etter Gorbatsjov .
# På nattklubb der menn sikkert snakker respektløst til unge jenter , skyter McClanes sønn John en rik mann og blir arrestert .
# Det gjør at den amerikanske politimannen må ta Aeroflot til Moskva for å redde gutten , men ting er ikke helt slik de ser ut .
# Jeg røper ikke det .
# Sønnen er sur og McClane litt defensiv , og for å være helt ærlig ønska jeg at de skulle komme bort fra hverandre ganske kvikt .
# Det er slutt på den tida da film-ungdom var spedlemma , men pene små fyrer .
# Den unge McClane spilles av den unge australieren Jay Courtney fra tv-serien « Spartacus » , som er omtrent like høy som Willis , men er firkanta som en Minecraft-Steve .
# Han har fjeset og humøret til Vinnie Jones og blir ikke tålelig før han omsider smiler .
# Far og sønn driver med kjerringaktig småkrangling , og samtalene kommer ikke til å skape forventninger om at replikk-forfatterne i USA er på bedringens vei .
# Både dattera til den antatte Komarov og unge McClane sutrer om at fedrene bare var på jobb hele tida .
# I ei tid da halve USA går arbeidsledige klager denne filmen på de som faktisk utøver et yrke .
# Det er ikke bare sviskete Oprah-skitt , men politisk umusikalsk i tillegg .
# Filmen redder seg av gårde til det mest uventa stedet i verden .
# Skurkene ikler seg drakter som ville ha holdt infuensaen ute i en heftig stavangervinter og tar seg inn i spøkelsesverket i Tsjernobyl .
# Dit kommer også McClane-familien i tynt sommertøy , og de gir seg ikke før skurker blir rotorkutta slik man ellers bare ser i Happy Wheels ( sjekk google ) .
# Hvis folk ikke hadde snakket til hverandre i det hele tatt , ville denne filmen vært perfekt .
# Nå er den bare litt mer enn bra nok .
# Følg meg på Twitter :
# @arilabra
# Gutta på tur
# Velspilt komedie med alvorlige undertoner .
# Barndomsvenner .
# Ordet smaker søtt , smaker sommer og saltvann og peanøtter .
# Venner for livet , liksom .
# Jadda .
# Som om .
# For plutselig er man andre steder , på hvert sitt sted , og det som var , er ikke lenger .
# Så er spørsmålet :
# Kan vennskapet fastholdes ?
# Er det overhodet et vennskap lenger ?
# Kjente vi hverandre , egentlig ?
# Regidebutantene Julian Hagemann og Andreas Lisberg stuper inn i tematikken med fin sans for timing og typetegning .
# I en særdeles effektiv åpningssekvens settes både rammen og personene .
# Den bokstavelig og billedlig talt syklende studenten Jo ( Øivind Vogt ) , trygghetsnarkoman , konfliktsky og samboer med Ane .
# Utagerende og rølpete Lasse ( Simen Aurstad Gjernes ) , som fortsatt bor hjemme hos mamma .
# Stoffern ( Benjamin Helstad ) som har begynt å slå seg opp som eiendomsmegler .
# De er i tyveårene , og fortsatt der hvor man kan se hvordan de var som guttunger , da vennskapet mellom dem oppsto .
# De treffes ikke så ofte lenger , men når de møtes , skal de gjøre de gamle greiene .
# De har særlig en tradisjon å ta vare på : den årlige gutteturen på hytten til Jos foreldre .
# Det blir en tur med flere nisser på lasset .
# Anes bikkje , blant annet .
# Andre , ikke spesielt velkomne folk .
# Personlig drass .
# Ting skjer som kaster nytt lys over både vennskapet og særlig en av guttene .
# Han som kanskje trenger disse kompisene mest .
# Hagemann og Lisberg etablerer raskt en frisk og lekende tone , full av autentiske dialoger og gjenkjennelige situasjoner .
# Her er mye å le av .
# Under det hele ligger et drag av noe som kanskje ikke er vemodig , det er snarere forgangent , og bidrar — til et visst punkt , til det komikkens skjær som ligger over disse kompisenes samvær og den maskuline hjelpeløsheten som etter hvert utspiller seg .
# « Å begrave en hund » er ingen ambisiøs eller dristig film , verken formmessig eller i måten temaet behandles på .
# Men den preges av en fin blanding munter ærlighet og vilje til å stå lenge nok i alvoret til at tøyset får en nødvendig klangbunn .
# Dessuten er den velspilt .
# Vogt og Gjernes har de mest takknemlige rollene , og fyller dem med stort nærvær og mye komisk talent .
# Små , innklippede videosnutter skaper god rytme og nærhet , og fungerer som en enkel , men fiffig tematisk kommentar .
# Filmen flyter ellers litt vimsete hit og dit , i tråd med både typer og vekslende stemningsleier .
# Slik sett har den en indre stringens , også der hvor manus synes å la en tråd henge løs av hensyn til dramaturgien .
# Det skjer idet det oppstår en situasjon hvor en av guttene skal , og bør , dra fra øyen .
# Han venter på en ferge , den viser seg å gå om flere timer .
# Guttene disponerer egen båt .
# Ingen tilbyr seg å skysse ham over .
# Fergeturen forsvinner i det blå .
# Ingen evner å ta grep om noe , ingen makter å si det som må sies .
# Filmen borer ikke dypt nok til at det vonde kjennes virkelig vondt .
# I stedet for å svi der det skulle svi , tenderer den mer mot å hvile i en tilstand av trykkende taushet .
# Er du enig med vår anmelder ?
# Chris Rea :
# « The Blue Jukebox »
# ( Edel )
# Britiske Chris Rea fortsetter å dyrke bluesen sammen med sine franske musikere .
# Chris Rea fortsetter blues-stilen som han vendte tilbake til på sin forrige plate « Stoney Road » .
# Den nye platen , med 13 låter signert Rea , appellerer mer til blues- enn til popfansen .
# Best er han i « Baby don't cry » og « Somebody Say Amen » .
# Disse tre er platens beste sanger .
# Fin tone i stemmen
# Natnael « Natti » Asgedom kom inn i finalen som sistemann .
# Han fremførte « Is This Love » av Bob Marley .
# - Det er ingen andre som koser seg så mye som deg , sa Kurt Nilsen og la til at han håper å se Natnael vidre .
# VG anmelder Morten Ståle Nilsens dom :
# Natti setter selv fingeren på problemet :
# Dette er en så velkjent sang at det er vanskelig å sette et nytt preg på den .
# Men han prøver , og kommer nærmest i det andre verset .
# Det første blir forsiktig amatøraften , komplett med ubekveme « moves » .
# Teskjekjerringa
# Mye snodig er nødt til å foregå bak kraniet til Vilde Tuv - et sted det godt kunne vært enklere å få slippe inn .
# “ Naivt ” og “ drømmende ” er to eldgamle adjektivklisjeer i musikkskribentgloseboka .
# Men det bergensbaserte enkvinnesbandet Vilde Tuv - hvor kun hun selv , baritongitar og basstromme står disponibelt - må være det nærmeste man kommer å få høre vuggesanger like håndgripelige som uhåndgripelige .
# En del av grunnen ligger riktignok i den visuelle presentasjonen .
# For bak sortkledde Tuv står det reist en halvmåneformet vegg , der kaleidoskopiske animasjoner ( signert kunstneren Birk Nygård ) av vindmøller , planeter , galakser og arkaiske symboler roterer “ hypnotisk ” på lag med musikken .
# Passende nok flyter tidvis gitarplukking ut i periferien og skaper en subtil ambiens ikke ulikt universet til Seattle-musikeren Grouper .
# Barnligheten kommer imidlertid til uttrykk gjennom Tuvs tekster , som trolig vil kunne bli godt mottatt blant nysgjerrige krapyler på Miniøya .
# Der eksempelvis to av låtene er titulert “ Tyngdekraft ” og “ Cellevevet ” , tar en låt for seg at “ det er så mye som blir bedre når man blir stor ” , mens en annen - som visstnok flere andre - handler om den ene av de fem sansene .
# “ For det er fem sanser ?
# Ja .
# Mange av sangene handler egentlig om den sansen , ” forklarer hun distré , uten at hun eller strofene svarer på hvilken sans det er snakk om .
# Hodet hennes virker med andre ord å være tusen steder på samme tid , et karaktertrekk man gjerne finner hos medbergenserne Fjorden Baby !-frontmann Sturle Kvilekval eller Christian Stockhaus fra all-nonsense-bandet Ungdomskulen .
# Snakker om sola :
# Stockhaus og Vilde Tuv har sammen gitt ut en av de kuleste låtene så langt i år , i form av det übersløye elektropopsporet “ Svømmebasseng ” .
# Seilende under sitt eget skrudde flagg finnes det enkelte - men ikke nok - hjelpere til å finne veien helt inn i hennes verden .
# Spillanmeldelse :
# « Beyond Good & Evil HD »
# ( VG Nett )
# Ubisoft varter opp med et herlig gjensyn med en skammelig forbigått sjarmbombe av et spill .
# I 2003 forsøkte Ubisoft å skape en actionheltinne og en spillopplevelse som tilførte dybde i en spillverden og en genre hvor det mer umiddelbart tilfredsstillende dominerte .
# « Beyond Good & Evil » hadde en uredd fotojournalist i hovedrollen , og tematikken sneiet innom temaer som politisk undertrykkelse , slaveindustri , krig og revolusjon .
# Pakket inn i en engasjerende sci-fi-historie og givende , « Ratchet & Clank » -lignende spillbarhet .
# Kanskje var det bare uheldige tilfeldigheter , kanskje ble spillet oppfattet som utilgjengelig og arty-farty eller kanskje var det noen år forut for sin tid .
# I så fall er muligens tiden mer moden nå , syv og et halvt år senere .
# Nå slippes spillet i HD-oppusset versjon på Xbox Live Marketplace og Playstation Network , og det er fremdeles snakk om en kruttsterk opplevelse .
# Det er riktignok umulig å ignorere at teknologien har tatt enorme skritt siden den gang , og at endel av designvalgene nå kan fremstå som litt vel gammeldagse .
# « Beyond Good & Evil » var utvilsomt mer interessant satt opp mot spillmarkedet anno 2003 .
# Men det at det fremdeles er såpass givende , underholdende , engasjerende og spennende tyder på et bunnsolid designfundament .
# Jeg liker dette universet , jeg er glad i Jade , Pey'j og det øvrige rollegalleriet , jeg koser meg med de givende oppdragene , jeg elsker tematikken og spillet i seg selv er veldig underholdende .
# Og det er tross alt vel så viktig som spillets spillhistoriske betydning .
# PS :
# Ute nå på Xbox Live Marketplace med en prislapp på 800 MS-poeng ( ca . 100 kroner ) .
# Kommer på PSN i 2. kvartal .
# BEYOND GOOD & EVIL HD Plattform : 360 Genre :
# Action / eventyr Alder : 12 Utvikler :
# Ubisoft Utgiver :
# Ubisoft
# Mer info
# Enestående spill-magi
# Avlys alle avtaler og gled deg til nok et magisk , enormt , fantastisk og oppslukende « Zelda » -eventyr .
# Det finnes neppe noen mer elskede spillserier enn « Zelda » .
# Helt siden starten i 1986 har det ene « Zelda » -spillet etter det andre bergtatt eventyrlystne over hele verden .
# Og det er med stor glede og et fårete glis om munnen jeg kan konstatere at « The Legend of Zelda :
# Twilight Princess » ikke er noe unntak .
# Det er i steden , i mine øyne , det kanskje beste spillet i serien til nå .
# Et fantastisk og episk eventyr som sakte men sikkert vokser og vokser helt til hjertet mitt holder på å eksplodere av pur lykke .
# Historien og oppbyggingen av spillet er velkjent .
# Det starter særdeles rolig og avslappet i en søvnig og idyllisk liten landsby .
# Men en ondskap er i ferd med å spre seg , og truer med å ta over fantasiverdenen spillet foregår i .
# Dermed blir det opp til spilleren , som tar på seg rollen som den utvalgte frelseren Link , å redde både prinsesse Zelda , kongeriket Hyrule , vennene fra landsbyen og til syvende og sist hele verden .
# Fra den spede starten legges den ene nye egenskapen og gjenstanden etter den andre til .
# Stadig nye områder å utforske åpner seg opp .
# Historien tar plutselige og dramatiske vendinger .
# Og før du vet ordet av det , er du fullstendig oppslukt i det som skjer .
# Et magisk eventyr på flerfoldige titalls timer ligger foran deg .
# Det er bare å rydde plass i kalenderen med en gang - inntil « Twilight Princess » er fullført vil du neppe ha lyst til å gjøre noe annet .
# Alt sitter som et skudd .
# Fra den nydelige visuelle stilen til det herlige lydbildet , den nostalgiske musikken , slåssingen mot monstere , utforsking av grotter og andre områder og kreativ bruk av diverse hjelpemidler for å komme videre .
# For å nevne noe .
# Det er i det hele tatt ikke langt mellom gåsehudøyeblikkene i dette spillet .
# Og det mener jeg bokstavelig .
# « Twilight Princess » er så bra at jeg får gåsehud bare av å tenke på det - en svært sjelden begivenhet for en som spiller såpass mye som meg .
# Wii-håndkontrolleren er dessuten utnyttet på en eksemplarisk måte .
# Du bruker den til å sikte med pil og bue , til å svinge sverd , til å fiske og til mye annet .
# Etter en tilvenningsperiode på rundt en halvtime , føles det både selvfølgelig og naturlig .
# Nintendos nye spillkonsoll kunne i det hele tatt ikke ha bedt om noe bedre lanseringsspill , selv om Gamecube-eiere muligens ikke vil gå glipp av mye dersom de går for Gamecube-versjonen 15. desember .
# For det er nok spillet i seg selv - og ikke Wii-håndkontrolleren - som gjør « The Legend of Zelda :
# Twilight Princess » til et av tidenes beste konsollspill .
# Den dypt elskede Zelda-serien får snart et nytt kapittel med Wii-spillet « The Legend of Zelda :
# Twilight Princess » .
# Slik blir spillet .
# Götze :
# - Skylder kjæresten min mye
# RIO DE JANIERO / OSLO ( VG ) ( Tyskland - Argentina 1 - 0 ) Mario Götze ( 22 ) kom inn fra benken og gjorde Tyskland til verdensmestere på egen hånd med en fantastisk volley i ekstraomgangene .
# - Det er utrolig hvordan vi alle har jobbet for dette .
# Dette er en utrolig følelse , jublet kaptein Philipp Lahm etter sin første VM-triumf i karrieren .
# Avgjørelsen på VM-finalen 2014 falt så sent som i det 112. minutt da innbytter André Schürrles innlegg fra venstresiden fant en annen innbytter inne i Argentina-boksen .
# Mario Götze erstattet tidenes mestscorende i VM-historien , Miroslav Klose , etter 88 minutter .
# Da innlegget kom svarte Bayern München-spilleren med en scoring på ekte goalgettervis .
# Matchvinneren møtte pressen i spillerutstyr og sandaler på pressesenteret i Rio , etter at laget hadde fått summet seg i garderoben .
# - Det var en utrolig følelse .
# Jeg vet ikke hva som skjedde , jeg bare skjøt .
# Det som skjer etter kampen , å ha denne festen med dette laget , det er en drøm som går i oppfyllelse .
# Jeg vet nesten ikke hva jeg føler , dette er helt sensasjonelt , sa Götze .
# - Det har ikke vært et enkelt år for meg og ikke en enkel turnering .
# Jeg skylder mye til familien og kjæresten min , som har trodd på meg .
# Jeg er veldig glad for at vi har vunnet dette .
# Jeg har fortsatt trent med laget , og hver eneste spiller fortjener å bli nevnt .
# Vi har fortjent dette trofeet .
# Mario Götzes kjæreste er den tyske modellen Ann-Kathrin Brömmel , som blant annet har figurert i spaltene hos den tyske utgaven av herremagasinet GQ.
# - Beskriver laget
# - Måten vi scorer målet på beskriver dette laget , sier Thomas Müller , Tysklands toppscorer i mesterskapet med fem mål .
# - Vi har kjempet så hardt for dette , jeg har ikke ord .
# Nå hylles de nybakte VM-vinnerne av tidligere tyske helter .
# - Et sensasjonelt mål av Götze !
# Disse ungdommene fortjente å bli verdensmestere .
# De er våre verdige etterfølgere , sier Andreas Brehme til den tyske avisen Bild .
# Brehme ble matchvinner fra straffemerket sist gang Tyskland vant en VM-finale - mot nettopp Argentina i Italia i 1990
# Dermed gjorde Tyskland akkurat som de gjorde mot Argentina i VM-finalen i 1990 :
# De vant 1 - 0 .
# Den gang etter scoring av Andreas Brehme .
# Og i 2014 var det altså unggutten Mario Götze som ble den store helten , til tross for at han ikke har vært fast på det tyske laget de siste VM-kampene .
# Det var en relativt nedtonet og lavmælt Argentinsk trener som møtte pressen etter nederlaget i finalen :
# Kampen hadde sine opp-og-ned-situasjoner .
# Vi hadde klare sjanser , sa Alejandro Sabella , for anledningen i skjorte og slips .
# Argentina-treneren nevnte også det faktum at Argentina-spillerne hadde flere minutter i beina før kampen .
# - Vi hadde spilt to ekstraomganger og vi hadde en dag mindre hvile .
# Generelt er jeg veldig stolt .
# Guttene har spilt en ekstraordinær VM-turnering .
# De har lagt igjen alt de har på banen .
# Sabella tok Argentina nærmere VM-gull enn de har vært på mange år .
# Allikevel fikk han spørsmål om han sitter trygt i trenerstolen .
# - Dere må bli lei av at jeg stadig gjentar dette .
# Jeg kan ikke snakke om fremtiden .
# Fremtiden min nå er å være med spillerne , støtteapparatet , familien min .
# Så jeg vet ikke hva jeg skal si , svarte Sabella .
# - Når du kommer til finalen vil du vinne , men jeg sitter også igjen med en følelse av være tilfredsstilt , av å ha gitt alt , avsluttet Sabella før han forlot salen til applaus fra flere av journalistene .
# Veteranene gråt
# Tyskland har hatt et fantastisk mesterskap og de fleste så på « Die Mannschaft » som den store favoritten til VM-gullet etter den vanvittige 7-1-seieren over Brasil i semifinalen .
# Den spådommen ble ikke gjort til skam .
# Götze gjorde også at flere av de aldrende Tyskland-spillerne endelig fikk løfte VM-trofeet før karriereslutt .
# Etter kampen var det blant andre veteranene Bastian Schweinsteiger og Thomas Müller som gråt mest over den enormt etterlengtede triumfen .
# Argentina klarte aldri å svare på Götzes volley i sluttminuttene .
# Ekspertene i VGs VM-studio mente perlemålet var en av tidenes vakreste scoringer som har avgjort et VM .
# - Det er så perfekt utført !
# Han legger den perfekt til rette med kassa , og smeller den i lengste hjørne , sier talentspeider Stig Thorbjørnsen .
# Dermed kunne både Tyskland-spillerne og den tyske fansen juble for trofeet de har vært nær ved å kapre flere ganger de siste tyve årene .
# - Det ble tøffere enn forventet .
# En åpen kamp , sånn man ønsker at en slik stor finale skal være .
# Det hadde ingen betydning så lenge kreftene holdt , men vi må huske at argentinerne hadde én dag mindre pause og måtte ut i ekstraomganger i semifinalen , sier den tyske legenden Franz Beckenbauer til Bild .
# Mens tyskerne feiret og gråt om hverandre , satte Argentina-stjernen Lionel Messi seg på gresset med hodet mellom knærne .
# Han lyktes ikke med å ta sitt Argentina til VM-gull , som Maradona gjorde i 1986 .
# Real Madrid-stjernen Ángel Di Maria ble ikke klar til søndagens VM-finale , og virker helt sønderknust ute på gressmatta sammen med lagkameratene etter kampslutt .
# Lionel Messi mottok Gullballen , prisen for VMs beste spiller , etter kampslutt , men Argentinas store stjerne rikket ikke på smilebåndet da han gikk opp podiet og mottok prisen fra FIFA-president Sepp Blatter .
# En som derimot smilte fra øret til øret var Tyskland-keeper Manuel Neuer , som både kunne innkassere VM-gullet og Gullhansken , prisen for mesterskapets beste keeper .
# Argentina nære
# Kampen var målløs helt frem til Götzes matchvinner-scoringen i det 112. minutt , men hadde nok av målsjanser .
# Både Argentina og Tyskland gikk ut i hundre i ekstraomgangene foran de 74738 tilskuerne på Maracana stadion .
# Først stoppet keeper Sergio Romero et André Schürrle-skudd på mesterlig vis fra fem-seks meter .
# Deretter beinet Lionel Messi fremover på en kontring , men Argentina-stjernen ble hindret rett før han var på vei gjennom mot mål .
# Messi spilte en stor første omgang , men maktet ikke å finne lukene i det tyske forsvaret i løpet av kampen .
# Innbytter Rodrigo Palacio var svært , svært nær ved å sende Argentina i en forløsende ledelse etter 97 minutter , men Inter-spissens lobb ble altfor upresis i en duell med keeper Manuel Neuer rundt åtte meter fra mål .
# Det var det nærmeste noen av lagene kom i den første ekstraomgangen .
# Higuaíns hode mot Neuers kne
# Den andre omgangen bød ikke på fantastisk angrepsspill fra noen av lagene , og det som satte mest støkk i publikum var en stygg episode mellom Gonzalo Higuaín og Manuel Neuer .
# Argentina-spissens hode frontkolliderte med kneet til Neuer da han forsøkte å rekke en gjennombruddspasning fra Pablo Zabaleta .
# Dommer Nicola Rizzoli dømte frisparket mot Higuáin , som heldigvis kom seg på beina etter smellen .
# - Det er livsfarlig spill av Neuer , sa fotballekspert Bernt Hulsker i VGs VM-studio .
# Sammenstøtet preget Higuaín såpass mye at han ble byttet ut etter 77 minutter .
# Tyskland hadde overtaket i siste halvdel av den andre omgangen , men maktet ikke å produsere de virkelig store mulighetene .
# Enorm Argentina-sjanse
# Første omgang var jevnspilt , inneholdt det meste , men heller ikke da kom den forløsende scoringen .
# Men det kunne den fort ha gjort .
# Argentina fikk en vanvittig gratismulighet etter 20 minutter .
# Bayern München-spiller Toni Kroos headet en høy ball bakover rundt 25 meter fra mål , muligens i håp om å treffe keeper , men midtbanespilleren endte med å sende den rett i beina på Higuaín .
# Napoli-spissen fosset alene mot mål og avsluttet fra 16 meter , men ballen skled av foten på Higuaín og trillet til venstre side for mål .
# Samme mann kom igjen i fokus etter 29 minutter .
# Argentina-stjernen Lionel Messi flikket ballen elegant ut på høyrekanten til en ledig Ezekiel Lavezzi .
# Lynvingen svinget ballen inn til Higuaín som avsluttet på direkten og i mål bak Manuel Neuer .
# Mens Higuáin jublet hemningsløst og stormet mot Argentina-benken , sto linjedommeren med flagget oppe og vinket for offside .
# TV-bildene viste en tydelig skuffet Higuaín og at avgjørelsen var korrekt .
# Stolpetreff for Tyskland
# Tyskland fikk to gode muligheter de siste fem minuttene av omgangen , først ved Toni Kroos .
# Etter 43 minutter fikk Tysklands pasningskonge stå alene å skyte fra rundt 16 meter , men skuddet var unormalt svakt til han å være .
# Og på overtid av første omgang traff Tyskland stolpen .
# En perfekt corner fra Kroos landet på hodet til en stormende Benedict Höwedes , som stanget ballen i stolpen fra fire-fem meter .
# Ballen spratt i beina på en uoppmerksom Thomas Müller før den trillet rolig inn i hendene på Sergio Romero .
# Overraskelse !
# Her står et par overraskelser tett som taxi-kø :
# Jason Statham har hår og skjegg , og han spiller et svett , psykologisk actiondrama som gjør at han antakelig blir invitert i selskaper hos pologenserne framover .
# Ray Liotta er hypa-paranoisk gangstersjef med en sjelelig og kroppslig nakenhet som nok en gang gjør den ugripelige skuespilleren til et ikon , en kult-ting for folk som samler på pyntegjenstander av isopor og ukrainske boksåpnere .
# Overraskelse tre :
# Briten og Madonna-mannen Guy Ritchie har våget lage en actionfilm etter millenniumskiftet der det så vidt er med ei eneste snakkende dame , og det er den middelaldrende Lilly Walker som ser ut som om hun sover med Johnny hver kveld og antakelig skal forestille aggressiv verktøy-homofil .
# De andre kvinnene som deltar , skrever tause som strupte ender i sofaer .
# Med andre ord :
# Samtidig er « Revolver » et ærgjerrig forsøk på psykologisk liksom-drama om egoet og dets blanda blendverk .
# Er selvet noe som finnes eller noe som skapes , og kan man lures til å tro at man er seg selv ?
# Da Madonna leste mannens manus , vurderte hun antakelig å re-konvertere fra jødedommen til muskuløse NY-dansere .
# Men vi som liker film , kan komme til å elske det aldeles forvrengte ved « Revolver » .
# Statham kommer ut av fengsel etter sju år , utfordrer kasino-kaksen Liotta og treffer to tilsynelatende visjonære forbrytere .
# Det handler om den perfekte svindel , det handler om hva tyveriet av Mr. Golds hvite pulver gjør med julebaksten det året .
# Statham er fantastisk med hår og skjegg .
# Stor og bred Seagal
# Steven Seagal er blitt like stor som Travolta , og han bærer skinnjakke innendørs for den er antakelig sydd fast til tatoveringene hans , og ansiktet er så bredt at du kan skjære fenalår på det .
# I denne filmen handler det om en seriemorder med veikrobart som gjør anatomiske ting med prostituert dame .
# Dermed er genrens patologi-imperativ ivaretatt .
# Verre er det med slagsmålene .
# Klipperen har overtatt Seagals martial art , og slåssinga er så kjipt og kjapt klippet at filmen antakelig kunne ha inneholdt Titanics undergang uten at du oppdaget det .
# Men noen fikse ting :
# Hettemannen ser ut som David Beckham etter en strevsom natt med konas venninner .
# Seagal får en Dirty Harry-pakke :
# Ei finslig dame skal bli med på kjøret og observere oksen i arbeid .
# SS slår små pyser tusen ganger , sjøl om ett av slagene ville ha kledd en rustningskledd bjørn .
# Filmer med den seriøse Seagal pleide å være litt puritanske av seg , men nå har mannen vært skilt så lenge fra Kvinnen i rødt at livet hans er blitt fylt opp av damer i ufullstendige klær .
# Mesterverk om mobbing
# Mobbeofferet Anna benytter nostalgisk klassegjenforening til å konfrontere sine tidligere klassekamerater og plageånder .
# Barne— og ungdomskolegjengen treffes igjen på fest 20 år etterpå , og plutselig er det som om man er 15 år igjen .
# Følelsene og minnene fra den gang , iblandet alkohol og utvalgte gode minner sørger for topp stemning .
# Så klinger Anna på glasset og reiser seg .
# Forteller en annen historie om " samholdet " og minnene .
# For det Anna husker fra skoletiden er mobbingen , utestengningen , skjellsordene .
# Boblene går helt ut av festen .
# Med håndholdt kamera i øyenhøyde , er det som om vi selv er til stede på gjenforeningsfesten og kjenner alle følelsene rundt de vonde konfrontasjonene som følger .
# Det gjør nesten fysisk vondt .
# Ikke bare å føle gjennom Anna , men også å kjenne på følelsene og reaksjonene til klassekameratene .
# Hva kunne skjedd ?
# Den kontroversielle , svenske kunstneren Anna Odell spiller seg selv i sin regidebut .
# Kanskje er mobbefortiden selvopplevd , men gjenforeningsfesten er det ikke .
# For Anna ble nemlig ikke invitert til klassens 20 års jubileum .
# Derfor laget hun en spillefilm om festen slik den kunne ha skjedd om hun var blitt bedt , og om hun hadde møtt opp og konfrontert sin gamle klasse .
# Ville de endelig sett henne da ?
# Ville de bedt om tilgivelse for sine tankeløse handlinger ?
# Eller ville de bare blitt irriterte fordi hun ødela feststemningen ?
# Men Odell stopper ikke der , selve festen er bare halve " Gjenforeningen " .
# Da det blir klart at " gjenforeningen " er fiksjon , inviterer Anna sine gamle klassekamerater til å se filmen og diskutere den , en etter en .
# Konfrontasjonene er oppsiktsvekkende , både i form og innhold .
# Og gradvis tegnes det et bilde av både nåtid og fortid som ikke bare er svart- hvitt .
# I " Gjenforeningen " belyses altså temaet mobbing gjennom direkte konfrontasjon mellom mobbeoffer og mobber på en voldsomt effektiv og nifst tankevekkende måte .
# Det er så lett å fordømme handlinger og reaksjoner .
# Men hvordan ville vi selv reagert ?
# Som et gnagsår kverner tankene , særlig fordi det slett ikke er så opplagt hvilken knagg vi skal henge vår sympati og antipati på .
# Minst like interessant og mesterlig som selve mobbetemaet er håndtert , er Anna Odells kunstneriske prosjekt med " Gjenforeningen " .
# Som med Karl Ove Knausgårds " Min kamp " kan " Gjenforeningen " være utlevering av virkelige mennesker , forkledd som " drama " .
# Eller er det egentlig motsatt :
# Fiksjon forkledd som halvdokumentar ?
# Sterkt er det uansett .
# Intens konfrontasjon
# Skillet mellom virkelighet og fiksjon er uansett sømløst , og egentlig ikke så viktig .
# Offerets behov for oppgjør gjennom konfrontasjon er det som driver historien framover og får oss til å følge fjetret med .
# Og gjenkjenneligheten .
# Feigheten .
# Selvforsvaret .
# Selvopptattheten .
# Sånn er vi altså : alltid oss selv nærmest .
# Alle som en .
# " Gjenforeningen " er tvers gjennom imponerende .
# Den sier mer om mobbingens natur enn tusen holdningskampanjer .
# Uten å gi noe svar .
# Film :
# Stilfull thriller
# Men nettopp det stilfulle fortrenger effekten av mysteriet i fortellingen .
# Sør-koreanere Chan-wook Park er kjent for surrealistisk og effektfullt billedspråk .
# I « Stoker » bruker han det på en elegant måte for å poengtere hva som rører seg i en ung jentes turbulente , kløktige og opprørske sinn og sjel .
# Plottes skal ikke røpes ; men det dreier seg om en unge jente som på sin 18-års dag opplever at faren blir drept i en bilulykke - tilsynelatende .
# Jentas forhold til moren er distansert , men både mor og datters nysgjerrighet pirres når farens ukjent yngre bror dukker opp i begravelsen .
# Kjapt aner man en onkel med manipulerende egenskaper , en mor med tåkelagt frustrasjon og en ungjente med farlige tilbøyeligheter .
# Sistnevnte spilles med en overbevisende miks av uggen , kjølig distanse og rå energi av Masikowska .
# Kidman som moren , leker seg med undertoner av sensuell søvnighet , og Weaver forfører damene med flørtende eleganse , som selvsagt skjuler et bunnløst mørke .
# Filmen betar med brå kast av visuell uhygge og vold som korresponderer godt med personenes turbulente sinn .
# Regissøren har Hitchcock som en av sine forbilder , noe som synliggjøres i fascinasjonen for natur , og skråblikk på menneskesinnet .
# Søt musikk
# FILM :
# Studio Ghibli har fortryllet millioner av barn ( og voksne ) med sine håndmalte eventyr - vi kan nevne « Chihiro og heksene » , « Ponyo » og « Min nabo Totoro » .
# Det er bare ett år siden kinopremieren på « Arriettas hemmelige verden » , som har det felles med « Møte på valmueåsen » at manus er skrevet av Ghiblis grunnlegger , Hayao Miyazaki .
# Regien er ved hans eldste sønn , Goro .
# Snill og søt
# Vanligvis kommer Studio Ghiblis filmer på kino i dubbet utgave , siden de er beregnet på små barn .
# « Møte på valmueåsen » er satt opp i originalutgaven , med japanske stemmer og norske tekster og er uttrykkelig rettet mot tenåringer .
# Uttrykkelig , i den forstand at det står på vaskeseddelen og fordi hovedfigurene er sånn omtrent 16 år .
# Den er også « tillatt for alle » , i motsetning til « Arrietta » ( 7 år ) , som var dubbet .
# Kjærlighetshistorien mellom Umi og Shun er muligens vel avansert for femåringer , men jeg tror på den annen side at tenåringer vil synes at den er ganske barnslig fortalt .
# Krevende overgang
# Litt om historien :
# Året er 1963 og Japan forbereder seg på Olympiske leker i Tokyo .
# Umi går på videregående i nabobyen Yokohama og bor på et pensjonat , der hun hjelper til med matlagingen og passer sine småsøsken .
# Faren ble borte under Koreakrigen og legemoren er i USA .
# På skolen blir det mye oppstyr når man får vite at studentenes klubbhus skal rives .
# Umi blir kjent med Shun , som er redaktør for studentavisa , markant rivningsmotstander og svært populær blant jentene .
# De blir venner , men et alvorlig hinder kommer i veien for at de skal bli mer intime med hverandre .
# Fjortiser er en krevende gjeng og ønsker ikke å la seg begeistre av det samme som sine småsøsken .
# Spillanmeldelse :
# Sløy samurai
# « Afro Samurai » er et skoleeksempel på å sette stil foran innhold .
# På papiret er « Afro Samurai » bortimot uimotståelig .
# Verdens cooleste samurai på hevntokt , ninjaer , ultravold i sakte film , Samuel L. Jackson , Ron Perlman og tilbakelente hip-hop-toner fra The RZA .
# Selv uten anime-serien spillet er basert på ville konseptet ha stått svært godt på egne ben .
# Det roper om å bli kjøpt .
# Og til en viss grad har Namco lykkes i å lage en kul opplevelse .
# Men spillet er så klønete satt sammen at « Afro Samurai » ikke er i nærheten av å oppnå sitt udiskutable potensiale .
# Historien er pælmet inn i spillet på vilkårlig og forvirrende vis , kameravinklene og kontrollsystemet er plaget av skurring jeg trodde vi var kvitt for godt for lenge siden og bortsett fra musikken er lydbildet amatørmessig spakt .
# Hvilket er skuffende , konseptet « Afro Samurai » fortjener et bedre spill enn dette .
# PS :
# I salg fra fredag 27. mars .
# Flere ferske anmeldelser av PS3- og 360-spill :
# Trailer fra PS3- og 360-spillet Afro Samurai .
# Tor Endresen fikser Lennon
# Lykkes nesten hundre prosent .
# Tor Endresen fikser det meste .
# Både julekonserter og Melodi Grand Prix .
# Tar han på seg runde briller og en dongerijakke klarer han til og med å fremstå som en troverdig utgave av John Lennon , slik han gjorde på Ricks torsdag kveld .
# En solid musikalsk historielekse som med ord , toner og litt humor ga et innblikk i livet til Beatles-idolet fra 60 og 70-tallet ..
# Forestillingen bygger på den engelske skuespilleren John Waters ’ « Looking Through A Glass Onion » , et show som har vært fremført over hele verden de siste 20 årene .
# En fortelling om John Lennons liv og musikk fremført som en monolog av Lennon selv .
# Men dette er ingen kopi av den engelske utgaven .
# Den musikalske grunnstammen er riktignok beholdt , men mange av låtene er også byttet ut .
# Teksten er oversatt og delvis nyskrevet av Tore Nysæther som også har regien .
# Den engelske utgaven fremføres bare med gitar og tangenter , mens Tor Endresen har et fire manns band i ryggen .
# Det starter og slutter med Mark David Chapmans fem skudd som tok livet av John Lennon en desemberkveld i New York i 1980 .
# I løpet av to timer forteller så Lennon om sitt liv .
# Om barndommen i Liverpool , tiden med The Beatles og de kaotiske årene som soloartist i New York .
# Historien blir fortalt med et bergensk gatespråk .
# Det er det eneste som ville fungert for Tor Endresen , men gjør likevel at det ikke alltid stemmer hundre prosent .
# For det skal innrømmes at man aldri helt kommer under huden på hovedpersonen .
# Noe som også er en nesten uoverkommelig oppgave i en to timer lang forestilling der mye av stoffet utgjøres av det musikalske .
# I all hovedsak er monologen bygget på intervjuer og Lennons eget skriftlige materiale .
# Men her må også være en del som er omformet for å passe inn i settingen .
# Uttrykk som bamseklubben på Playa Del Ingles er vel tvilsomt om kommer fra Lennon selv .
# Da Endresen nevner Lennons elskerinne May Pang , og trommis Nyheim utbryter « Meir peng ? » får han selvfølgelig publikum til å le .
# Men det har lite med Lennon å gjøre .
# Slike kjipe morsomheter er det heldigvis få av .
# Da fungerer det atskillig bedre når det første verset på Beatleslåten « Girl » fremføres med indisk dialekt som en parodi på guruen Maharishi Yogi som Beatlesmedlemmene var opptatt av i en kort periode .
# Det musikalske er det derimot lite å utsette på .
# Tor Endresen klarer faktisk til tider å høres ut som Lennon selv med sin spesielle og lett nasale stemme , og her skurrer det aldri .
# Verken på gammelrocklåtene , Beatles eller stoffet fra soloalbumene .
# Totalt inneholder kvelden mer enn 30 sanger – en lett blanding fra hele Lennons produksjon .
# Ikke alle fremføres i sin helhet , men riktig bra låter det uten unntak .
# Det hjelper selvsagt at de fire musikerne har fått Beatles inn med morsmelken .
# Ofte er de ganske tro mot originalen som under « Lucy In The Sky With Diamonds » .
# Men også når de leverer mer frie tolkninger som « Working Class Hero » , blir det hundre prosent riktig .
# Til og med det å flette den første Beatles-singelen « Love Me Do » midt inne i en versjon av Lennons « Crippled Inside » er helt som det skal være .
# Bandet bestående av Daniel Birkeland på gitar , Kai Taule på bass , Dag Øivind Rebnord bak tangentene og trommis Helge Nyheim klarer virkelig å gjenskape både Beatles og Lennon på en måte som det står respekt av .
# Som musikalsk forestilling lykkes « Lennon » hundre prosent .
# Som historielekse er den derimot ikke helt uten små svakheter .
# Likevel så bra at Tor Endresen allerede nå burde søke skoleverket om få fremført forestillingen som pensum for den oppvoksende generasjon .
# EINAR ENGELSTAD
# Gavin DeGraw « Free »
# ( J Records / Sony Music )
# Under gjennomsnittet fra gjennomsnittlig artist .
# Det åpner ikke så aller verst med en renskåret versjon av avdøde Chris Whitleys blues « Indian Summer » .
# Den tydeliggjør samtidig DeGraws store problem - at han ikke evner å skrive gode låter selv .
# Det hjelper ikke at tekstene bugner over av klisjeer med titler som « Stay » , « Lover Be Strong » og « Waterfall » .
# Og at man ikke klarer å finne en annen albumtittel enn en av rockehistoriens mest brukte , sier det meste om mangelen på kreativitet .
# ANBEFALTE KJØP :
# « Indian Summer » , « Why Do The Men Stray » .
# Bjølsen Valsemølle :
# Et ufortjent glemt band
# De kritiserer Israel , menn som skyter ulv og hyller marit Bjørgen .
# Bjølsen Valsemølle er i utgangspunktet et tradisjonelt rockeband og på sitt vis – kanskje et av Oslos viktigste band .
# De tilhører en prisverdig tradisjon der samfunnsengasjement og politisk stillingtagen er en selvfølge .
# Samtidig har de et blikk for hva som rører seg i byen både i nåtid og fortid .
# Bandet har aldri glemt hvor de kommer fra og er tro mot sitt opphav .
# Disse har Aftenposten kåret til årets juleplater :
# Stayerevne
# Bandet oppsto i et husokkupasjonsmiljø på Sagene / Bjølsen på 70-tallet .
# Slikt setter spor .
# Solidaritetstanken sitter i ryggmargen .
# Det gjør også optimismen og fremtidshåpet .
# Stayerevnen til låtskriver og frontmann , Trond Ingebretsen og Bjølsen Valsemølle er både imponerende og i
# nteressant .
# Ikke nok med at de har holdt det gående i nærmere førti år , de klarer også fortsatt å ta pulsen på samtiden , hedre historien og fargelegge sitt uttrykk med kledelig avvæpnende nostalgi .
# Vi har anmeldt Bruce Springsteens nyeste samleplate :
# Mer enn et lokalband
# Til tross for opptil flere strålende plater de siste årene har lite endret seg .
# I dagens urolige tider trenger vi folk og musikk som får oss til å tenke .
# Han gir av egen erfaring og spenner opp et speil vi kan se oss selv i .
# Det er ingenting som er vanskeligere enn å skrive politiske sanger som også skal fungere utover budskapets tematikk .
# Det er her Bjølsen Valsemølle viser sitt mesterlige grep på denne sjangeren .
# Har du hørt plata som hyller Raga Rockers ?
# Vi har anmeldt den også :
# Dagsaktuelle temaer
# Få , om noen , skriver slike sanger i landet i dag .
# Trond Ingebretsen er en god historieforteller som har hjertet med seg i fortellingene .
# Om de er illsinte politiske betraktninger eller en liten nostalgisk minnestund forblir man ikke uberørt .
# Han er spesielt god på de ulike tidsbildene han setter sangene i .
# Det gjør godt i disse tider .
# Disse sangene er ikke skrevet i et vakuum , men er blitt til i frustrasjon over hvordan vi har stelt oss .
# Den mest kontroversielle og brennbare sangen er nok « Israel , det räcker nu » , hvor han har fått med seg Michael Wiehe som duettpartner .
# Sangen taler for seg selv .
# Han synger om norsk våpenproduksjon og eksport i den bitende kommentaren « En vanlig mann » .
# « Menn i mørket » er tilegnet Osvald-sabotørene , mens « Ekte mannfolk skyter ikke ulv » tar for seg ulovlig ulvejakt .
# Dette er Maria Menas nyeste plate :
# Minneperler
# En av de fineste øyeblikkene er Ingebretsens ode til Tjuvholmen .
# Her har han fått med seg Jon Arne Corell , en av frontfigurene i den politiske visebevegelsen på 70-tallet .
# Et nydelig lite tidsbilde på byutviklingens merkelige gang .
# En annen godbit er « Erik , Jim Morrison og jeg » om et musikalsk møte som viser hva som setter seg i minnet .
# Den mest rørende sangen er tittelmelodien , som er en sterkt personlig sang skrevet til barnebarnet .
# En sang som griper direkte inn i dagens mest aktuelle konflikt .
# En sang om samhold , tilhørighet og raushet .
# Som en kommentar til « Tider skal komme » kan man se Wyoming .
# En hyllest til Marit Bjørgen er det også blitt plass til .
# Fikk du med deg podcasten « Serial » ?
# Vi har anmeldt sesong to :
# Finstemt band
# Bjølsen Valsemølle er en finstemt gruppe som gir vitalt liv til låtskriverens mer eller mindre illsinte tekster .
# Dette er et rockeband tuftet på visens premisser .
# Det kan høres litt gammelmodig i disse tider , men som Henning Kvitnes og Trond Granlund treffer de en jordnær nerve som gjør godt .
# Denne gruppen står fjellstøtt på egne premisser .
# Se Aftenposten Kultur baksnakke kulturlivet i nytt program :
# Trenger du TV-tips ?
# Her er ti serier du bør få med deg i høst :
# Robert Forster « The Evangelist »
# ( Tuition / Tuba )
# Rørende hyllest til avdød partner .
# På åttitallet var The Go-Betweens Australias svar på The Smiths og R.E.M. - stilmessig og kvalitetsmessig , om ikke salgsmessig .
# Etter å ha ligget brakk som gruppe hele nittitallet gjorde de et formidabelt kunstnerisk comeback dette tiåret , og lagde sin kanskje beste plate , « Oceans Apart » , i 2005 .
# Året etter ble det stopp , for da døde Grant McLennan , halvparten av den kreative kjernen i bandet .
# Robert Forster er den gjenlevende halvparten , og med sitt første soloalbum på 12 år byr han på sørgmodig , akustisk drevet rock helt i tråd med det siste han og McLennan lagde sammen .
# Dødsfallet kaster selvsagt skygge over platen , noe Forster takler med verdighet og en rak rygg som bærer praktfulle melodier og oppløftende tekster .
# Det er en ikke ubetydelig « Automatic For The People » -følelse over « The Evangelist » .
# Anbefalt kjøp :
# « Pandanus » , « The Evangelist » , « Let Your Light In , Babe » , « A Place To Hide Away » , « It Ain't Easy »
# TEST :
# Lexus GS 450h
# Lexus er av de store premium-aktørene globalt og er på fremmarsj også hos oss .
# 343 hestekrefter mot 340 ?
# Ja , effekttallet fra Lexus GS 450h ligger svært nær BMW ActiveHybrid 5 og det er ikke tilfeldig .
# De to bilene er nære konkurrenter , og BMW ble sist med på leken .
# Mercedes OG BMW-konkurrent
# Lexus-testbilen er nemlig allerede annen generasjon fra merket i klassen for store premium-sedaner med hybriddrift og fjerde generasjon GS .
# Det kan forekomme litt paradoksalt at vi nevner BMW først blant referansene , da Lexus lenge har posisjonert seg nærmere Mercedes i dette segmentet - det vil si med fokus på komfort og luksusfølelse .
# Bilen vi kjørte denne gangen tåler imidlertid sammenligningen med BMW når det gjelder sistnevnte merkes kjennemerke nummer 1 : Kjøreglede .
# Når Lexus helt opp her ?
# Svaret kommer litt lenger ned .
# LF-design
# Først litt om design og interiør .
# ...
# Derfor har Pendulum også MC-en Ben Mount .
# Et genialt trekk .
# En helt utrolig konsertopplevelse .
# Et annet Pendulum enn på plate , men minst like bra !
# Stevie Nicks :
# « In Your Dreams »
# ( Reprise / Warner )
# På sporet av fortidens magi .
# Et forsøk på å følge opp de to første , drusefine soloalbumene hennes :
# Samt , mer foruroligende , ordene « produced by Dave Stewart » på omslaget .
# Hva verre er :
# Stewart har skrevet mange av melodiene .
# Dumt , all den tid komposisjonene hans på langt nær er like særpregede som hennes .
# Spesielt når hennes , som i tilfellet « Secret Love » , har røtter 35 år tilbake i tid .
# Men når det er fint , er det fint .
# « Soldier's Angel » kunne forsvart en plass på « Tusk » ( 1979 ) .
# BESTE LÅT :
# « Soldier's Angel »
# MORTEN STÅLE NILSEN
# Låt :
# Stay Artist :
# Tooji Komponist : Tooji , Peter Boström og Figge Boström Tekstforfatter : Tooji , Peter Boström og Figge Boström
# Iranskfødte Tooji forsøker godt med et dansbart , orientalsk-inspirert og refrenglett bidrag .
# Arne Lygre går nok en gang dypt inn i menneskelige kjerner
# Essensielle berøringspunkter
# TEATER :
# « Midt i livet er vi i døden » , sier det gamle latinske munnhellet , opprinnelig en verselinje fra et korverk .
# « Media vita in morte sumus » .
# Arne Lygres nyeste tekst sier det like enkelt , like klassisk rent , like poetisk og like minneverdig :
# « Vi er her » .
# Og , i variasjoner over det samme :
# « Nå er vi her » , « Jeg er her » .
# I « La deg være » berører dødsbevisstheten vi-et , så vel som her-et , nå-et og er-et .
# Det handler om bånd mellom mennesker , eller kanskje rettere sagt , om behovet for bånd , behovet for å ha noen å stå nær - koblet med vissheten om at det ikke kommer til å vare .
# En dag vil båndet brytes , enten det skyldes et menneskelig valg eller en død .
# Dette uttrykkes gjennom skjerpede , spissede versjoner av gjenkjennelige menneskelige situasjoner , med analyser og rekonstruksjoner av de emosjoner som hører til .
# Sammenhenger
# Scenene er konsentrater av menneskelighet , og skuespillerne framfører dem med nerve og nyanse .
# Ett og samme utsagn kan ha mange ulike meninger , avhengig av den kontekst det er sagt i , og den måte det er sagt på .
# Hva et ansiktsuttrykk betyr gjennomgår gradvis foranderlige fortolkninger og omfortolkninger .
# Undertekst legges inn i kroppsspråk og i skuespillernes plassering i forhold til hverandre .
# Det er finstemt , og det fører med seg subtile ( og noen mindre subtile , humoristiske ) forskyvninger mellom de ord som sies og de meninger som ligger mellom dem , mellom det som gjøres og det som kunne vært gjort .
# Hver av de fem - Tone Mostraum , Andrine Sæther , Glenn André Kaada , Hanne Skille Reitan og Olav Waastad - er bare tildelt ett rollenavn , men de opptrer alle som ulike personer med ulike forhold til hverandre underveis .
# Handlingen er inndelt i sekvenser , med omdreiningspunkter der den personen som sist uttalte seg går inn i rollen som en annen , og denne andre er alltid en person med tilknytning til det siste som skjedde eller det siste som ble sagt .
# Slik oppløses de enkelte rolleidentitetene , på tvers av kjønn og alder , og det tydeliggjøres hvor fellesmenneskelige erfaringene er , samtidig som alt også viser seg å henge sammen med alt det andre .
# Det finnes alltid berøringspunkter , ett menneskes handlinger og valg påvirker alltid også minst ett annets .
# Noen ganger står to personers opplevelse av en og samme situasjon i konflikt med hverandre , andre ganger utfyller de hverandre til en harmonisk felles sannhet .
# Åpenhet og brudd
# På ett tidspunkt rykkes undertegnede ut av de rom teksten skaper .
# Det er under et ordløst innslag der skuespillerne trekker strømper over hodene , og kler på seg parykker .
# En liten stund svirrer de rundt uten å si noe , før de går tilbake til sine rollefigurer .
# Dette er den ene unntaksscenen i en teateroppsetning som ellers , tross all sin åpenhet , er helhetlig og sterk .
# Rebekka Ringsts scenografi , en skrånende bakke av pressede sponplater , har den samme åpne fleksibiliteten som rolleidentitetene og replikkene .
# Den kan være et svaberg , en brygge , en gate eller en terrasse , men mest er den et forankringspunkt for skiftende mentale landskap , overalt og ingen steder .
# En eminent skribent
# En kunne trodd at 630 sider er i meste laget for en roman , men denne er av en slik karakter at en blir glad for hver eneste en av dem .
# Carsten Jensen er så god skribent at han unngår langhalm og dødperioder ; alt han skriver er meningsbærende for historien .
# Og den er helt rå .
# Men kanskje ikke helt troverdig .
# For hvor sannsynlig er det at en dansk troppssjef hopper av fra det militære oppdraget i Afghanistan , får 13 av sine menn massakrert og driver egen krigføring med skiftende lokale allianser i et slags internettspill — bare for moro ? ? ?
# Men dødsspennende er det.Styrken til Carsten Jensen ligger i tre forhold :
# Han er en eminent litterat som behersker det håndverksmessige til fingerspissene .
# Språket er skrelt til det nødvendigste , likevel billedskapende og flytende deilig .
# Oppdelingen i mange små kapitler med « cliff hangere » gjør den til en page turner .
# Med en usedvanlig innsikt gir Jensen dybdepsykologiske innblikk i tenkningen og dilemmaene til flere av figurene i romanen .
# Refleksjonene til offiseren som forhandler med afghanere i nærmiljøet til den danske militærleiren er alene verd lesningen av boka .
# Her er mye anvendt menneskekunnskap .
# Og så er Jensen en ener i å skrive gode fortellinger .
# Denne gangen skriver han en thriller , en spenningsroman , om danskenes militære engasjement i Afghanistan .
# Tittelen Den første sten har dobbel bunn ; den viser både til barbariske , muslimske tradisjoner , men også til Jesu utsagn om å kaste den første sten , og blir slik en metafor for budskapet i boka :
# Vi , altså Vesten , drar til fjerne sivilisasjoner for å ordne opp og havner i et uoversiktlig kaos der alle potensielt er hverandres fiender , men også allierte .
# Svart / hvit- og snill / slem-tenkningen strekker ikke til for å takle de innviklede forholdene .
# I romanen tvinges danskene til å inngå forbindelser med folk de egentlig er fiender med og er sendt ut for å nedkjempe - lokale krigsherrer og Taliban - for å oppnå høyere mål .
# Og under sånne forhold , hvem kan kaste den første sten ?
# Men sten blir kastet .
# Og blodige blir de .
# Ludacris :
# « Chicken-N-Beer »
# ( Def Jam South / Universal )
# Mer breial ræpp fra sørstatenes mest selvsikre .
# Men hverken beats , flow eller humor holder hele veien til mål her .
# I det hele tatt er « Chicken-N-Beer » oppsiktsvekkende lite oppfinnsom i produksjonen med tanke på hva to andre sørstats-helter nylig kom med , nemlig Outkast .
# Et par kutt hvor snippen henger lovlig løst , « Screwed Up » og « Hoes In My Room » , redder dagen og minner oss om at man ikke alltid skal ta hip hop gravalvorlig .
# Son Volt :
# « The Search »
# ( Legacy / SonyBMG )
# GENRE : ALT. /
# ROCK
# Her tar Farrar steget på mange måter tilbake til den første og beste Son Volt-skiva , « Trace » fra 1995 , selv om de manglende country-innflytelsene på første halvdel ligger mye nærmere R.E.M. og Counting Crows enn noen gang tidligere .
# Mot slutten aner vi imidlertid hvor Jay Farrar kommer fra musikalsk , og det er først her vi gjenkjenner den sterkeste Farrar-signaturen - den som både fans av Uncle Tupelo og tidlig Son Volt vil elske .
# ANBEFALTE KJØP :
# « The Picture » , « Automatic Society » , « Metamphetamine » og « Highways And Cigarettes » .
# Teateranmeldelse :
# « Fulle folk »
# Fylla er en farlig greie .
# De vanlige skjerpede filtre lekker som en sil , og sannheten fosser fram som en flodbølge .
# Dette er essensen i den robust realistiske , velregisserte og underholdende forestillingen « Fulle folk » ; et stykke som raljerer med urban europeisk selvopptatt syting og som inneholder små poetiske perler .
# DET NORSKE TEATRET
# Den russiske dramatiker Vyrypajev har skrevet et stykke som utelukkende handler om folk som er dritings .
# Vi presenteres for ulike settinger der et bredt spekter av samfunnet er representert .
# De har sine koder for sine respektive klaner , men når beruselsen går over til det punkt der hjernen slutter å operere med fornuftens filter , så er de alle i samme bås .
# De er seg selv , bare litt mer seg selv enn vanlig .
# De - eller vi - slipper løs de tanker , idéer , aggresjoner , og sorger som man av ymse årsaker helst ikke lufter offentlig .
# Og behovet for å si sannheten er en av de skumleste farene ved kraft-fylla .
# Dette fremføres alldeles utmerket av ensemblet .
# Å være full i noen timer er en ting , å spille full over lengre tid på en scene , er noe annet .
# Faren for overdrivelse er skyhøy .
# Her balanseres det , med noen unntak , nennsomt Den fysiske slapsticken er rene balletten og viser hvordan kroppskontrollen er på vaklende grunn .
# Replikker og tema tydeliggjøres og det lattervekkende kombineres med beskt alvor .
# Samtalene som føres i de ulike settinger har noe til felles ; det handler om Gud , kjærlighet , hvem vi er og hvordan vi forvalter det hele .
# Er vi små nurk som liker å sause oss inn i all dritten rundt oss ( her er en fornøyelig referanse til den danske filmskaper Lars von Trier ) , klarer vi ikke å mestre hverdagen uten noen små løgner , eller evner vi å se kjærligheten ?
# Store tema og sårbare mennesker - nokså gjenkjennbart det hele .
# Regissøren har lagt vekt på godt ensemblespill .
# Det er flust av fine detaljer , både hos de som er mest i fokus gjennom dialogene , men også hos de som kommer med herlige komikk fra sidelinja .
# I siste del av forestillingen samles tråder , når persongallerier fra første akt møtes i andre settinger .
# Dansefeber av tredje grad
# At denne dansefilmen er i 3D er den eneste nye ingrediensen i « Streetdance 3D » .
# Heldigvis holder det ganske langt .
# Én gruppe dansere liker streetdance .
# En annen liker ballett .
# Sammen må de lære å kombinere kreftene for å slå ut konkurrentene .
# Høres det kjent ut ?
# Kanskje fordi du har sett det ørten ganger før .
# Allerede i 1953 tilpasset Fred Astaire dansestilen til ballett i « The band Wagon » .
# På 80-tallet viste « Flashdance » oss at stilmiks var sexy .
# I « Center Stage » ( 2000 ) måtte balletten jazzes opp for å bli en suksessformel .
# Året etter viste « Save the Last Dance » det samme .
# Og nylig lagde NRK en hel TV-serie , « AF1 » , over temaet .
# Vi har skjønt det allerede :
# Å mikse forskjellige dansestiler er bra .
# Det er likevel gøy å se fusjonen ufolde seg foran deg .
# Ikke minst er det gøy å se det i 3D - hvor dansernes piruetter nesten pirker deg på nesa .
# Selve handlingen er svært banal og forutsigbar - og selvfølgelig bare et påskudd for å vise dans .
# Det er likevel ikke det som trekker denne filmen ned , men de flaue transportetappene mellom dansenumrene .
# Og i en slik sjangerfilm kunne det med fordel vært enda mer dans .
# En sitter også igjen med følelsen av at 3D-teknikkens muligheter kunne vært utnyttet bedre i koreografien : gjerne enda flere føtter i fjeset !
# I tillegg skjemmer dårlig oversettelse de norske tekstene .
# Sjokoladen Kit Kat er blitt til kattemat .
# Det å drille / øve lidenskapen ut av danserne har blitt å banke den ut av dem , og det å være « cheeky » , altså frekk , har blitt til jålete .
# Selv til å være en dansefilm er denne av den overtydelige sorten :
# Igjen lærer man å være seg selv 110 prosent , og fjerde gangen det understrekes at dansegruppa er en familie , har du fått nok .
# Det er lyspunkter i « Streetdance 3D » .
# Den er fylt av spenstige kropper , halsbrekkende hopp og både hjerte og smerte .
# Om du kobler ut hjernen kan øynene bare boltre seg - i partier .
# Men faktum forblir at selv om denne dansefilmen er i 3D , er den litt for ... tja ... flat .
# INGVILL DYBFEST DAHL
# Suveren mørkemannsdisco
# Canadiske Arcade Fire inntar dansegulvet med en av årets beste plater .
# Oppbygningen og veien mot slippet har vært så intens og forventningsfylt at selve platen lå an til å bli en skuffelse .
# Det er da man priser seg lykkelig over at Arcade Fire har laget det som kanskje er et av de mest ambisiøse og storslåtte verkene på denne siden av 2010 .
# Punktum .
# Man vil ikke bli skuffet om man likte « The Suburbs » , platen hvor de vant det kommersielle publikum og mot alle odds endte opp med å få en Grammy-pris .
# Én ting har likevel endret seg :
# « The Reflektor » viser et band som er mer dansbart enn noensinne .
# James Murphy , eks-frontmann i LCD
# Soundsystem og en forkjemper for bass— og trommetung disko , har fungert som produsent på platen .
# Han har definitivt satt dype spor .
# « Afterlife » kan bokstavelig talt sees som en hommage til LCD Soundsystem - likheten er påfallende .
# Kunststykket er at Arcade Fire fortsatt er seg selv , og låter som « We Exist » , « It's Never Over ( Oh Orpheus ) » , « You Already Know » kunne like godt ha dukket opp på en av deres forrige plater .
# Selv når bandet viser frem tydelig inspirasjon fra haitisk ra-ra-musikk på « Here Come The Night Time » , høres det ut som Arcade Fire .
# Bandet har med « The Reflektor » tatt ting til et helt nytt nivå og ærlig talt er jeg bekymret for hvordan de noen gang kan komme til å overgå dette .
# Godkjent retur
# LÅT : PUNKROCK Turboneger « You Give Me Worms » ( Scandinavian Leather / Universal )
# En bra , men ikke fantastisk , omstart .
# Første innspilte turboøyeblikk på fem år føler nok forventningspresset .
# Delvis på grunn av tiden , men mest fordi bandet introduserer ny trommis og - viktigst - ny vokalist .
# Samtlige av disse har alt innfridd live .
# Tommy Akerholdt , bl.a. tidligere rytmemaskin i Serena-Maneesh , gjør bandet strammere og tettere .
# Denne første singelen fra det nært forestående albumet lener seg for øvrig på et riff som er like mye The Hives som ZZ Top , og kan turbokatalogiseres som den harde og mer kompakte lillebroren til « Get It On » .
# Turboneger 4.0 , eller hva man skal kalle dem , er i alle fall godkjent så langt .
# TOR MARTIN BØE
# Fotballtilhengere uten trekkvogn
# Egentlig trodde jeg at livet mitt hadde kommet til det høydepunktet da jeg skulle få se Hege Schøyen spille sex-komedie .
# Det kunne ha ført til at også mennesker med selvinnsikt fikk et avslappa forhold til sin egen prestasjonsevne .
# I stedet er « Andre omgang » en kontinuerlig kommunikasjonskrise .
# Nok en gang har en norsk filmskaper klart å lage en film som ikke bare handler om ingen ting , men dessuten gjør det med dårlige setninger .
# Dårlige setninger er like norsk som puddelbunader og ketchupgrisete pølseservietter .
# Norske setningsprodusenter har lett for å late som om innholdet skal ligge innimellom , og halve litteraturen består av beskrivelser uten egentlig forstand :
# « Det var første gang hun tok på seg selv ; lot hånden bli liggende på låret .
# Så reinsdyrene i tapetet .
# Hva tenker de nå ?
# Lav kveldssol . »
# Setningene i « Andre omgang » er ikke litterære , men de er boklige i den forstand at de ikke forsøker å kommunisere .
# Schøyen og Johannes Joner spiller et merkelig oppfunnet ektepar i 46 års alderen , og etter en farseaktig beskrivelse av hennes kreftangst , vandrer filmen ut i den uforløste forstadserotikkens banale grenseland , og der skjer det dummere ting enn i Nettavisens Aylar-journalistikk .
# Bror hans flytter hjemmefra etter at kona har skreket om den nye kjærestens analsex til sine små døtre i en scene som er så utillatelig logikk-skeiv at den burde ført til unntakstilstand på apoteket :
# Stå klar med pille og vann , her kommer en norsk manusforfatter !
# Den tredje fotballtilhengeren er brødrenes pappa Baard Owe som vandrer rundt som en bauta over de eldres absolutte humørløshet og er latterlig i veien for alt .
# Aftenbladets journalister har naturlig nok henlagt høstfesten sin til pensjonistbula Skipper Worse , så avisa har spisskompetanse på gamle menneskers festlighet .
# Dette kan vi .
# Hovedpoenget er at de tre mennene holder lidenskapelig med Skeid .
# Nå er det antakelig flere som var der da enhjørningene parret seg enn de som så Skeid spille fotball , men likevel :
# Så sære som dette er ikke engang folk med Johannes Joners hakeskjegg .

# %% [markdown]
# From these last three test we see that oure data is orginized in lists of dictionaries, so the "data" variable is a dictionary of lists of dictionaries.

# %% [markdown]
# Using bag of words to orginize method to orginize the text into easaly computable vectors

# %%
text_3class = {'train':[x['text'] for x in data_3class['train']], 
               'test':[x['text'] for x in data_3class['test']]}

labels_3class ={'train':[x['label'] for x in data_3class['train']],
                'test':[x['label'] for x in data_3class['test']]}

# %% [markdown]
# as the original data comes in dictionaries of lists of reviews which are also dictionaries, we chose to re structure the data for our own purposes

# %%
print(labels_3class['train'])
# Out:
# ['Neutral', 'Neutral', 'Negative', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Positive', 'Neutral', 'Neutral', 'Positive', 'Neutral', 'Neutral', 'Neutral', 'Positive', 'Neutral', 'Neutral', 'Negative', 'Neutral', 'Positive', 'Positive', 'Positive', 'Positive', 'Negative', 'Positive', 'Positive', 'Negative', 'Neutral', 'Neutral', 'Neutral', 'Negative', 'Negative', 'Neutral', 'Negative', 'Neutral', 'Positive', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Positive', 'Positive', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Positive', 'Neutral', 'Positive', 'Neutral', 'Neutral', 'Positive', 'Neutral', 'Positive', 'Positive', 'Negative', 'Neutral', 'Neutral', 'Negative', 'Neutral', 'Negative', 'Positive', 'Negative', 'Neutral', 'Positive', 'Positive', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Negative', 'Neutral', 'Neutral', 'Negative', 'Neutral', 'Neutral', 'Neutral', 'Positive', 'Neutral', 'Neutral', 'Positive', 'Negative', 'Neutral', 'Negative', 'Positive', 'Neutral', 'Neutral', 'Neutral', 'Negative', 'Neutral', 'Neutral', 'Negative', 'Negative', 'Neutral', 'Negative', 'Negative', 'Positive', 'Neutral', 'Neutral', 'Negative', 'Negative', 'Neutral', 'Neutral', 'Neutral', 'Positive', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Positive', 'Positive', 'Neutral', 'Negative', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Positive', 'Positive', 'Neutral', 'Negative', 'Positive', 'Positive', 'Positive', 'Positive', 'Negative', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Negative', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Positive', 'Positive', 'Positive', 'Neutral', 'Neutral', 'Positive', 'Neutral', 'Neutral', 'Neutral', 'Positive', 'Negative', 'Neutral', 'Negative', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Positive', 'Positive', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Negative', 'Neutral', 'Positive', 'Negative', 'Neutral', 'Neutral', 'Neutral', 'Positive', 'Neutral', 'Neutral', 'Positive', 'Neutral', 'Neutral', 'Positive', 'Negative', 'Negative', 'Positive', 'Positive', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Positive', 'Positive', 'Positive', 'Positive', 'Positive', 'Neutral', 'Positive', 'Positive', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Positive', 'Positive', 'Positive', 'Positive', 'Positive', 'Positive', 'Positive', 'Neutral', 'Positive', 'Neutral', 'Positive', 'Positive', 'Neutral', 'Positive', 'Positive', 'Positive', 'Positive', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Positive', 'Neutral', 'Neutral', 'Positive', 'Neutral', 'Positive', 'Neutral', 'Positive', 'Positive', 'Negative', 'Neutral', 'Positive', 'Positive', 'Positive', 'Neutral', 'Neutral', 'Positive', 'Neutral', 'Positive', 'Positive', 'Positive', 'Positive', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Positive', 'Positive', 'Positive', 'Positive', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Positive', 'Positive', 'Neutral', 'Neutral', 'Neutral', 'Positive', 'Positive', 'Positive', 'Neutral', 'Positive', 'Positive', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Positive', 'Positive', 'Neutral', 'Neutral', 'Neutral', 'Positive', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Negative', 'Neutral', 'Neutral', 'Negative', 'Neutral', 'Neutral', 'Positive', 'Neutral', 'Neutral', 'Positive', 'Neutral', 'Neutral', 'Neutral', 'Positive', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Positive', 'Negative', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Neutral', 'Positive', 'Positive', 'Neutral', 'Neutral', 'Neutral', 'N ...

# %% [markdown]
# Notice there are a lot of neutral values

# %%
def lemmatizer(list_sentc:list, nlp:spacy, stop:list)->list:
    """takes a list of sentences and returns a list of lemmatized sentences

    Args:
        list_sentc (list): sentences

    Returns:
        list: lemmatized sentences
    """
    result = []
    for sentence in list_sentc:
        doc = nlp(sentence.lower())
        result.append(' '.join([token.lemma_ for token in doc if token.lemma_ not in stop]))

    return result

# %%
nb_nlp = {'smal': spacy.load('nb_core_news_sm'), 'medium': spacy.load('nb_core_news_md'), 'large':spacy.load('nb_core_news_lg')}

# %% [markdown]
# lemmatizer is reducing the complexity of the text by turning words into their base form also known as lemma, here i test 3 different sizes of norwegian laguage models to lemmatize, later i wil see the difference in accuracy between them.

# %%
file_1 = open('stopwords-no.json')
file_2 = open('stopwords_nb.txt')
no_stop = {'short': file_2.read().split('\n'), 'long':json.load(file_1)}

print(no_stop['short'][:50], no_stop['long'][:50])
# Out:
# ['alle', 'andre', 'arbeid', 'av', 'begge', 'bort', 'bra', 'bruke', 'da', 'denne', 'der', 'deres', 'det', 'din', 'disse', 'du', 'eller', 'en', 'ene', 'eneste', 'enhver', 'enn', 'er', 'et', 'folk', 'for', 'fordi', 'forsÛke', 'fra', 'fÅ', 'fÛr', 'fÛrst', 'gjorde', 'gjÛre', 'god', 'gÅ', 'ha', 'hadde', 'han', 'hans', 'hennes', 'her', 'hva', 'hvem', 'hver', 'hvilken', 'hvis', 'hvor', 'hvordan', 'hvorfor'] ['alle', 'andre', 'arbeid', 'at', 'av', 'bare', 'begge', 'ble', 'blei', 'bli', 'blir', 'blitt', 'bort', 'bra', 'bruke', 'både', 'båe', 'da', 'de', 'deg', 'dei', 'deim', 'deira', 'deires', 'dem', 'den', 'denne', 'der', 'dere', 'deres', 'det', 'dette', 'di', 'din', 'disse', 'ditt', 'du', 'dykk', 'dykkar', 'då', 'eg', 'ein', 'eit', 'eitt', 'eller', 'elles', 'en', 'ene', 'eneste', 'enhver']

# %%
text = text_3class['train']

test_sm = TfidfVectorizer(use_idf=False).fit(lemmatizer(text, nb_nlp['smal']))
test_md = TfidfVectorizer(use_idf=False).fit(lemmatizer(text, nb_nlp['medium']))
test_lg = TfidfVectorizer(use_idf=False).fit(lemmatizer(text, nb_nlp['large']))
compare = TfidfVectorizer(use_idf=False).fit(text)

print('smal norgwegian model pecent remove:', 1-len(test_sm.get_feature_names_out())/len(compare.get_feature_names_out()))
print('medium norgwegian model pecent remove:', 1-len(test_md.get_feature_names_out())/len(compare.get_feature_names_out()))
print('large norgwegian model pecent remove:', 1-len(test_lg.get_feature_names_out())/len(compare.get_feature_names_out()))
# Out:
# smal norgwegian model pecent remove: 0.18522612582304032
# medium norgwegian model pecent remove: 0.1933483923679531
# large norgwegian model pecent remove: 0.20137453741529288

# %% [markdown]
# only removing about 20% of words with the largest model seems a bit low considdering the possible number of forms for nowegian word

# %%
pipe = Pipeline([('vect', TfidfVectorizer()),
                ('clf', MultinomialNB())])

parameters = {'clf__alpha': [0.01, 0.1, 1],
              'vect__use_idf': [True, False],
              'vect__ngram_range': [(1,1), (1,2), (1,3)]}

# differing complexity data might require different methods, 
# therefore i use grid search to find the best parameters for each set of data that has been lematized in differente ways
text = text_3class['train'] + text_3class['test']
labels = labels_3class['train'] + labels_3class ['test']

grid = GridSearchCV(pipe, parameters, n_jobs=-1)
grid.fit(text, labels)

print('Best parameters:', grid.best_params_)
print('Best score:', grid.best_score_)
print('Size of model: none')
print('Size of stopword list: none')

for model in nb_nlp:
    grid = GridSearchCV(pipe, parameters, n_jobs=-1)
    grid.fit(text, labels)

    print('Best parameters:', grid.best_params_)
    print('Best score:', grid.best_score_)
    print('Size of model:', model)
    print('Size of stopword list: none')

    for stop in no_stop:
        text = lemmatizer(text, nb_nlp[model], no_stop[stop])

        grid = GridSearchCV(pipe, parameters, n_jobs=-1)
        grid.fit(text, labels)

        print('Best parameters:', grid.best_params_)
        print('Best score:', grid.best_score_)
        print('Size of model:', model)
        print('Size of stopword list:', stop)
# Out:
# Best parameters: {'clf__alpha': 0.1, 'vect__ngram_range': (1, 1), 'vect__use_idf': False}
# Best score: 0.6159053698746243
# Size of model: none
# Size of stopword list: none
# Best parameters: {'clf__alpha': 0.1, 'vect__ngram_range': (1, 1), 'vect__use_idf': False}
# Best score: 0.5971150167276981
# Size of model: smal
# Size of stopword list: short
# Best parameters: {'clf__alpha': 0.1, 'vect__ngram_range': (1, 2), 'vect__use_idf': False}
# Best score: 0.5978803424925314
# Size of model: smal
# Size of stopword list: long
# Best parameters: {'clf__alpha': 0.1, 'vect__ngram_range': (1, 2), 'vect__use_idf': False}
# Best score: 0.5989722239631364
# Size of model: medium
# Size of stopword list: short
# Best parameters: {'clf__alpha': 0.1, 'vect__ngram_range': (1, 2), 'vect__use_idf': False}
# Best score: 0.597552055820672
# Size of model: medium
# Size of stopword list: long
# Best parameters: {'clf__alpha': 0.1, 'vect__ngram_range': (1, 2), 'vect__use_idf': False}
# Best score: 0.599190564444166
# Size of model: large
# Size of stopword list: short
# Best parameters: {'clf__alpha': 0.1, 'vect__ngram_range': (1, 2), 'vect__use_idf': False}
# Best score: 0.5995183139196533
# Size of model: large
# Size of stopword list: long

# %% [markdown]
# output:
# ```
# Best parameters: {'clf__alpha': 0.1, 'vect__ngram_range': (1, 1), 'vect__use_idf': False}
# Best score: 0.5971150167276981
# Size of model: smal
# Size of stopword list: short
# Best parameters: {'clf__alpha': 0.1, 'vect__ngram_range': (1, 2), 'vect__use_idf': False}
# Best score: 0.5978803424925314
# Size of model: smal
# Size of stopword list: long
# Best parameters: {'clf__alpha': 0.1, 'vect__ngram_range': (1, 2), 'vect__use_idf': False}
# Best score: 0.5989722239631364
# Size of model: medium
# Size of stopword list: short
# Best parameters: {'clf__alpha': 0.1, 'vect__ngram_range': (1, 2), 'vect__use_idf': False}
# Best score: 0.597552055820672
# Size of model: medium
# Size of stopword list: long
# Best parameters: {'clf__alpha': 0.1, 'vect__ngram_range': (1, 2), 'vect__use_idf': False}
# Best score: 0.599190564444166
# Size of model: large
# Size of stopword list: short
# Best parameters: {'clf__alpha': 0.1, 'vect__ngram_range': (1, 2), 'vect__use_idf': False}
# Best score: 0.5995183139196533
# Size of model: large
# Size of stopword list: long
# ```
# here we se that the large language model with the long stopword list gives us the highest acuracy after preprocessing, word counts are better than word weights for the moddel, and we don't gain performans from ngrams larger than 2.

# %%
pipe = Pipeline([('vect', TfidfVectorizer(ngram_range=(1,2), use_idf=False)),
                ('clf', MultinomialNB())])

alphas = [round(x, 3) for x in arange(0.01, 0.16, 0.01)]
# every number between 0.1 and 0.01 with a difference of 0.01

parameters = {'clf__alpha': alphas}

text = text_3class['train']+text_3class['test']
text = lemmatizer(text, nb_nlp['medium'])

labes = labels_3class['train']+text_3class['test']

grid = GridSearchCV(pipe, parameters, n_jobs=-1)
grid.fit(text, labels)

print(grid.best_score_, grid.best_params_)
# Out:
# 0.621476454384567 {'clf__alpha': 0.1}

# %% [markdown]
# same best alpha, but the model performes slightly better, this is probably because i did not lemmatize the test data, the better performance is therefore the moddel generelizing better because the training data is different from the test data, we don't actualy want this, because the better performance is not due to a better rather a model that predicts more randomly

# %%
pipe = Pipeline([('vect', TfidfVectorizer(ngram_range=(1,2), use_idf=False)),
                ('clf', MultinomialNB(alpha=0.1))])

text = lemmatizer(text_3class['train'], nb_nlp['medium'])

pipe.fit(text, labels_3class['train'])

prediction = pipe.predict(text_3class['test'])

conf_matrix = confusion_matrix(prediction, labels_3class['test'], labels=['Positive', 'Neutral', 'Negative'])

matrix = pandas.DataFrame(conf_matrix, index= ['Positive', 'Neutral', 'Negative'], columns=['Positive', 'Neutral', 'Negative'])

print(matrix)
# Out:
#           Positive  Neutral  Negative
# Positive       131       73        36
# Neutral        268      518       137
# Negative         2        7         9

# %% [markdown]
# rows are the true value, whil the columns are what MultinomialNB predicted. we see that multinomialNB is bad at detecting negative sentiment, it predicts sentiment as neutral when it should be negative, this can be due to using word count in oure vectors instead of word weight.

# %%
pipe = Pipeline([('vect', TfidfVectorizer(ngram_range=(1,2))),
                ('clf', MultinomialNB(alpha=0.1))])

text = lemmatizer(text_3class['train'], nb_nlp['medium'])

pipe.fit(text, labels_3class['train'])

prediction = pipe.predict(text_3class['test'])

conf_matrix = confusion_matrix(prediction, labels_3class['test'], labels=['Positive', 'Neutral', 'Negative'])

matrix = pandas.DataFrame(conf_matrix, index= ['Positive', 'Neutral', 'Negative'], columns=['Positive', 'Neutral', 'Negative'])

print(matrix)
# Out:
#           Positive  Neutral  Negative
# Positive       153       90        40
# Neutral        243      496       123
# Negative         5       12        19

# %% [markdown]
# we see that it get's better at predicting negative and positive sentiment but not neutral. we might be limited by oure classifier.

# %%
pipe = Pipeline([('vect', TfidfVectorizer()),
                ('clf', BernoulliNB())])

parameters = {'clf__alpha': [0.01, 0.001, 0.1, 1],
              'vect__use_idf': [True, False],
              'vect__ngram_range': [(1,1), (1,2), (1,3)]}

text = text_3class['train'] + text_3class['test']
labels = labels_3class['train'] + labels_3class ['test']

print('Best parameters:', grid.best_params_)
print('Best score:', grid.best_score_)
print('Size of model: none')
print('Size of stopword list: none')

for model in nb_nlp:
    for stop in no_stop:
        text = lemmatizer(text, nb_nlp[model], no_stop[stop])

        grid = GridSearchCV(pipe, parameters, n_jobs=-1)
        grid.fit(text, labels)

        print('Best parameters:', grid.best_params_)
        print('Best score:', grid.best_score_)
        print('Size of model:', model)
        print('Size of stopword list:', stop)
# Out:
# Best parameters: {'clf__alpha': 0.1, 'vect__ngram_range': (1, 2), 'vect__use_idf': False}
# Best score: 0.5995183139196533
# Size of model: none
# Size of stopword list: none
# Best parameters: {'clf__alpha': 0.1, 'vect__ngram_range': (1, 1), 'vect__use_idf': True}
# Best score: 0.5934006022568217
# Size of model: smal
# Size of stopword list: short
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[24], line 21
#      18 text = lemmatizer(text, nb_nlp[model], no_stop[stop])
#      20 grid = GridSearchCV(pipe, parameters, n_jobs=-1)
# ---> 21 grid.fit(text, labels)
#      23 print('Best parameters:', grid.best_params_)
#      24 print('Best score:', grid.best_score_)
#
# File ~/.local/lib/python3.10/site-packages/sklearn/model_selection/_search.py:874, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     868     results = self._format_results(
#     869         all_candidate_params, n_splits, all_out, all_more_results
#     870     )
#     872     return results
# --> 874 self._run_search(evaluate_candidates)
#     876 # multimetric is determined here because in the case of a callable
#     877 # self.scoring the return type is only known after calling
#     878 first_test_score = all_out[0]["test_scores"]
#
# File ~/.local/lib/python3.10/site-packages/sklearn/model_selection/_search.py:1388, in GridSearchCV._run_search(self, evaluate_candidates)
#    1386 def _run_search(self, evaluate_candidates):
#    1387     """Search all candidates in param_grid"""
# -> 1388     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File ~/.local/lib/python3.10/site-packages/sklearn/model_selection/_search.py:821, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     813 if self.verbose > 0:
#     814     print(
#     815         "Fitting {0} folds for each of {1} candidates,"
#     816         " totalling {2} fits".format(
#     817             n_splits, n_candidates, n_candidates * n_splits
#     818         )
#     819     )
# --> 821 out = parallel(
#     822     delayed(_fit_and_score)(
#     823         clone(base_estimator),
#     824         X,
#     825         y,
#     826         train=train,
#     827         test=test,
#     828         parameters=parameters,
#     829         split_progress=(split_idx, n_splits),
#     830         candidate_progress=(cand_idx, n_candidates),
#     831         **fit_and_score_kwargs,
#     832     )
#     833     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     834         enumerate(candidate_params), enumerate(cv.split(X, y, groups))
#     835     )
#     836 )
#     838 if len(out) < 1:
#     839     raise ValueError(
#     840         "No fits were performed. "
#     841         "Was the CV iterator empty? "
#     842         "Were there no candidates?"
#     843     )
#
# File ~/.local/lib/python3.10/site-packages/sklearn/utils/parallel.py:63, in Parallel.__call__(self, iterable)
#      58 config = get_config()
#      59 iterable_with_config = (
#      60     (_with_config(delayed_func, config), args, kwargs)
#      61     for delayed_func, args, kwargs in iterable
#      62 )
# ---> 63 return super().__call__(iterable_with_config)
#
# File ~/.local/lib/python3.10/site-packages/joblib/parallel.py:1098, in Parallel.__call__(self, iterable)
#    1095     self._iterating = False
#    1097 with self._backend.retrieval_context():
# -> 1098     self.retrieve()
#    1099 # Make sure that we get a last message telling us we are done
#    1100 elapsed_time = time.time() - self._start_time
#
# File ~/.local/lib/python3.10/site-packages/joblib/parallel.py:975, in Parallel.retrieve(self)
#     973 try:
#     974     if getattr(self._backend, 'supports_timeout', False):
# --> 975         self._output.extend(job.get(timeout=self.timeout))
#     976     else:
#     977         self._output.extend(job.get())
#
# File ~/.local/lib/python3.10/site-packages/joblib/_parallel_backends.py:567, in LokyBackend.wrap_future_result(future, timeout)
#     564 """Wrapper for Future.result to implement the same behaviour as
#     565 AsyncResults.get from multiprocessing."""
#     566 try:
# --> 567     return future.result(timeout=timeout)
#     568 except CfTimeoutError as e:
#     569     raise TimeoutError from e
#
# File /usr/lib/python3.10/concurrent/futures/_base.py:453, in Future.result(self, timeout)
#     450 elif self._state == FINISHED:
#     451     return self.__get_result()
# --> 453 self._condition.wait(timeout)
#     455 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#     456     raise CancelledError()
#
# File /usr/lib/python3.10/threading.py:320, in Condition.wait(self, timeout)
#     318 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     319     if timeout is None:
# --> 320         waiter.acquire()
#     321         gotit = True
#     322     else:
#
# KeyboardInterrupt:

# %% [markdown]
# BernoulliNB performed slightly worse

# %%
pipe = Pipeline([('vect', TfidfVectorizer(ngram_range=(1,2))),
                ('clf', BernoulliNB(alpha=0.1))])

text = lemmatizer(text_3class['train'], nb_nlp['medium'])

pipe.fit(text, labels_3class['train'])

prediction = pipe.predict(text_3class['test'])

conf_matrix = confusion_matrix(prediction, labels_3class['test'], labels=['Positive', 'Neutral', 'Negative'])

matrix = pandas.DataFrame(conf_matrix, index= ['Positive', 'Neutral', 'Negative'], columns=['Positive', 'Neutral', 'Negative'])

print(matrix)
# Out:
#           Positive  Neutral  Negative
# Positive        84       34        20
# Neutral        308      557       148
# Negative         9        7        14

# %% [markdown]
# even less accurate at predicting sentiment, it seems like the neutral values are being predicted falsly as positive or negative.

# %% [markdown]
# the two linear models are proably bad at predicting neutral values because they try to draw a plane, and the line is not "curvy" enough, to fix this, let's try reducing oure alpha/normalization

# %%
pipe = Pipeline([('vect', TfidfVectorizer(ngram_range=(1,2))),
                ('clf', BernoulliNB(alpha=0.000001))])

text = lemmatizer(text_3class['train'], nb_nlp['medium'])

pipe.fit(text, labels_3class['train'])

prediction = pipe.predict(text_3class['test'])

conf_matrix = confusion_matrix(prediction, labels_3class['test'], labels=['Positive', 'Neutral', 'Negative'])

matrix = pandas.DataFrame(conf_matrix, index= ['Positive', 'Neutral', 'Negative'], columns=['Positive', 'Neutral', 'Negative'])

print(matrix)
# Out:
#           Positive  Neutral  Negative
# Positive       163      104        64
# Neutral        221      461        91
# Negative        17       33        27

# %% [markdown]
# ass we see with the example of an extremly small alpa/almost no normalization, we classify the positive and negative values better but overall we are less accurate(the predicted sentiment is more spread out), and as explained erlier this is not something we want

# %% [markdown]
# Random forest classifier uses decisiton trees, it makes multiple trees that each try to classify the data and then it takes the result of each tree weighted with the probability of the classification to be true and finds the moste probable answere. since it makes decision trees it is not limited by "curvynes" or the fact that there are "islands" of data in the two dimetional field, but this unlimited ability to seperate the field of values also makes it more vonurable to over fitting

# %%
pipe = Pipeline([('vect', TfidfVectorizer()),
                ('clf', RandomForestClassifier(n_jobs=-1, n_estimators=100))])

parameters = {'clf__max_depth': [10, 100, None],
              'vect__use_idf': [True, False],
              'vect__ngram_range': [(1,1), (1,2), (1,3)]}

text = text_3class['train'] + text_3class['test']
labels = labels_3class['train'] + labels_3class ['test']

grid = GridSearchCV(pipe, parameters, n_jobs=-1)
grid.fit(text, labels)

print('Best parameters:', grid.best_params_)
print('Best score:', grid.best_score_)
print('Size of model: none')
print('Size of stopword list: none')

for model in nb_nlp:
    for stop in no_stop:
        text = lemmatizer(text, nb_nlp[model], no_stop[stop])

        grid = GridSearchCV(pipe, parameters, n_jobs=-1)
        grid.fit(text, labels)

        print('Best parameters:', grid.best_params_)
        print('Best score:', grid.best_score_)
        print('Size of model:', model)
        print('Size of stopword list:', stop)
# Out:
# Best parameters: {'clf__max_depth': None, 'vect__ngram_range': (1, 1), 'vect__stop_words': ['alle', 'andre', 'arbeid', 'at', 'av', 'bare', 'begge', 'ble', 'blei', 'bli', 'blir', 'blitt', 'bort', 'bra', 'bruke', 'både', 'båe', 'da', 'de', 'deg', 'dei', 'deim', 'deira', 'deires', 'dem', 'den', 'denne', 'der', 'dere', 'deres', 'det', 'dette', 'di', 'din', 'disse', 'ditt', 'du', 'dykk', 'dykkar', 'då', 'eg', 'ein', 'eit', 'eitt', 'eller', 'elles', 'en', 'ene', 'eneste', 'enhver', 'enn', 'er', 'et', 'ett', 'etter', 'folk', 'for', 'fordi', 'forsûke', 'fra', 'få', 'før', 'fûr', 'fûrst', 'gjorde', 'gjûre', 'god', 'gå', 'ha', 'hadde', 'han', 'hans', 'har', 'hennar', 'henne', 'hennes', 'her', 'hjå', 'ho', 'hoe', 'honom', 'hoss', 'hossen', 'hun', 'hva', 'hvem', 'hver', 'hvilke', 'hvilken', 'hvis', 'hvor', 'hvordan', 'hvorfor', 'i', 'ikke', 'ikkje', 'ingen', 'ingi', 'inkje', 'inn', 'innen', 'inni', 'ja', 'jeg', 'kan', 'kom', 'korleis', 'korso', 'kun', 'kunne', 'kva', 'kvar', 'kvarhelst', 'kven', 'kvi', 'kvifor', 'lage', 'lang', 'lik', 'like', 'makt', 'man', 'mange', 'me', 'med', 'medan', 'meg', 'meget', 'mellom', 'men', 'mens', 'mer', 'mest', 'mi', 'min', 'mine', 'mitt', 'mot', 'mye', 'mykje', 'må', 'måte', 'navn', 'ned', 'nei', 'no', 'noe', 'noen', 'noka', 'noko', 'nokon', 'nokor', 'nokre', 'ny', 'nå', 'når', 'og', 'også', 'om', 'opp', 'oss', 'over', 'part', 'punkt', 'på', 'rett', 'riktig', 'samme', 'sant', 'seg', 'selv', 'si', 'sia', 'sidan', 'siden', 'sin', 'sine', 'sist', 'sitt', 'sjøl', 'skal', 'skulle', 'slik', 'slutt', 'so', 'som', 'somme', 'somt', 'start', 'stille', 'så', 'sånn', 'tid', 'til', 'tilbake', 'tilstand', 'um', 'under', 'upp', 'ut', 'uten', 'var', 'vart', 'varte', 'ved', 'verdi', 'vere', 'verte', 'vi', 'vil', 'ville', 'vite', 'vore', 'vors', 'vort', 'vår', 'være', 'vært', 'vöre', 'vört', 'å'], 'vect__use_idf': False}
# Score: 0.6008298490179752
# Size of model: smal
# Best parameters: {'clf__max_depth': None, 'vect__ngram_range': (1, 1), 'vect__stop_words': ['alle', 'andre', 'arbeid', 'at', 'av', 'bare', 'begge', 'ble', 'blei', 'bli', 'blir', 'blitt', 'bort', 'bra', 'bruke', 'både', 'båe', 'da', 'de', 'deg', 'dei', 'deim', 'deira', 'deires', 'dem', 'den', 'denne', 'der', 'dere', 'deres', 'det', 'dette', 'di', 'din', 'disse', 'ditt', 'du', 'dykk', 'dykkar', 'då', 'eg', 'ein', 'eit', 'eitt', 'eller', 'elles', 'en', 'ene', 'eneste', 'enhver', 'enn', 'er', 'et', 'ett', 'etter', 'folk', 'for', 'fordi', 'forsûke', 'fra', 'få', 'før', 'fûr', 'fûrst', 'gjorde', 'gjûre', 'god', 'gå', 'ha', 'hadde', 'han', 'hans', 'har', 'hennar', 'henne', 'hennes', 'her', 'hjå', 'ho', 'hoe', 'honom', 'hoss', 'hossen', 'hun', 'hva', 'hvem', 'hver', 'hvilke', 'hvilken', 'hvis', 'hvor', 'hvordan', 'hvorfor', 'i', 'ikke', 'ikkje', 'ingen', 'ingi', 'inkje', 'inn', 'innen', 'inni', 'ja', 'jeg', 'kan', 'kom', 'korleis', 'korso', 'kun', 'kunne', 'kva', 'kvar', 'kvarhelst', 'kven', 'kvi', 'kvifor', 'lage', 'lang', 'lik', 'like', 'makt', 'man', 'mange', 'me', 'med', 'medan', 'meg', 'meget', 'mellom', 'men', 'mens', 'mer', 'mest', 'mi', 'min', 'mine', 'mitt', 'mot', 'mye', 'mykje', 'må', 'måte', 'navn', 'ned', 'nei', 'no', 'noe', 'noen', 'noka', 'noko', 'nokon', 'nokor', 'nokre', 'ny', 'nå', 'når', 'og', 'også', 'om', 'opp', 'oss', 'over', 'part', 'punkt', 'på', 'rett', 'riktig', 'samme', 'sant', 'seg', 'selv', 'si', 'sia', 'sidan', 'siden', 'sin', 'sine', 'sist', 'sitt', 'sjøl', 'skal', 'skulle', 'slik', 'slutt', 'so', 'som', 'somme', 'somt', 'start', 'stille', 'så', 'sånn', 'tid', 'til', 'tilbake', 'tilstand', 'um', 'under', 'upp', 'ut', 'uten', 'var', 'vart', 'varte', 'ved', 'verdi', 'vere', 'verte', 'vi', 'vil', 'ville', 'vite', 'vore', 'vors', 'vort', 'vår', 'være', 'vært', 'vöre', 'vört', 'å'], 'vect__use_idf': False}
# Score: 0.6029053370459572
# Size of model: medium
# Best parameters: {'clf__max_depth': None, 'vect__ngram_range': (1, 1), 'vect__stop_words': ['alle', 'andre', 'arbeid', 'at', 'av', 'bare', 'begge', 'ble', 'blei', 'bli', 'blir', 'blitt', 'bort', 'bra', 'bruke', 'både', 'båe', 'da', 'de', 'deg', 'dei', 'deim', 'deira', 'deires', 'dem', 'den', 'denne', 'der', 'dere', 'deres', 'det', 'dette', 'di', 'din', 'disse', 'ditt', 'du', 'dykk', 'dykkar', 'då', 'eg', 'ein', 'eit', 'eitt', 'eller', 'elles', 'en', 'ene', 'eneste', 'enhver', 'enn', 'er', 'et', 'ett', 'etter', 'folk', 'for', 'fordi', 'forsûke', 'fra', 'få', 'før', 'fûr', 'fûrst', 'gjorde', 'gjûre', 'god', 'gå', 'ha', 'hadde', 'han', 'hans', 'har', 'hennar', 'henne', 'hennes', 'her', 'hjå', 'ho', 'hoe', 'honom', 'hoss', 'hossen', 'hun', 'hva', 'hvem', 'hver', 'hvilke', 'hvilken', 'hvis', 'hvor', 'hvordan', 'hvorfor', 'i', 'ikke', 'ikkje', 'ingen', 'ingi', 'inkje', 'inn', 'innen', 'inni', 'ja', 'jeg', 'kan', 'kom', 'korleis', 'korso', 'kun', 'kunne', 'kva', 'kvar', 'kvarhelst', 'kven', 'kvi', 'kvifor', 'lage', 'lang', 'lik', 'like', 'makt', 'man', 'mange', 'me', 'med', 'medan', 'meg', 'meget', 'mellom', 'men', 'mens', 'mer', 'mest', 'mi', 'min', 'mine', 'mitt', 'mot', 'mye', 'mykje', 'må', 'måte', 'navn', 'ned', 'nei', 'no', 'noe', 'noen', 'noka', 'noko', 'nokon', 'nokor', 'nokre', 'ny', 'nå', 'når', 'og', 'også', 'om', 'opp', 'oss', 'over', 'part', 'punkt', 'på', 'rett', 'riktig', 'samme', 'sant', 'seg', 'selv', 'si', 'sia', 'sidan', 'siden', 'sin', 'sine', 'sist', 'sitt', 'sjøl', 'skal', 'skulle', 'slik', 'slutt', 'so', 'som', 'somme', 'somt', 'start', 'stille', 'så', 'sånn', 'tid', 'til', 'tilbake', 'tilstand', 'um', 'under', 'upp', 'ut', 'uten', 'var', 'vart', 'varte', 'ved', 'verdi', 'vere', 'verte', 'vi', 'vil', 'ville', 'vite', 'vore', 'vors', 'vort', 'vår', 'være', 'vært', 'vöre', 'vört', 'å'], 'vect__use_idf': True}
# Score: 0.6031249906736741
# Size of model: large

# %% [markdown]
# output:
# ```
# Best parameters: {'clf__max_depth': None, 'vect__ngram_range': (1, 1), 'vect__stop_words': no_stop, 'vect__use_idf': False}
# Score: 0.6008298490179752
# Size of model: smal
# Best parameters: {'clf__max_depth': None, 'vect__ngram_range': (1, 1), 'vect__stop_words': no_stop, 'vect__use_idf': False}
# Score: 0.6029053370459572
# Size of model: medium
# Best parameters: {'clf__max_depth': None, 'vect__ngram_range': (1, 1), 'vect__stop_words': no_stop, 'vect__use_idf': True}
# Score: 0.6031249906736741
# Size of model: large
# ```

# %% [markdown]
# random forest seems to perform best with very preprossesed data, this might be because it generates more "usefull" trees if the data only includes the most usefull words. it also performes better than anny of the linear models, let's try with a larger amount of estimators now that we are not looking for the best parameters.

# %%
pipe = Pipeline([('vect', TfidfVectorizer(ngram_range=(1,1), stop_words=no_stop)),
                ('clf', RandomForestClassifier(n_jobs=-1))])

parameters = {'clf__n_estimators': [100, 300, 500, 700, 1000]}

text = text_3class['train']+text_3class['test']
text = lemmatizer(text, nb_nlp['large'])

labels = labels_3class['train'] + labels_3class['test']

grid = GridSearchCV(pipe, parameters, n_jobs=-1)
grid.fit(text, labels)

print('Score:', grid.best_score_, 'Best parms:', grid.best_params_)
# Out:
# Score: 0.6003926905480299 Best parms: {'clf__n_estimators': 1000}

# %% [markdown]
# out:
# ```
# Score: 0.6003926905480299 Best parms: {'clf__n_estimators': 1000}
# ```

# %%
pipe = Pipeline([('vect', TfidfVectorizer(ngram_range=(1,1), stop_words=no_stop)),
                ('clf', RandomForestClassifier(n_jobs=-1))])

parameters = {'clf__n_estimators': [1000, 1500, 2000]}

text = text_3class['train']+text_3class['test']
text = lemmatizer(text, nb_nlp['large'])

labels = labels_3class['train'] + labels_3class['test']

grid = GridSearchCV(pipe, parameters, n_jobs=-1)
grid.fit(text, labels)

print('Score:', grid.best_score_, 'Best parms:', grid.best_params_)
# Out:
# Score: 0.6000647023185992 Best parms: {'clf__n_estimators': 1000}

# %% [markdown]
# i don't know why we gett lower acuracy, it is probably a quirk of how i programmed the model differently (with the optimal parameters). the best number of estimators seems to be 1000

# %%
pipe = Pipeline([('vect', TfidfVectorizer(ngram_range=(1,1), stop_words=no_stop)),
                ('clf', RandomForestClassifier(n_jobs=-1, n_estimators=10000))])

text = lemmatizer(text_3class['train'], nb_nlp['large'])

pipe.fit(text, labels_3class['train'])

prediction = pipe.predict(text_3class['test'])

conf_matrix = confusion_matrix(prediction, labels_3class['test'], labels=['Positive', 'Neutral', 'Negative'])

matrix = pandas.DataFrame(conf_matrix, index= ['Positive', 'Neutral', 'Negative'], columns=['Positive', 'Neutral', 'Negative'])

print(matrix)
# Out:
#           Positive  Neutral  Negative
# Positive       101       53        28
# Neutral        281      526       124
# Negative        19       19        30

# %% [markdown]
# again we see that Neutral sentiment get's under predicted, maby oure problem is that the feature space is too sparce.

# %% [markdown]
# i therefore try logistic regression, logistic regression creates a statistical moddel that tries to draw a boundery in the feature space, the goal is to classify oure data

# %%
pipe = Pipeline([('vect', TfidfVectorizer()),
                ('clf', LogisticRegression(max_iter=500, n_jobs=-1))])

params = {'clf__C': [0.001, 0.01, 0.1, 1, 10, 100]}

grid = GridSearchCV(pipe, params, n_jobs=-1)
grid.fit(text, labels)

score = grid.best_score_
parms = grid.best_params_

print(score, parms)
# Out:
# 0.6348028041650624 {'clf__C': 1}

# %%
pipe = Pipeline([('vect', TfidfVectorizer()),
                 ('clf', GradientBoostingClassifier())])

params = {'clf__n_estimators': [100, 200, 300, 400, 500, 600, 700]}

grid = GridSearchCV(pipe, params, n_jobs=-1)
grid.fit(text, labels)

time = grid.cv_results_['mean_fit_time']
scores = grid.cv_results_['mean_test_score']
parameters = grid.cv_results_['params']

for i in range(0, len(time)):
    print(f'time: {time[i]} \tscore: {scores[i]} \tparameters: {parameters[i]}')
# Out:
# time: 9.1149338722229 	score: 0.5989715077013069 	parameters: {'clf__n_estimators': 50}
# time: 17.170205211639406 	score: 0.6109887099229123 	parameters: {'clf__n_estimators': 100}
# time: 33.38438782691956 	score: 0.6169968932143145 	parameters: {'clf__n_estimators': 200}
# time: 53.35387144088745 	score: 0.6192913782966697 	parameters: {'clf__n_estimators': 300}
# time: 71.8617947101593 	score: 0.6240979726805801 	parameters: {'clf__n_estimators': 400}
# time: 89.77509512901307 	score: 0.6224588074837424 	parameters: {'clf__n_estimators': 500}
# time: 105.62572784423828 	score: 0.6274843989220259 	parameters: {'clf__n_estimators': 600}
# time: 101.68260288238525 	score: 0.6272656406215958 	parameters: {'clf__n_estimators': 700}

# %% [markdown]
# we choose to use Suport vector machines because we have

# %%
pipe = Pipeline([('vect', TfidfVectorizer()),
                 ('clf', SVC())])

params = {'clf__C': [0.1, 1, 1000],
          'clf__gamma': [0.1, 1, 10],
          'vect__use_idf': [True, False],
          'vect__ngram_range': [(1,1), (1,2), (1,3)]}

text = text_3class['train'] + text_3class['test']
labels = labels_3class['train'] + labels_3class ['test']

grid = GridSearchCV(pipe, parameters, n_jobs=-1)
grid.fit(text, labels)

print('Best parameters:', grid.best_params_)
print('Best score:', grid.best_score_)
print('Size of model: none')
print('Size of stopword list: none')

for model in nb_nlp:
    for stop in no_stop:
        text = lemmatizer(text, nb_nlp[model], no_stop[stop])

        grid = GridSearchCV(pipe, parameters, n_jobs=-1)
        grid.fit(text, labels)

        print('Best parameters:', grid.best_params_)
        print('Best score:', grid.best_score_)
        print('Size of model:', model)
        print('Size of stopword list:', stop)
# Out:
# time: 11.150942420959472 	score: 0.5109241866697705 	parameters: {'clf__C': 0.1, 'clf__gamma': 0.1}
# time: 14.382927799224854 	score: 0.5114703363147732 	parameters: {'clf__C': 0.1, 'clf__gamma': 1}
# time: 17.20559158325195 	score: 0.5109241866697705 	parameters: {'clf__C': 0.1, 'clf__gamma': 10}
# time: 14.470163488388062 	score: 0.5877206459487934 	parameters: {'clf__C': 1, 'clf__gamma': 0.1}
# time: 16.74793496131897 	score: 0.6331644746070259 	parameters: {'clf__C': 1, 'clf__gamma': 1}
# time: 17.581197452545165 	score: 0.5122350651947486 	parameters: {'clf__C': 1, 'clf__gamma': 10}
# time: 19.091429281234742 	score: 0.605308753614884 	parameters: {'clf__C': 1000, 'clf__gamma': 0.1}
# time: 17.595486545562743 	score: 0.6426686721997893 	parameters: {'clf__C': 1000, 'clf__gamma': 1}
# time: 14.481508255004883 	score: 0.5122350651947486 	parameters: {'clf__C': 1000, 'clf__gamma': 10}

# %% [markdown]
# Weighted matricees are already numbers from 0 to 1, best accuracy is 0.63%, meaning this is currently the moste accurate method, maby an even higher C can give even better results?

# %%
pipe = Pipeline([('vect', TfidfVectorizer()),
                 ('clf', SVC(gamma=1))])

params = {'clf__C': [100,1000,10000]}

grid = GridSearchCV(pipe, params, n_jobs=-1)
grid.fit(text, labels)

time = grid.cv_results_['mean_fit_time']
scores = grid.cv_results_['mean_test_score']
parameters = grid.cv_results_['params']

print('Best parameters:', grid.best_params_)
print('Best score:', grid.best_score_)
print('Size of model: none')
print('Size of stopword list: none')

for model in nb_nlp:
    for stop in no_stop:
        text = lemmatizer(text, nb_nlp[model], no_stop[stop])

        grid = GridSearchCV(pipe, parameters, n_jobs=-1)
        grid.fit(text, labels)

        print('Best parameters:', grid.best_params_)
        print('Best score:', grid.best_score_)
        print('Size of model:', model)
        print('Size of stopword list:', stop)
# Out:
# time: 18.146734714508057 	score: 0.6426686721997893 	parameters: {'clf__C': 100}
# time: 18.08936176300049 	score: 0.6426686721997893 	parameters: {'clf__C': 1000}
# time: 15.812409019470214 	score: 0.6426686721997893 	parameters: {'clf__C': 10000}

# %% [markdown]
# Larger normalization does not seem to improve the performance of SVC, but Smaler does not seem to decreese the performance either

# %%
pipe = Pipeline([('vect', TfidfVectorizer()),
                 ('clf', SVC(gamma=1))])

params = {'clf__C': [1,5,7,10,100]}

grid = GridSearchCV(pipe, params, n_jobs=-1)
grid.fit(text, labels)

time = grid.cv_results_['mean_fit_time']
scores = grid.cv_results_['mean_test_score']
parameters = grid.cv_results_['params']

for i in range(0, len(time)):
    print(f'time: {time[i]} \tscore: {scores[i]} \tparameters: {parameters[i]}')
# Out:
# time: 14.907119083404542 	score: 0.6331644746070259 	parameters: {'clf__C': 1}
# time: 16.471586418151855 	score: 0.6425596213362461 	parameters: {'clf__C': 5}
# time: 18.462618112564087 	score: 0.6426686721997893 	parameters: {'clf__C': 7}
# time: 18.148515748977662 	score: 0.6426686721997893 	parameters: {'clf__C': 10}
# time: 16.538453245162962 	score: 0.6426686721997893 	parameters: {'clf__C': 100}

# %% [markdown]
# we see that a C between 5 and 7 is optimal, but we don't gain anything from findin the exact right C as we can se from the score of C=10

# %%
pipe = Pipeline([('vect', TfidfVectorizer()),
                 ('scale', StandardScaler(with_mean=False)),
                 ('clf', MLPClassifier())])

params = {'clf__hidden_layer_sizes': [[10,10],[100,100],[1000,1000]]}

grid = GridSearchCV(pipe, params, n_jobs=-1)
grid.fit(text, labels)

scores = grid.cv_results_['mean_test_score']
parameters = grid.cv_results_['params']

print(f'best score:{grid.best_score_} parameters:{grid.best_params_}')
# Out:
# best score:0.5789823710057211 parameters:{'clf__hidden_layer_sizes': [1000, 1000]}
# best score:0.5789823710057211 parameters:{'clf__hidden_layer_sizes': [1000, 1000]}
# best score:0.5789823710057211 parameters:{'clf__hidden_layer_sizes': [1000, 1000]}

# %% [markdown]
# output:
# ```
# best score:0.5789823710057211 parameters:{'clf__hidden_layer_sizes': [1000, 1000]}
# best score:0.5789823710057211 parameters:{'clf__hidden_layer_sizes': [1000, 1000]}
# best score:0.5789823710057211 parameters:{'clf__hidden_layer_sizes': [1000, 1000]}
# ```
# we see that two hidden layers with 1000 items each is stil not overfitting

# %%
print(scores, parameters)
# Out:
# [0.55702614 0.57286514 0.57898237] [{'clf__hidden_layer_sizes': [10, 10]}, {'clf__hidden_layer_sizes': [100, 100]}, {'clf__hidden_layer_sizes': [1000, 1000]}]

# %%
pipe = Pipeline([('vect', TfidfVectorizer()),
                 ('scale', StandardScaler(with_mean=False)),
                 ('clf', MLPClassifier())])

params = {'clf__hidden_layer_sizes': [[1000,1000], [10000,1000], [1000,1000,1000]]}

grid = GridSearchCV(pipe, params, n_jobs=-1)
grid.fit(text, labels)

scores = grid.cv_results_['mean_test_score']
parameters = grid.cv_results_['params']

print(f'best score:{grid.best_score_} parameters:{grid.best_params_}')

# %% [markdown]
# output:
# ```
# [0.55702614 0.57286514 0.57898237] [{'clf__hidden_layer_sizes': [10, 10]}, {'clf__hidden_layer_sizes': [100, 100]}, {'clf__hidden_layer_sizes': [1000, 1000]}]
# ```
# we see that the hidden layers are increasing the performance by 0.6% between two 100 item layers and two 1000 item layers, so we are probably close to overfitting

# %% [markdown]
# CountVectorizer, tokenizes, builds a vocabulary, and encodes the text, in other words, it seperates sentences into lists of words, removes norwegian stopwords (due to us defining norwegian stopwords), and builds dictionaries of the frequencie of each word across each sentence. the stoppwords used here are downloaded from the git: https://raw.githubusercontent.com/stopwords-iso/stopwords-no/master/stopwords-no.json

# %% [markdown]
# The transform function turns the dictionaries from "CountVectorizer" into vectors, and the "get_feature_names_out" function returns the words in the two vectors as a list in alphabetical order. we see that the vectors build on lemmatized sentences are smaler

# %% [markdown]
# still need to test neural network accuracy, and find the optimal classifier for binary sentiment analysis
