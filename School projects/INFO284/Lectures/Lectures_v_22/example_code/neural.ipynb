# %%
import numpy as np
import pandas as pd
import sklearn.datasets as data

# %%
boston = data.load_boston()
X = boston.data
y = boston.target

# %%
from sklearn.neural_network import MLPRegressor
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state= 1234)

# %%
from sklearn.linear_model import LinearRegression
lin = LinearRegression()
lin.fit(X_train,y_train)
print("Linear regression")
print("Test score",  lin.score(X_test, y_test))
print("Train  score", lin.score(X_train, y_train))
# Out:
# Linear regression
# Test score 0.7325732922440757
# Train  score 0.7301842893511348

# %% [markdown]
# ![nn_regression.jpeg](attachment:nn_regression.jpeg)

# %%
nn = MLPRegressor(hidden_layer_sizes = [12,6], activation = 'relu', alpha = 1, max_iter = 10000, solver = 'adam')
nn.fit(X_train,y_train)
print("Neural network")
print("Test score",  nn.score(X_test, y_test))
print("Train  score", nn.score(X_train, y_train))
# Out:
# Neural network
# Test score 0.7829226064789998
# Train  score 0.7573518842388893
